# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 08/01/2020
#
# Obj: Parametrizar o perfil Power Law esférico. A parametrização é feita com gaussianas, de modo que possam ser adicionadas ao potencial do JAM mais tarde. A forma funcional do modelo Power Law Esférico (SPW) é:
#     $\rho(r) = \rho_0 (\frac{r_0}{r})^\alpha = \frac{\bar{\rho_0}}{r^\alpha}$, onde $\bar{\rho_0} = \rho_0 r_0^\alpha$.

# %%
from mgefit import mge_fit_1d
import numpy as np
import matplotlib.pyplot as plt

import astropy.units as u
from astropy.cosmology import Planck15 as cosmo
from astropy.constants import G, c, M_sun

# %%
#Lens parameters

z_lens = 0.035
z_source = 2.1

D_l = cosmo.angular_diameter_distance(z_lens)
D_s = cosmo.angular_diameter_distance(z_source)
D_ls = cosmo.angular_diameter_distance_z1z2(z_lens, z_source)

#Useful constants
metre2Mpc = (1*u.m).to(u.Mpc)/u.m           #Constant factor to convert metre to Mpc.
kg2Msun = (1*u.kg/M_sun)*u.solMass/u.kg     #Constant factor to convert kg to Msun

G_Mpc = G*(metre2Mpc)**3/kg2Msun            #Gravitational constant in Mpc³/(Msun s²)
c_Mpc = c*metre2Mpc                         #Speed of light in Mpc/s
G_pc = G_Mpc*(1e6**3/u.Mpc**3)*u.pc**3      #Gravitational constant in pc³/(Msun s²)

SQRT_TOW_PI = np.sqrt(2*np.pi)              #Square root of 2pi

#ELP parameters
einstein_radius_arc = 2.3*u.arcsec                                              #Einstein radius in arcsec
einstein_radius_rad = einstein_radius_arc.to(u.rad)                             #Einstein radius in rad
einstein_radius_pc = (einstein_radius_arc*D_l).to(u.pc, u.dimensionless_angles()) #Einstein radius in pc

slope = 2.73                                                                  #Slope. Adimensional

mass_inside = (einstein_radius_rad.value**2*D_l*D_s*c_Mpc**2)/(4*G_Mpc*D_ls)  #Mass inside Einstein Ring. Msun
bar_rho0 = (mass_inside*(3-slope))/(4*np.pi*einstein_radius_pc**(3-slope))    #bar_rho0 in Msun/pc^(3-slope)
bar_rho0
# Out:
# <Quantity 2.88163702e+08 solMass / pc(27/100)>

# %%
#Perfil Spherical Power Law
def SPL(bar_rho0, slope, r):
    """
    bar_rho0: float
        Normalization parameter of Spherical Power Law [Msun/pc^(3 - slope)]
    slope: float
        Slope parameter of Spherical Power Law model. [Admensional]
    r: array
        Radius in logscale where do you want parametrize the model. [log(pc)]     
    """
    rho = bar_rho0/r**slope
    print(rho.unit)
    return rho.value

#Realializa a deprojeção de 2d para 3d das gaussianas. Isso assume uma certa parametrização mge2d, um ângulo
    #de inclinação para deprojeção e um formato (oblate ou prolate)
def deprojection(mge2d, inc, shape):
        '''
        Return the 3D deprojected MGE coefficients
        '''
        mge3d = np.zeros_like(mge2d)
        if shape == 'oblate':
            qintr = mge2d[:, 2]**2 - np.cos(inc)**2
            if np.any(qintr <= 0):
                raise RuntimeError('Inclination too low q < 0')
            qintr = np.sqrt(qintr)/np.sin(inc)
            if np.any(qintr < 0.05):
                raise RuntimeError('q < 0.05 components')
            dens = mge2d[:, 0]*mge2d[:, 2] /\
                (mge2d[:, 1]*qintr*SQRT_TOW_PI)
            mge3d[:, 0] = dens
            mge3d[:, 1] = mge2d[:, 1]
            mge3d[:, 2] = qintr
        elif shape == 'prolate':
            qintr = np.sqrt(1.0/mge2d[:, 2]**2 -
                            np.cos(inc)**2)/np.sin(inc)
            if np.any(qintr > 10):
                raise RuntimeError('q > 10.0 conponents')
            sigmaintr = mge2d[:, 1]*mge2d[:, 2]
            dens = mge2d[:, 0] / (SQRT_TOW_PI*mge2d[:, 1] *
                                       mge2d[:, 2]**2*qintr)
            mge3d[:, 0] = dens
            mge3d[:, 1] = sigmaintr
            mge3d[:, 2] = qintr
        return mge3d


#Calcula a densidade luminosa de gaussianadas 3d para algum raio R
def luminosityDensity(mge3d, R, z):
        '''
        Return the luminosity density at coordinate R, z (in L_solar/pc^3)
        '''
        rst = 0.0
        ngauss = mge3d.shape[0]
        for i in range(ngauss):
            rst += mge3d[i, 0] * np.exp(-0.5/mge3d[i, 1]**2 *
                                        (R**2 + (z/mge3d[i, 2])**2))
        return rst

# %%
#Main code

r = np.logspace(np.log10(0.001), np.log10(3000), 1500)*u.pc #Cria valores espaçados em de um delta-log (requerido para o mge1d_fit). Unidade de pc
logr = np.log10(r.value)                                   #"Unidade de pc"

#Calculando o perfil SPL analítico e tomando o log para posterior plot
profile_SPL = np.log10(SPL(bar_rho0=bar_rho0, slope=slope, r=r))   #M_sun/pc³ 

#Agora vamos realizar a parametrização em MGE 1d
r_mge2d = np.logspace(np.log10(0.001), np.log10(3000), 1500)*u.pc #Cria valores espaçados em de um delta-log (requerido para o mge1d_fit)
rho_mge2d = SPL(bar_rho0=bar_rho0, slope=slope, r=r_mge2d) #Perfil SphericalNFW

#-------------Aqui é onde realmente começa a parametrização MGE--------------------------------

mge = mge_fit_1d.mge_fit_1d(r_mge2d.value, rho_mge2d, quiet=True, ngauss=40)
mge_peak = mge.sol[0]         #Pico de cada gaussiana
mge_sigma = mge.sol[1]        #Sigma de cada gaussiana
#O resultado acima já está em M_sun/pc²

mge2d = np.zeros((len(mge_peak), 3)) #Agora iremos criar um array com o número de linhas igual ao número de
                                        #gaussianas e três colunas para armazenar os dados
mge2d[:, 0] = mge_peak     #Pico de cada gaussiana
mge2d[:, 1] = mge_sigma    #Sigma de cada gausiana
mge2d[:, 2] = 1.00         #qObs de cada gaussiana. 



#--------------A partir daqui vamos apenas comparar o perfil analítico com o perfil parametrizado. Em princípio
    #o necessário para o modelo JAM termina acima e só é necessário salvar os dados. ----------------------------#
#Here are some unit conversion
mge3d = deprojection(mge2d=mge2d, inc=np.pi/2, shape='oblate')#Deprojeta o perfil 2d para 3d assumindo uma inclinação inc e um formato do elipsoide de velocidades 
mge_density = luminosityDensity(mge3d,r.value,0) #Densidade das MGE deprojetadas. Atenção as unidades de medida.

#Finalmente o perfil parametrizado pelo MGE.
profile_mge = np.log10(mge_density)

# plot the density profile of the dark halo and the mge approximation

plt.figure(figsize=(18,5))
plt.subplot(121)
line_dh, = plt.plot(logr, 10**profile_SPL, 'k')
line_mge, = plt.plot(logr, 10**profile_mge, 'r')
diff, = plt.plot(logr, profile_SPL-profile_mge, 'b', scalex=200)
plt.xlabel('logR [pc]')
plt.ylabel('[M_solar/pc^3]')
plt.legend([line_dh, line_mge, diff], ['SPL Model', 'MGE approximation', 'Difference'])


plt.subplot(122)
diff, = plt.plot(logr, profile_SPL-profile_mge, 'b', scalex=200)
plt.xlabel('logR [pc]')
plt.ylabel('logrho [M_solar/pc^3]')
plt.legend([diff], ['Difference'])

plt.subplots_adjust(wspace=0.2)
plt.savefig('/home/carlos/autolens_workspace/howtolens/Testes with MGE/Spherical Power-Law/Image Output/SPL MGE and Analitic', fmt='png')

plt.show()
# Out:
# solMass / pc3
# solMass / pc3
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`

# %%
np.savetxt('SPL MGE.txt', np.column_stack([mge2d[:, 0], mge2d[:,1]/(D_l.value*np.pi/0.648),mge2d[:,2]]),
                            fmt=b'%10.6f\t\t %e %10.6f', 
                            header='Surface Potential(M_sun/pc²) Sigma Potential(arcsec) qObs')

#Aqui, quando salvamos o sigma de cada gaussiana dividimos pelo valor (D_l*np.pi/0.648) para termos o valor em arcsec

# %%
mge2d.shape
# Out:
# (34, 3)

# %%
mge2d[:, 0]/1e6**2
# Out:
# array([1.21340987e+13, 5.10026594e+12, 2.47952172e+12, 1.28616370e+12,
#        6.78100088e+11, 3.59590208e+11, 1.91525066e+11, 1.02438043e+11,
#        5.50160300e+10, 2.96712711e+10, 1.60842003e+10, 8.81501741e+09,
#        4.98379017e+09, 2.98706364e+09, 2.00461974e+09])
