# %%
import numpy as np
from astropy.io import fits
from matplotlib import rc
from matplotlib.lines import Line2D

from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# %%
#Reading mask data (shoud be in ascii file with two columns -- ra dec)

x_arc_l,y_arc_l=np.loadtxt('maior.reg',unpack=True, delimiter=',')
x_arc_s,y_arc_s=np.loadtxt('menor.reg',unpack=True)


#Reading image
image_data = fits.getdata('Alma_with_lens_center.fits')

image_shape = image_data.shape

mask = np.ones(image_shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4dd4937e0612> in <module>
#       1 #Reading mask data (shoud be in ascii file with two columns -- ra dec)
#       2
# ----> 3 x_arc_l,y_arc_l=np.loadtxt('maior.reg',unpack=True, delimiter=',')
#       4 x_arc_s,y_arc_s=np.loadtxt('menor.reg',unpack=True)
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1157         # converting the data
#    1158         X = None
# -> 1159         for x in read_data(_loadtxt_chunksize):
#    1160             if X is None:
#    1161                 X = np.array(x, dtype)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1085
#    1086             # Convert each value according to its column and store
# -> 1087             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1088
#    1089             # Then pack it according to the dtype's nesting
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1085
#    1086             # Convert each value according to its column and store
# -> 1087             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1088
#    1089             # Then pack it according to the dtype's nesting
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in floatconv(x)
#     792         if '0x' in x:
#     793             return float.fromhex(x)
# --> 794         return float(x)
#     795
#     796     typ = dtype.type
#
# ValueError: could not convert string to float:

# %%
print(image_shape)
# Out:
# (520, 380)

# %%
pol_l=Polygon(zip(x_arc_l,y_arc_l))
pol_s=Polygon(zip(x_arc_s,y_arc_s))



for i in range(image_shape[1]):
    for j in range(image_shape[0]):
        point = Point((i,j))
        if pol_l.contains(point):
            mask[j,i]=0
        if pol_s.contains(point):
            mask[j,i]=0       
            
fits.writeto('mask.fits',mask,clobber=True)
# Out:
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [warnings]
