# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
hdu_f814w = fits.open('/home/carlos/Área de Trabalho/Testes com JAM e MGE/f814w.fits')
img_f814w = hdu_f814w[1].data
plt.imshow(img_f814w,vmin=0,vmax=1,cmap='gray')
plt.colorbar()

# %%
r = np.arange(0,2+np.pi+2.42407e-5,2.42407e-5)
len(r)
# Out:
# 212107

# %%
print(np.cos(np.pi/2))
# Out:
# 6.123233995736766e-17
