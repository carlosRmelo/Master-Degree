# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 05/27/2020
#
# Obj: Perform the modeling of spectrum based on pPXF method by Cappellari,and obtein the kinematics./Realizar o modelamento de espectros baeado no código pPXF de Cappellari, e obter a cinemática.

# %%
import glob
from os import path

from astropy.io import fits
from scipy import ndimage
import numpy as np

import ppxf as ppxf_package
from ppxf.ppxf import ppxf
import ppxf.ppxf_util as util

import matplotlib.pyplot as plt

# %% [markdown]
# Adaptation of the Ppxf code to apply different spectra.
# **x** and **y** are positions in px, which serves as counter and also index to open the spectrum files, which were saved in the format **y_px X x_px.fits**.
#
# As discussed in the README, the .fits files containing the spectrum have three extensions. Note that pyton, by default, starts a count of zero.
#
# It should be viewed as units of wavelength and flux. By default, pPXF works with wavelength in Angstrons, as we are using the MILES star library. In our case, as we normalize the spectrum, as units of intensity should not cause problems.
#
#
#
# Adapatação do código Ppxf para se aplicar a diversos espectros.
# x e y são as posições em px, de modo que servem de contador e também de index para abrir os arquivos de espectro, que foram salvos no formato **y_px X x_px.fits**.
#
# Como discutido no README, os arquivos .fits que contém os espectros possuem três extensões. Note que o pyton, por padrão, começa a contagem do zero.
#
# Deve-se antentar as unidades de comprimento de onda e fluxo. Por padrão, o ppxf trabalha com comprimento de onda em Angstrons pois estamos utilizando a biblioteca estelar do MILES. No nosso caso como vamos normalizar o espectro, as unidades de intensidade não devem gerar problemas.

# %%
ant = np.loadtxt('Output_Ppxf.txt')
ant[0:25]
# Out:
# array([[   0.        ,    0.        , -396.02255729,  284.25182203,
#            1.66454547,   28.95856277],
#        [   0.        ,    1.        , -324.41309547,  205.10599654,
#            1.96541936,   20.8449083 ],
#        [   0.        ,    2.        , -385.92453345,  381.85498912,
#            1.66226452,   30.56212519],
#        [   0.        ,    3.        , -273.81403898,  290.028026  ,
#            1.45518114,   27.51162755],
#        [   0.        ,    4.        , -359.94879926,  297.12493035,
#            1.57159413,   22.9212819 ],
#        [   0.        ,    5.        , -306.41726948,  279.77893789,
#            1.53186574,   26.35084056],
#        [   0.        ,    6.        , -310.27536308,  247.75067135,
#            1.51819038,   18.97564075],
#        [   0.        ,    7.        , -290.64263526,  295.34989611,
#            1.40606355,   20.15227215],
#        [   0.        ,    8.        , -285.8949286 ,  306.69959497,
#            1.32167415,   20.41834491],
#        [   0.        ,    9.        , -332.25564813,  316.56817698,
#            1.51617368,   22.43912814],
#        [   0.        ,   10.        , -303.28279559,  242.18847963,
#            1.51880655,   18.36255862],
#        [   0.        ,   11.        , -334.35912647,  293.75016588,
#            1.31028374,   18.41537617],
#        [   0.        ,   12.        , -331.76937171,  271.00685295,
#            1.18586694,   17.70084921],
#        [   0.        ,   13.        , -300.34948741,  252.32263445,
#            1.36106304,   19.95060907],
#        [   0.        ,   14.        , -324.7713909 ,  252.20624723,
#            1.21567835,   15.77778579],
#        [   0.        ,   15.        , -335.60624434,  229.02593466,
#            1.16150923,   16.58084277],
#        [   0.        ,   16.        , -338.75143105,  225.5955807 ,
#            1.40820893,   16.12315788],
#        [   0.        ,   17.        , -305.27814411,  291.6427966 ,
#            1.26924763,   18.98124401],
#        [   0.        ,   18.        , -286.9929277 ,  318.52155143,
#            1.30754021,   24.23562994],
#        [   0.        ,   19.        , -336.02228756,  263.16192537,
#            1.42250275,   22.32610942],
#        [   1.        ,    0.        , -244.12347176,  301.25638017,
#            1.30616492,   24.26498916],
#        [   1.        ,    1.        , -277.45494312,  220.66115819,
#            1.46457192,   25.90405541],
#        [   1.        ,    2.        , -325.26502868,  268.24306777,
#            1.50328634,   23.92128786],
#        [   1.        ,    3.        , -299.90980912,  258.13359885,
#            1.43367362,   18.27659268],
#        [   1.        ,    4.        , -306.05185793,  271.8606569 ,
#            1.5342702 ,   21.80813194]])

# %%
ppxf_dir = '/home/carlos/Desktop/ppxf' #Directory of stellar library/Diretória da biblioteca estelar

stellar_lib = '/home/carlos/Downloads/Bibliotecas Estelares/BINTABLE'
stellar_G = '/home/carlos/Downloads/Bibliotecas Estelares/G'
Indo = glob.glob(stellar_lib + '/*.fits')
FWHM_tem = 1.35
chi_dof = []
cont = 0 
for y in range(20):
    for x in range(20):
        chi2_dof = ant[cont][4]
        print(chi2_dof)
    #READING THE SPECTRUM/LENDO UM ESPECTRO
        file = ('/home/carlos/Desktop/ESO325 MUSE-ColletBinning (01-07-20)/Espectros/%dx%d.fits'%(y,x)) #Path and name of the spectrum/Caminho e nome do arquivo do espectro
        hdu = fits.open(file) #Opening the .fits file/Abrindo o arquivo.fits
        gal_lin = hdu[1].data #Read the data/Lendo os dados
        h1 = hdu[1].header    #Read the header/Lendo o header dos dados
        
    #READING THE VARIANCE/LENDO A VARIÂNCIA DO ESPECTRO
        var = hdu[2].data     #Read the variance/Lendo a variância
        h_var = hdu[2].header #Read the variance header/Lendo o header da variância
        
    #LOG-REBIN THE SPECTRUM AND VARIANCE/LOGARITMIZANDO O ESPECTRO E A VARIÂNCIA
        #SPECTRUM/ESPECTRO
        FWHM_gal = 2.71  #FWHM of telescope in Angstrons/FWHM do telescópio em Angstrons
        lambRange1 = h1['CRVAL1'] + np.array([0.,h1['CDELT1']*(h1['NAXIS1']-1)]) #Generating the wavelengths/Está linha gera os comprimentos de onda
                                #pois a variável gal_lin armazena em um array apenas as intensidades, mas não os comprimentos de onda
        
        #De-redshift
        z = 0.035 # Initial estimate of the galaxy redshift
        lambRange1 = lambRange1/(1+z) # Compute approximate restframe wavelength range
        FWHM_gal = FWHM_gal/(1+z)   # Adjust resolution in Angstrom
        #Depois do passo acima, a galáxia passa a estar no restframe, logo é preeciso setar
        z = 0.
        
        #Log-Rebin
        galaxy, logLam1, velscale = util.log_rebin(lambRange1, gal_lin) #Log-rebin the spectrum/Logaritimizando o espectro da galáxia
        median_galaxy = np.median(galaxy) #Mean of spectrum for normalization/Média do espectro, pois vamos normalizá-lo pela média
        galaxy = galaxy/median_galaxy        #Normalizing the spectrum/Normalizando o espectro pela média
        lam = np.exp(logLam1)                #Recovering the wavelength in Ansgstrons/Recuperando o comprimento de onda em unidades do SI
        
        #VARIANCE/VARIÂNCIA
        lamRange_var = h_var['CRVAL1'] + np.array([0.,h_var['CDELT1']*(h_var['NAXIS1']-1)])
        erro = np.sqrt(chi2_dof*var) #1-sigma error from variance/1-sigma erro da variância
        erro, loglam_var, velscale_var = util.log_rebin(lamRange_var, erro)
        noise = erro/median_galaxy         #Normalizing the error/Normalizando o erro        
        
     
    
    
    
    
    #READING ONE TEMPLATE FOR DETERMINE THE LENGHT/LENDO UM TEMPLATE PARA SABER O TAMANHO DO VETOR FINAL
        #The ideia is make a empty array to after complete with the informations about the templates of the stellar libary/
                    #A ideia é crirar um array vazio para que mais tarde seja preenchido com as informações de todos os templetes.
        
        
        velscale_ratio = 2
        hdu = fits.open(Indo[0])
        data = hdu[1].data
        ssp = data[0][1]
        h2 = hdu[0].header
        
    #Log_rebin TEMPLATE/LOGARITMIZANDO O TEMPLATE
        lamRange2 = np.array([data[0][0][0], data[0][0][len(data[0][0]) - 1]]) 
        sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
        templates = np.empty((sspNew.size, len(Indo)))  #Array com o tamanho necessário

    #FINAL FWHM FOR GALAXY AND TEMPLATE CONVOLUTION/CALCULANDO A FWHM FINAL PARA REALIZAR A CONVOLUÇÃO DO TEMPLATE E GALÁXIA
        FWHM_dif = np.sqrt(FWHM_gal**2 - FWHM_tem**2)
        sigma = FWHM_dif/2.355/0.4 #New sigma PSF/Novo sigma da PSF.
    
    #READING ALL TEMPLATES/LENDO TODOS OS TEMPLATES E JÁ LOGARITMIZANDO
        for j, file in enumerate(Indo):
            hdu = fits.open(file)
            data = hdu[1].data
            ssp = data[0][1]
            ssp = ndimage.gaussian_filter1d(ssp, sigma) #Realizando a convolução
            sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
            templates[:, j] = sspNew/np.median(sspNew)
    #ADICIONANDO UM SHIFT PARA COINCIDIR OS COMPRIMENTOS DE ONDA DO ESPECTRO E DO TEMPLATE
        #Artificial shift for the galaxy and templates wavelenght may coincide.    
        #Nem sempre os comprimentos de onda do templete e do espectro coincidem, por esse motivo é dado um 
        #shift artificial ao templete, mas que após o ajuste é retirado.
        c = 299792.458 #Speed of light/Velocidade da Luz
        dv = (np.mean(logLam2[:velscale_ratio]) - logLam1[0])*c #Shift
        goodPixels = util.determine_goodpixels(logLam1, lamRange2, z)  #Mask bad emission lines/Máscaras para linhas de emissão
        vel = c*np.log(1 + z)
        start = [vel, 200.] #Inicial guess/Chute inicial
    
    #START OF FIT/INÍCIO DO AJUSTE
       #For each spectrum the modeling is done. After the best solution is printed 
       #(velocity, velocity dispersion, another moments). Then, a table is write with the information about the
       #pixel position, velocity, velocity dispersion, chi²/DOF and 1-sigma error. The table is saved with name
       #'Output_Ppxf.txt'.  
        
       #Para cada espectro ele realiza o ajuste e printa abaixo o nome do px em que foi realizado o ajuste,
       #bem como as infomações do melhor ajuste (qui², Velocidade, Dispersão, Demais momentos). Então cria uma
       #tabela com as informações necessárias e a salva com o nome 'Output_Ppxf.txt'.
        pp = ppxf(templates, galaxy, noise, velscale, start,
                lam = lam, plot=True, moments=2,
                  degree=6,vsyst=dv, goodpixels=goodPixels, velscale_ratio=velscale_ratio)
    
        #For more informations about the method, visit the paper of Cappellari avaible in README
        #Para mais informações sobre o método, visite o paper de Cappellari disponível no README
        
        #Plot and save the best model/Plota e salva o melhor modelo
        
        pp.plot() #Plot the fit/Plota o fit
        plt.savefig('/home/carlos/Desktop/ESO325 MUSE-ColletBinning (01-07-20)/Spec Fit/%dx%d.png'%(y,x),format='png', dpi=1200)
        plt.clf()
        print(y,x)
        print('Vel :%f.\nDisp:%f.'%(pp.sol[0],pp.sol[1]))
        print('Best-fitting redshift z:', (0.035 + 1)*(1 + pp.sol[0]/c) - 1)
        error = pp.error*np.sqrt(pp.chi2) #1-sigma error/1-sigma erro
    #ESCREVENDO UMA TABELA COM OS DADOS DE Y_PX, X_PX,  VELOCIDADE(KM/S) E DISPERSÃO(KM/S)
        newrow = [np.int(y), np.int(x), pp.sol[0], pp.sol[1], pp.chi2, error[1]]
        if y == 0 and x == 0:
            table = np.array([np.int(y),np.int(x),pp.sol[0], pp.sol[1],pp.chi2, error[1]])
        else:
            table = np.vstack([table,newrow])
        print('\n####################\n')
        cont = cont + 1
# Out:
# 1.6645454718727086
#  Best Fit:       Vel     sigma
#  comp.  0:      -352       296
# chi2/DOF: 1.001
# method = capfit; Jac calls: 8; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 0
# Vel :-351.917441.
# Disp:296.259125.
# Best-fitting redshift z: 0.03378504431339513
#
# ####################
#
# 1.9654193588346764
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       206
# chi2/DOF: 1
# method = capfit; Jac calls: 8; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 1
# Vel :-321.827422.
# Disp:206.121445.
# Best-fitting redshift z: 0.03388892674773958
#
# ####################
#
# 1.6622645217915497
#  Best Fit:       Vel     sigma
#  comp.  0:      -382       383
# chi2/DOF: 1
# method = capfit; Jac calls: 9; Func calls: 29; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 2
# Vel :-382.441448.
# Disp:383.343914.
# Best-fitting redshift z: 0.03367966358631502
#
# ####################
#
# 1.4551811427273014
#  Best Fit:       Vel     sigma
#  comp.  0:      -274       290
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 0 3
# Vel :-273.814055.
# Disp:290.027998.
# Best-fitting redshift z: 0.034054687535070016
#
# ####################
#
# 1.571594128584386
#  Best Fit:       Vel     sigma
#  comp.  0:      -360       297
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 4
# Vel :-360.115455.
# Disp:297.055403.
# Best-fitting redshift z: 0.033756741585704075
#
# ####################
#
# 1.5318657385791314
#  Best Fit:       Vel     sigma
#  comp.  0:      -308       280
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 5
# Vel :-307.807436.
# Disp:280.268525.
# Best-fitting redshift z: 0.033937329184195564
#
# ####################
#
# 1.518190375862505
#  Best Fit:       Vel     sigma
#  comp.  0:      -311       248
# chi2/DOF: 1
# method = capfit; Jac calls: 8; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 6
# Vel :-311.144856.
# Disp:247.929541.
# Best-fitting redshift z: 0.03392580711360016
#
# ####################
#
# 1.4060635484471862
#  Best Fit:       Vel     sigma
#  comp.  0:      -291       295
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 7
# Vel :-290.691019.
# Disp:295.111354.
# Best-fitting redshift z: 0.03399642170208561
#
# ####################
#
# 1.321674152410992
#  Best Fit:       Vel     sigma
#  comp.  0:      -286       307
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 8
# Vel :-285.733089.
# Disp:307.385283.
# Best-fitting redshift z: 0.034013538401208354
#
# ####################
#
# 1.5161736750050334
#  Best Fit:       Vel     sigma
#  comp.  0:      -332       317
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 0 9
# Vel :-332.255490.
# Disp:316.567854.
# Best-fitting redshift z: 0.03385292500506121
#
# ####################
#
# 1.5188065523378982
#  Best Fit:       Vel     sigma
#  comp.  0:      -303       242
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 0 10
# Vel :-303.282689.
# Disp:242.188504.
# Best-fitting redshift z: 0.03395295036547452
#
# ####################
#
# 1.310283743613507
#  Best Fit:       Vel     sigma
#  comp.  0:      -334       294
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 11
# Vel :-334.286322.
# Disp:294.051907.
# Best-fitting redshift z: 0.03384591378547297
#
# ####################
#
# 1.1858669427962005
#  Best Fit:       Vel     sigma
#  comp.  0:      -332       271
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 0 12
# Vel :-331.769373.
# Disp:271.006850.
# Best-fitting redshift z: 0.03385460326889733
#
# ####################
#
# 1.3610630357921
#  Best Fit:       Vel     sigma
#  comp.  0:      -301       252
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 13
# Vel :-300.542272.
# Disp:252.362189.
# Best-fitting redshift z: 0.03396241135240685
#
# ####################
#
# 1.2156783541777691
#  Best Fit:       Vel     sigma
#  comp.  0:      -325       252
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 14
# Vel :-324.505704.
# Disp:252.456430.
# Best-fitting redshift z: 0.03387968027633237
#
# ####################
#
# 1.1615092259716842
#  Best Fit:       Vel     sigma
#  comp.  0:      -335       229
# chi2/DOF: 1
# method = capfit; Jac calls: 8; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 15
# Vel :-334.975267.
# Disp:228.740680.
# Best-fitting redshift z: 0.03384353527829509
#
# ####################
#
# 1.4082089292967201
#  Best Fit:       Vel     sigma
#  comp.  0:      -339       226
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 0 16
# Vel :-338.751436.
# Disp:225.595586.
# Best-fitting redshift z: 0.03383049847628383
#
# ####################
#
# 1.269247625816653
#  Best Fit:       Vel     sigma
#  comp.  0:      -305       292
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 0 17
# Vel :-305.278743.
# Disp:291.643979.
# Best-fitting redshift z: 0.033946059212749624
#
# ####################
#
# 1.307540211035863
#  Best Fit:       Vel     sigma
#  comp.  0:      -287       319
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 0 18
# Vel :-286.986480.
# Disp:318.527340.
# Best-fitting redshift z: 0.03400921120888212
#
# ####################
#
# 1.4225027492267537
#  Best Fit:       Vel     sigma
#  comp.  0:      -336       263
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0 19
# Vel :-335.996449.
# Disp:262.995465.
# Best-fitting redshift z: 0.03384000976205748
#
# ####################
#
# 1.3061649210466542
#  Best Fit:       Vel     sigma
#  comp.  0:      -244       302
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 0
# Vel :-243.837856.
# Disp:301.505154.
# Best-fitting redshift z: 0.03415817701759005
#
# ####################
#
# 1.4645719167999753
#  Best Fit:       Vel     sigma
#  comp.  0:      -280       219
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 22; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 1
# Vel :-280.025297.
# Disp:219.359699.
# Best-fitting redshift z: 0.034033243916258504
#
# ####################
#
# 1.5032863414303932
#  Best Fit:       Vel     sigma
#  comp.  0:      -325       268
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 2
# Vel :-324.852505.
# Disp:267.612491.
# Best-fitting redshift z: 0.03387848298397489
#
# ####################
#
# 1.4336736196896969
#  Best Fit:       Vel     sigma
#  comp.  0:      -301       258
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 1 3
# Vel :-301.346485.
# Disp:258.489070.
# Best-fitting redshift z: 0.03395963489529441
#
# ####################
#
# 1.534270201169111
#  Best Fit:       Vel     sigma
#  comp.  0:      -306       272
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 4
# Vel :-306.482562.
# Disp:271.754235.
# Best-fitting redshift z: 0.033941903163862586
#
# ####################
#
# 1.388670928738489
#  Best Fit:       Vel     sigma
#  comp.  0:      -337       280
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 5
# Vel :-336.695319.
# Disp:279.513030.
# Best-fitting redshift z: 0.033837596989778174
#
# ####################
#
# 1.1459337039332895
#  Best Fit:       Vel     sigma
#  comp.  0:      -290       265
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 1 6
# Vel :-289.921553.
# Disp:265.080851.
# Best-fitting redshift z: 0.03399907819771775
#
# ####################
#
# 1.4096337362831912
#  Best Fit:       Vel     sigma
#  comp.  0:      -308       265
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  13 / 1273
# 1 7
# Vel :-308.063765.
# Disp:264.767315.
# Best-fitting redshift z: 0.033936444237451235
#
# ####################
#
# 1.2909296552475138
#  Best Fit:       Vel     sigma
#  comp.  0:      -310       305
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 8
# Vel :-310.376862.
# Disp:305.067486.
# Best-fitting redshift z: 0.0339284585267281
#
# ####################
#
# 1.3686180673557466
#  Best Fit:       Vel     sigma
#  comp.  0:      -339       272
# chi2/DOF: 1
# method = capfit; Jac calls: 8; Func calls: 29; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  11 / 1273
# 1 9
# Vel :-338.659805.
# Disp:272.407115.
# Best-fitting redshift z: 0.033830814821105504
#
# ####################
#
# 1.3942383400982916
#  Best Fit:       Vel     sigma
#  comp.  0:      -319       288
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 1 10
# Vel :-319.269377.
# Disp:288.272138.
# Best-fitting redshift z: 0.03389775810960005
#
# ####################
#
# 1.0791663941272487
#  Best Fit:       Vel     sigma
#  comp.  0:      -360       316
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 1 11
# Vel :-360.135135.
# Disp:316.291985.
# Best-fitting redshift z: 0.03375667364435264
#
# ####################
#
# 1.3345240879149096
#  Best Fit:       Vel     sigma
#  comp.  0:      -314       278
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 1 12
# Vel :-314.290415.
# Disp:278.395628.
# Best-fitting redshift z: 0.03391494742323098
#
# ####################
#
# 1.4395463384395253
#  Best Fit:       Vel     sigma
#  comp.  0:      -384       263
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 13
# Vel :-383.982004.
# Disp:262.843696.
# Best-fitting redshift z: 0.03367434498847621
#
# ####################
#
# 1.4072479949325158
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       262
# chi2/DOF: 1
# method = capfit; Jac calls: 8; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  12 / 1273
# 1 14
# Vel :-316.898092.
# Disp:261.503518.
# Best-fitting redshift z: 0.03390594470880037
#
# ####################
#
# 1.2580036105099135
#  Best Fit:       Vel     sigma
#  comp.  0:      -301       268
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 15
# Vel :-301.051991.
# Disp:267.748988.
# Best-fitting redshift z: 0.0339606516037434
#
# ####################
#
# 1.2066001024511426
#  Best Fit:       Vel     sigma
#  comp.  0:      -298       303
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 1 16
# Vel :-297.622127.
# Disp:303.120121.
# Best-fitting redshift z: 0.03397249282551251
#
# ####################
#
# 1.4134648852361784
#  Best Fit:       Vel     sigma
#  comp.  0:      -314       263
# chi2/DOF: 1
# method = capfit; Jac calls: 8; Func calls: 28; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 17
# Vel :-314.329807.
# Disp:263.318078.
# Best-fitting redshift z: 0.03391481142347752
#
# ####################
#
# 1.3349835235857381
#  Best Fit:       Vel     sigma
#  comp.  0:      -291       329
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 18
# Vel :-290.875387.
# Disp:329.294954.
# Best-fitting redshift z: 0.033995785194031125
#
# ####################
#
# 1.443772287045948
#  Best Fit:       Vel     sigma
#  comp.  0:      -326       262
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1 19
# Vel :-326.398163.
# Disp:262.214550.
# Best-fitting redshift z: 0.03387314677366238
#
# ####################
#
# 1.6828826503259462
#  Best Fit:       Vel     sigma
#  comp.  0:      -296       291
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 2 0
# Vel :-295.915873.
# Disp:291.108651.
# Best-fitting redshift z: 0.03397838347838955
#
# ####################
#
# 1.4196021107599333
#  Best Fit:       Vel     sigma
#  comp.  0:      -341       269
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 2 1
# Vel :-340.968773.
# Disp:268.676372.
# Best-fitting redshift z: 0.03382284336771346
#
# ####################
#
# 1.4079590880285853
#  Best Fit:       Vel     sigma
#  comp.  0:      -306       304
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 2 2
# Vel :-306.317730.
# Disp:304.338188.
# Best-fitting redshift z: 0.03394247222562652
#
# ####################
#
# 1.262996455255957
#  Best Fit:       Vel     sigma
#  comp.  0:      -334       326
# chi2/DOF: 1
# method = capfit; Jac calls: 9; Func calls: 31; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 2 3
# Vel :-334.181269.
# Disp:326.209076.
# Best-fitting redshift z: 0.03384627646683325
#
# ####################
#
# 1.2962590207926823
#  Best Fit:       Vel     sigma
#  comp.  0:      -319       266
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 4
# Vel :-319.274039.
# Disp:265.745967.
# Best-fitting redshift z: 0.03389774201478968
#
# ####################
#
# 1.3883521345581646
#  Best Fit:       Vel     sigma
#  comp.  0:      -315       206
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 2 5
# Vel :-315.409196.
# Disp:206.319789.
# Best-fitting redshift z: 0.03391108495402362
#
# ####################
#
# 1.210393031203094
#  Best Fit:       Vel     sigma
#  comp.  0:      -340       275
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 6
# Vel :-339.763935.
# Disp:274.946217.
# Best-fitting redshift z: 0.03382700293749563
#
# ####################
#
# 1.322704242889073
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       298
# chi2/DOF: 1
# method = capfit; Jac calls: 8; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 7
# Vel :-317.024935.
# Disp:297.643040.
# Best-fitting redshift z: 0.033905506795887774
#
# ####################
#
# 1.284905095492469
#  Best Fit:       Vel     sigma
#  comp.  0:      -331       283
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 8
# Vel :-331.468579.
# Disp:283.484572.
# Best-fitting redshift z: 0.0338556417280913
#
# ####################
#
# 1.2117194692390543
#  Best Fit:       Vel     sigma
#  comp.  0:      -308       272
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 2 9
# Vel :-308.047727.
# Disp:271.979271.
# Best-fitting redshift z: 0.033936499605220716
#
# ####################
#
# 1.4870322098717466
#  Best Fit:       Vel     sigma
#  comp.  0:      -312       280
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 10
# Vel :-311.602065.
# Disp:280.100586.
# Best-fitting redshift z: 0.03392422865059963
#
# ####################
#
# 1.1978187119502304
#  Best Fit:       Vel     sigma
#  comp.  0:      -336       281
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 11
# Vel :-336.255476.
# Disp:281.259663.
# Best-fitting redshift z: 0.03383911549973195
#
# ####################
#
# 1.2130779007811583
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       314
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 12
# Vel :-316.516644.
# Disp:314.052928.
# Best-fitting redshift z: 0.0339072616140812
#
# ####################
#
# 1.2045700719894787
#  Best Fit:       Vel     sigma
#  comp.  0:      -338       281
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 13
# Vel :-337.591881.
# Disp:280.939427.
# Best-fitting redshift z: 0.033834501710370946
#
# ####################
#
# 1.335163949362704
#  Best Fit:       Vel     sigma
#  comp.  0:      -355       290
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 14
# Vel :-355.013799.
# Disp:289.756743.
# Best-fitting redshift z: 0.03377435448476129
#
# ####################
#
# 1.446485949104975
#  Best Fit:       Vel     sigma
#  comp.  0:      -367       288
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 2 15
# Vel :-366.743319.
# Disp:288.110084.
# Best-fitting redshift z: 0.03373385962535158
#
# ####################
#
# 1.331921468079554
#  Best Fit:       Vel     sigma
#  comp.  0:      -308       281
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 16
# Vel :-307.876756.
# Disp:280.701037.
# Best-fitting redshift z: 0.03393708986419264
#
# ####################
#
# 1.3510892375115002
#  Best Fit:       Vel     sigma
#  comp.  0:      -263       263
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 17
# Vel :-263.150491.
# Disp:262.972771.
# Best-fitting redshift z: 0.034091502300906074
#
# ####################
#
# 1.3471168361520844
#  Best Fit:       Vel     sigma
#  comp.  0:      -270       287
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2 18
# Vel :-269.886213.
# Disp:286.593946.
# Best-fitting redshift z: 0.034068247974440746
#
# ####################
#
# 1.5444232501159816
#  Best Fit:       Vel     sigma
#  comp.  0:      -302       271
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 2 19
# Vel :-302.209650.
# Disp:271.449784.
# Best-fitting redshift z: 0.03395665491399158
#
# ####################
#
# 1.4113092221882721
#  Best Fit:       Vel     sigma
#  comp.  0:      -324       260
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 0
# Vel :-323.720194.
# Disp:259.846391.
# Best-fitting redshift z: 0.033882392162783326
#
# ####################
#
# 1.340436379593769
#  Best Fit:       Vel     sigma
#  comp.  0:      -286       265
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 1
# Vel :-285.587933.
# Disp:265.129433.
# Best-fitting redshift z: 0.03401403953552129
#
# ####################
#
# 1.447184569320201
#  Best Fit:       Vel     sigma
#  comp.  0:      -324       275
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 2
# Vel :-324.005497.
# Disp:274.662648.
# Best-fitting redshift z: 0.03388140718472621
#
# ####################
#
# 1.3218830789825078
#  Best Fit:       Vel     sigma
#  comp.  0:      -354       287
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 3 3
# Vel :-353.635667.
# Disp:287.123847.
# Best-fitting redshift z: 0.0337791123311193
#
# ####################
#
# 1.248246686924182
#  Best Fit:       Vel     sigma
#  comp.  0:      -304       289
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 3 4
# Vel :-304.173918.
# Disp:289.354477.
# Best-fitting redshift z: 0.0339498734981214
#
# ####################
#
# 1.2296000201194364
#  Best Fit:       Vel     sigma
#  comp.  0:      -253       278
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 5
# Vel :-252.929390.
# Disp:278.277528.
# Best-fitting redshift z: 0.03412678951070314
#
# ####################
#
# 1.1844092449054981
#  Best Fit:       Vel     sigma
#  comp.  0:      -357       281
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 3 6
# Vel :-357.374042.
# Disp:281.459898.
# Best-fitting redshift z: 0.033766206008809085
#
# ####################
#
# 1.3018153728756334
#  Best Fit:       Vel     sigma
#  comp.  0:      -318       296
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 3 7
# Vel :-318.485680.
# Disp:296.469404.
# Best-fitting redshift z: 0.03390046373606448
#
# ####################
#
# 1.3760844939652115
#  Best Fit:       Vel     sigma
#  comp.  0:      -298       282
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  13 / 1273
# 3 8
# Vel :-297.993310.
# Disp:282.015150.
# Best-fitting redshift z: 0.03397121135741088
#
# ####################
#
# 1.2730280992721028
#  Best Fit:       Vel     sigma
#  comp.  0:      -335       280
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 9
# Vel :-334.905507.
# Disp:279.727393.
# Best-fitting redshift z: 0.03384377611577616
#
# ####################
#
# 1.3467916361004924
#  Best Fit:       Vel     sigma
#  comp.  0:      -278       296
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 10
# Vel :-277.843830.
# Disp:295.895675.
# Best-fitting redshift z: 0.03404077518755888
#
# ####################
#
# 1.096566812705899
#  Best Fit:       Vel     sigma
#  comp.  0:      -358       292
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  20 / 1273
# 3 11
# Vel :-357.774795.
# Disp:292.087693.
# Best-fitting redshift z: 0.033764822452085896
#
# ####################
#
# 1.212948973228336
#  Best Fit:       Vel     sigma
#  comp.  0:      -305       306
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 12
# Vel :-304.745995.
# Disp:305.851467.
# Best-fitting redshift z: 0.033947898466410775
#
# ####################
#
# 1.1437751230328623
#  Best Fit:       Vel     sigma
#  comp.  0:      -329       298
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  2 / 1273
# 3 13
# Vel :-329.422496.
# Disp:298.126499.
# Best-fitting redshift z: 0.03386270560237614
#
# ####################
#
# 1.2785344986942908
#  Best Fit:       Vel     sigma
#  comp.  0:      -285       267
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 14
# Vel :-284.662603.
# Disp:266.800388.
# Best-fitting redshift z: 0.03401723413643887
#
# ####################
#
# 1.3175980301488834
#  Best Fit:       Vel     sigma
#  comp.  0:      -315       308
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 22; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  2 / 1273
# 3 15
# Vel :-315.326972.
# Disp:308.275687.
# Best-fitting redshift z: 0.033911368825195964
#
# ####################
#
# 1.4230955958112386
#  Best Fit:       Vel     sigma
#  comp.  0:      -331       286
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 16
# Vel :-331.367725.
# Disp:286.477793.
# Best-fitting redshift z: 0.03385598991475214
#
# ####################
#
# 1.3924579400580452
#  Best Fit:       Vel     sigma
#  comp.  0:      -366       321
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 17
# Vel :-366.133065.
# Disp:320.537544.
# Best-fitting redshift z: 0.03373596645989152
#
# ####################
#
# 1.2164878738630072
#  Best Fit:       Vel     sigma
#  comp.  0:      -293       256
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 3 18
# Vel :-292.797058.
# Disp:255.961589.
# Best-fitting redshift z: 0.03398915083877729
#
# ####################
#
# 1.3140697534811054
#  Best Fit:       Vel     sigma
#  comp.  0:      -278       262
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3 19
# Vel :-277.787713.
# Disp:262.470462.
# Best-fitting redshift z: 0.0340409689268395
#
# ####################
#
# 1.4227760324186596
#  Best Fit:       Vel     sigma
#  comp.  0:      -354       211
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 0
# Vel :-354.104658.
# Disp:210.609952.
# Best-fitting redshift z: 0.03377749319239842
#
# ####################
#
# 1.4688641182848925
#  Best Fit:       Vel     sigma
#  comp.  0:      -299       306
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 1
# Vel :-299.299108.
# Disp:305.637354.
# Best-fitting redshift z: 0.033966703234686424
#
# ####################
#
# 1.1322101256267811
#  Best Fit:       Vel     sigma
#  comp.  0:      -323       267
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 2
# Vel :-322.911475.
# Disp:266.964235.
# Best-fitting redshift z: 0.033885184174689886
#
# ####################
#
# 1.3384920166166376
#  Best Fit:       Vel     sigma
#  comp.  0:      -359       309
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 3
# Vel :-359.477005.
# Disp:308.798940.
# Best-fitting redshift z: 0.03375894576351279
#
# ####################
#
# 1.2383113187978874
#  Best Fit:       Vel     sigma
#  comp.  0:      -314       288
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 4 4
# Vel :-313.634886.
# Disp:287.738347.
# Best-fitting redshift z: 0.03391721056217856
#
# ####################
#
# 1.2636280211941864
#  Best Fit:       Vel     sigma
#  comp.  0:      -302       294
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 5
# Vel :-302.412024.
# Disp:293.656753.
# Best-fitting redshift z: 0.03395595624158387
#
# ####################
#
# 1.2136720220437285
#  Best Fit:       Vel     sigma
#  comp.  0:      -343       298
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 4 6
# Vel :-342.723400.
# Disp:298.048585.
# Best-fitting redshift z: 0.033816785714164244
#
# ####################
#
# 1.4002043685835608
#  Best Fit:       Vel     sigma
#  comp.  0:      -360       291
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 4 7
# Vel :-360.246430.
# Disp:291.443024.
# Best-fitting redshift z: 0.03375628941003028
#
# ####################
#
# 1.1739783171911062
#  Best Fit:       Vel     sigma
#  comp.  0:      -341       271
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 8
# Vel :-340.629852.
# Disp:271.441572.
# Best-fitting redshift z: 0.03382401345451491
#
# ####################
#
# 1.1903673615962
#  Best Fit:       Vel     sigma
#  comp.  0:      -319       289
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 9
# Vel :-319.093678.
# Disp:288.816802.
# Best-fitting redshift z: 0.0338983646923523
#
# ####################
#
# 0.9525117531964292
#  Best Fit:       Vel     sigma
#  comp.  0:      -310       304
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 10
# Vel :-309.898604.
# Disp:304.497455.
# Best-fitting redshift z: 0.0339301096586202
#
# ####################
#
# 1.1567633003646547
#  Best Fit:       Vel     sigma
#  comp.  0:      -298       302
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 4 11
# Vel :-297.668314.
# Disp:302.358494.
# Best-fitting redshift z: 0.03397233337002392
#
# ####################
#
# 1.1266915490904388
#  Best Fit:       Vel     sigma
#  comp.  0:      -329       315
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 12
# Vel :-328.952817.
# Disp:314.941391.
# Best-fitting redshift z: 0.03386432711547882
#
# ####################
#
# 1.1164382862459192
#  Best Fit:       Vel     sigma
#  comp.  0:      -308       297
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  22 / 1273
# 4 13
# Vel :-308.312190.
# Disp:296.731880.
# Best-fitting redshift z: 0.03393558657558571
#
# ####################
#
# 1.684446370240623
#  Best Fit:       Vel     sigma
#  comp.  0:      -302       286
# chi2/DOF: 1
# method = capfit; Jac calls: 9; Func calls: 31; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 14
# Vel :-301.856033.
# Disp:285.990589.
# Best-fitting redshift z: 0.03395787573809317
#
# ####################
#
# 1.1503617444185223
#  Best Fit:       Vel     sigma
#  comp.  0:      -305       323
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 25; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  2 / 1273
# 4 15
# Vel :-304.861812.
# Disp:323.076014.
# Best-fitting redshift z: 0.03394749862097379
#
# ####################
#
# 1.2003903200184596
#  Best Fit:       Vel     sigma
#  comp.  0:      -334       322
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 16
# Vel :-334.304831.
# Disp:321.623250.
# Best-fitting redshift z: 0.03384584988448869
#
# ####################
#
# 1.180730437695441
#  Best Fit:       Vel     sigma
#  comp.  0:      -338       276
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 17
# Vel :-337.551188.
# Disp:276.379989.
# Best-fitting redshift z: 0.0338346421997342
#
# ####################
#
# 1.3534463207651135
#  Best Fit:       Vel     sigma
#  comp.  0:      -329       264
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 18
# Vel :-328.637129.
# Disp:264.125349.
# Best-fitting redshift z: 0.033865416991962105
#
# ####################
#
# 1.778708043258709
#  Best Fit:       Vel     sigma
#  comp.  0:      -311       292
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4 19
# Vel :-311.112134.
# Disp:291.880040.
# Best-fitting redshift z: 0.033925920081060434
#
# ####################
#
# 1.48929415714418
#  Best Fit:       Vel     sigma
#  comp.  0:      -303       306
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5 0
# Vel :-303.276442.
# Disp:306.321805.
# Best-fitting redshift z: 0.03395297193464031
#
# ####################
#
# 1.221663054584871
#  Best Fit:       Vel     sigma
#  comp.  0:      -308       304
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 5 1
# Vel :-307.772294.
# Disp:303.599481.
# Best-fitting redshift z: 0.03393745050658459
#
# ####################
#
# 1.2583212142819626
#  Best Fit:       Vel     sigma
#  comp.  0:      -283       269
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5 2
# Vel :-282.525673.
# Disp:269.221726.
# Best-fitting redshift z: 0.03402461164700887
#
# ####################
#
# 1.2745281726187916
#  Best Fit:       Vel     sigma
#  comp.  0:      -320       280
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  12 / 1273
# 5 3
# Vel :-319.938238.
# Disp:280.015321.
# Best-fitting redshift z: 0.033895448941463346
#
# ####################
#
# 1.2739603808037818
#  Best Fit:       Vel     sigma
#  comp.  0:      -315       279
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 5 4
# Vel :-314.617642.
# Disp:278.882580.
# Best-fitting redshift z: 0.033913817707417415
#
# ####################
#
# 1.1304749033236483
#  Best Fit:       Vel     sigma
#  comp.  0:      -340       295
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5 5
# Vel :-339.552502.
# Disp:294.810083.
# Best-fitting redshift z: 0.033827732886360984
#
# ####################
#
# 0.9998585356468292
#  Best Fit:       Vel     sigma
#  comp.  0:      -275       317
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  2 / 1273
# 5 6
# Vel :-275.466955.
# Disp:316.516901.
# Best-fitting redshift z: 0.034048981085093466
#
# ####################
#
# 1.1470035198539335
#  Best Fit:       Vel     sigma
#  comp.  0:      -335       307
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 5 7
# Vel :-334.600674.
# Disp:307.131650.
# Best-fitting redshift z: 0.033844828519205894
#
# ####################
#
# 1.0986581265322621
#  Best Fit:       Vel     sigma
#  comp.  0:      -298       291
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 22; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5 8
# Vel :-297.852485.
# Disp:290.659436.
# Best-fitting redshift z: 0.0339716975408213
#
# ####################
#
# 1.127548376253845
#  Best Fit:       Vel     sigma
#  comp.  0:      -331       300
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5 9
# Vel :-330.844576.
# Disp:300.013842.
# Best-fitting redshift z: 0.03385779602838035
#
# ####################
#
# 1.0093491480041001
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       284
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 5 10
# Vel :-322.137997.
# Disp:283.786517.
# Best-fitting redshift z: 0.033887854519025096
#
# ####################
#
# 1.0178455132500135
#  Best Fit:       Vel     sigma
#  comp.  0:      -314       318
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5 11
# Vel :-313.898699.
# Disp:318.470053.
# Best-fitting redshift z: 0.03391629977637445
#
# ####################
#
# 1.1875167270577707
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       313
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 5 12
# Vel :-320.895758.
# Disp:312.501795.
# Best-fitting redshift z: 0.03389214321197187
#
# ####################
#
# 0.9766184298666638
#  Best Fit:       Vel     sigma
#  comp.  0:      -310       296
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5 13
# Vel :-310.076200.
# Disp:295.963472.
# Best-fitting redshift z: 0.03392949652727051
#
# ####################
#
# 1.1413066612396747
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       308
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5 14
# Vel :-313.179670.
# Disp:308.384034.
# Best-fitting redshift z: 0.03391878214374655
#
# ####################
#
# 1.1806796597053202
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       268
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  24 / 1273
# 5 15
# Vel :-320.562978.
# Disp:267.668208.
# Best-fitting redshift z: 0.033893292096682126
#
# ####################
#
# 1.187929592150992
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       311
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 5 16
# Vel :-322.235370.
# Disp:310.822787.
# Best-fitting redshift z: 0.033887518350569135
#
# ####################
#
# 1.5663184270553858
#  Best Fit:       Vel     sigma
#  comp.  0:      -291       280
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5 17
# Vel :-290.971851.
# Disp:279.701374.
# Best-fitting redshift z: 0.03399545215944588
#
# ####################
#
# 1.3658589331470816
#  Best Fit:       Vel     sigma
#  comp.  0:      -291       281
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  13 / 1273
# 5 18
# Vel :-291.134463.
# Disp:281.402178.
# Best-fitting redshift z: 0.03399489076038664
#
# ####################
#
# 1.2960394166740896
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       324
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5 19
# Vel :-313.346482.
# Disp:323.949891.
# Best-fitting redshift z: 0.033918206243324756
#
# ####################
#
# 1.279222286756276
#  Best Fit:       Vel     sigma
#  comp.  0:      -305       285
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  13 / 1273
# 6 0
# Vel :-304.838853.
# Disp:284.553876.
# Best-fitting redshift z: 0.03394757788489966
#
# ####################
#
# 1.2324153320564795
#  Best Fit:       Vel     sigma
#  comp.  0:      -316       305
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6 1
# Vel :-315.818531.
# Disp:305.149710.
# Best-fitting redshift z: 0.03390967177305848
#
# ####################
#
# 1.2645256183487013
#  Best Fit:       Vel     sigma
#  comp.  0:      -359       299
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  2 / 1273
# 6 2
# Vel :-359.480523.
# Disp:298.947308.
# Best-fitting redshift z: 0.033758933619026266
#
# ####################
#
# 1.2705580924775124
#  Best Fit:       Vel     sigma
#  comp.  0:      -309       309
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6 3
# Vel :-309.290059.
# Disp:309.016840.
# Best-fitting redshift z: 0.03393221059224416
#
# ####################
#
# 1.0722181296062583
#  Best Fit:       Vel     sigma
#  comp.  0:      -342       302
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  11 / 1273
# 6 4
# Vel :-341.785504.
# Disp:301.820094.
# Best-fitting redshift z: 0.0338200236940589
#
# ####################
#
# 1.288829476029085
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       312
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 6 5
# Vel :-316.712991.
# Disp:311.829690.
# Best-fitting redshift z: 0.03390658374940059
#
# ####################
#
# 1.1312071342415324
#  Best Fit:       Vel     sigma
#  comp.  0:      -338       293
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  19 / 1273
# 6 6
# Vel :-337.747924.
# Disp:292.901155.
# Best-fitting redshift z: 0.0338339629885831
#
# ####################
#
# 1.099975729938517
#  Best Fit:       Vel     sigma
#  comp.  0:      -312       305
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 4
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6 7
# Vel :-311.711404.
# Disp:304.778744.
# Best-fitting redshift z: 0.033923851167932506
#
# ####################
#
# 1.0097357469946937
#  Best Fit:       Vel     sigma
#  comp.  0:      -333       318
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6 8
# Vel :-332.881989.
# Disp:318.282864.
# Best-fitting redshift z: 0.03385076208640991
#
# ####################
#
# 0.96344174049722
#  Best Fit:       Vel     sigma
#  comp.  0:      -335       321
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  22 / 1273
# 6 9
# Vel :-335.219318.
# Disp:320.873008.
# Best-fitting redshift z: 0.03384269272038498
#
# ####################
#
# 0.9127047532292895
#  Best Fit:       Vel     sigma
#  comp.  0:      -301       308
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 6 10
# Vel :-301.323114.
# Disp:308.063727.
# Best-fitting redshift z: 0.03395971558015076
#
# ####################
#
# 0.929114310354164
#  Best Fit:       Vel     sigma
#  comp.  0:      -324       302
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6 11
# Vel :-324.403306.
# Disp:302.004356.
# Best-fitting redshift z: 0.033880033795262054
#
# ####################
#
# 1.0111164780301476
#  Best Fit:       Vel     sigma
#  comp.  0:      -347       289
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6 12
# Vel :-346.501128.
# Disp:288.609374.
# Best-fitting redshift z: 0.03380374353032978
#
# ####################
#
# 1.2500840909746749
#  Best Fit:       Vel     sigma
#  comp.  0:      -330       290
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 6 13
# Vel :-330.237431.
# Disp:290.065920.
# Best-fitting redshift z: 0.03385989213025575
#
# ####################
#
# 1.1645624710146716
#  Best Fit:       Vel     sigma
#  comp.  0:      -305       309
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6 14
# Vel :-304.990440.
# Disp:308.708389.
# Best-fitting redshift z: 0.03394705454793412
#
# ####################
#
# 1.0915155936365968
#  Best Fit:       Vel     sigma
#  comp.  0:      -315       297
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6 15
# Vel :-314.508981.
# Disp:297.354621.
# Best-fitting redshift z: 0.03391419284775421
#
# ####################
#
# 1.1890678562625918
#  Best Fit:       Vel     sigma
#  comp.  0:      -331       317
# chi2/DOF: 1
# method = capfit; Jac calls: 8; Func calls: 28; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6 16
# Vel :-331.245412.
# Disp:317.451169.
# Best-fitting redshift z: 0.03385641218842417
#
# ####################
#
# 1.3029753290549753
#  Best Fit:       Vel     sigma
#  comp.  0:      -304       291
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 6 17
# Vel :-304.494154.
# Disp:291.326968.
# Best-fitting redshift z: 0.033948767919985245
#
# ####################
#
# 1.3702061783254718
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       275
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6 18
# Vel :-312.614056.
# Disp:274.717026.
# Best-fitting redshift z: 0.03392073486568914
#
# ####################
#
# 1.157046554586505
#  Best Fit:       Vel     sigma
#  comp.  0:      -352       290
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  19 / 1273
# 6 19
# Vel :-351.560154.
# Disp:290.175368.
# Best-fitting redshift z: 0.03378627780922461
#
# ####################
#
# 1.4469879007023088
#  Best Fit:       Vel     sigma
#  comp.  0:      -278       273
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 7 0
# Vel :-277.855785.
# Disp:273.471676.
# Best-fitting redshift z: 0.03404073391650764
#
# ####################
#
# 1.2062547898775484
#  Best Fit:       Vel     sigma
#  comp.  0:      -283       278
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 7 1
# Vel :-283.350507.
# Disp:277.852288.
# Best-fitting redshift z: 0.03402176400095969
#
# ####################
#
# 1.1186304825338067
#  Best Fit:       Vel     sigma
#  comp.  0:      -305       310
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 7 2
# Vel :-305.343448.
# Disp:310.471689.
# Best-fitting redshift z: 0.03394583582610089
#
# ####################
#
# 1.0892928622238156
#  Best Fit:       Vel     sigma
#  comp.  0:      -310       291
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 7 3
# Vel :-310.388139.
# Disp:290.607197.
# Best-fitting redshift z: 0.033928419595297354
#
# ####################
#
# 1.1112417205217526
#  Best Fit:       Vel     sigma
#  comp.  0:      -300       293
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 7 4
# Vel :-299.561700.
# Disp:292.712334.
# Best-fitting redshift z: 0.03396579666517585
#
# ####################
#
# 1.1887911604347727
#  Best Fit:       Vel     sigma
#  comp.  0:      -312       304
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 7 5
# Vel :-311.535220.
# Disp:303.587055.
# Best-fitting redshift z: 0.03392445942574618
#
# ####################
#
# 1.0942142449499492
#  Best Fit:       Vel     sigma
#  comp.  0:      -345       305
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  13 / 1273
# 7 6
# Vel :-345.425758.
# Disp:305.200924.
# Best-fitting redshift z: 0.03380745612658953
#
# ####################
#
# 1.0395371430184963
#  Best Fit:       Vel     sigma
#  comp.  0:      -326       301
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 7 7
# Vel :-326.074337.
# Disp:301.269134.
# Best-fitting redshift z: 0.03387426474563271
#
# ####################
#
# 0.9477970616124065
#  Best Fit:       Vel     sigma
#  comp.  0:      -334       305
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 7 8
# Vel :-334.148178.
# Disp:305.407208.
# Best-fitting redshift z: 0.03384639071271689
#
# ####################
#
# 0.9651147452527191
#  Best Fit:       Vel     sigma
#  comp.  0:      -326       326
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 7 9
# Vel :-325.563562.
# Disp:325.785130.
# Best-fitting redshift z: 0.033876028140831016
#
# ####################
#
# 1.1311971524498723
#  Best Fit:       Vel     sigma
#  comp.  0:      -315       311
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  19 / 1273
# 7 10
# Vel :-314.696074.
# Disp:310.618376.
# Best-fitting redshift z: 0.033913546930160354
#
# ####################
#
# 0.9261205176365412
#  Best Fit:       Vel     sigma
#  comp.  0:      -328       309
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# ...
# Vel :-351.886813.
# Disp:289.871735.
# Best-fitting redshift z: 0.033785150053090574
#
# ####################
#
# 1.1422808385879546
#  Best Fit:       Vel     sigma
#  comp.  0:      -315       246
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 17 10
# Vel :-314.584209.
# Disp:245.952401.
# Best-fitting redshift z: 0.0339139331293421
#
# ####################
#
# 1.1491439939211996
#  Best Fit:       Vel     sigma
#  comp.  0:      -283       257
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 17 11
# Vel :-282.940325.
# Disp:256.537635.
# Best-fitting redshift z: 0.03402318010791161
#
# ####################
#
# 1.2701098831531183
#  Best Fit:       Vel     sigma
#  comp.  0:      -335       320
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 17 12
# Vel :-334.835667.
# Disp:320.314563.
# Best-fitting redshift z: 0.03384401723189301
#
# ####################
#
# 1.4005431106221016
#  Best Fit:       Vel     sigma
#  comp.  0:      -346       274
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 17 13
# Vel :-346.038290.
# Disp:274.499394.
# Best-fitting redshift z: 0.03380534142539782
#
# ####################
#
# 1.475993987845408
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       322
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 17 14
# Vel :-320.871535.
# Disp:322.303073.
# Best-fitting redshift z: 0.033892226839695505
#
# ####################
#
# 1.3305156619461027
#  Best Fit:       Vel     sigma
#  comp.  0:      -340       275
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 17 15
# Vel :-339.908756.
# Disp:274.518974.
# Best-fitting redshift z: 0.033826502958397286
#
# ####################
#
# 1.3791473120143958
#  Best Fit:       Vel     sigma
#  comp.  0:      -365       301
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  2 / 1273
# 17 16
# Vel :-364.916842.
# Disp:300.842823.
# Best-fitting redshift z: 0.03374016533259705
#
# ####################
#
# 1.4027293095621662
#  Best Fit:       Vel     sigma
#  comp.  0:      -324       251
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 17 17
# Vel :-323.693710.
# Disp:251.300899.
# Best-fitting redshift z: 0.03388248359364954
#
# ####################
#
# 1.5137794820105996
#  Best Fit:       Vel     sigma
#  comp.  0:      -280       320
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 17 18
# Vel :-279.806335.
# Disp:320.482215.
# Best-fitting redshift z: 0.03403399985728783
#
# ####################
#
# 1.3752300433190296
#  Best Fit:       Vel     sigma
#  comp.  0:      -333       271
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 17 19
# Vel :-333.484029.
# Disp:271.155576.
# Best-fitting redshift z: 0.033848683612414776
#
# ####################
#
# 1.3324339085016008
#  Best Fit:       Vel     sigma
#  comp.  0:      -318       268
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 18 0
# Vel :-317.675875.
# Disp:268.109467.
# Best-fitting redshift z: 0.03390325949808215
#
# ####################
#
# 1.4246526446180157
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       284
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 1
# Vel :-317.048319.
# Disp:283.686370.
# Best-fitting redshift z: 0.03390542606477576
#
# ####################
#
# 1.3375786998657206
#  Best Fit:       Vel     sigma
#  comp.  0:      -272       252
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 2
# Vel :-271.758222.
# Disp:252.203169.
# Best-fitting redshift z: 0.03406178507154478
#
# ####################
#
# 1.4014201265334074
#  Best Fit:       Vel     sigma
#  comp.  0:      -325       283
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 3
# Vel :-324.885538.
# Disp:282.725286.
# Best-fitting redshift z: 0.03387836894257257
#
# ####################
#
# 1.3564041329025256
#  Best Fit:       Vel     sigma
#  comp.  0:      -340       228
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 4
# Vel :-339.586660.
# Disp:227.629589.
# Best-fitting redshift z: 0.03382761496088049
#
# ####################
#
# 1.3808391126890047
#  Best Fit:       Vel     sigma
#  comp.  0:      -327       273
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 24; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 5
# Vel :-327.099567.
# Disp:273.155604.
# Best-fitting redshift z: 0.03387072525280588
#
# ####################
#
# 1.6166784404918562
#  Best Fit:       Vel     sigma
#  comp.  0:      -329       291
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 6
# Vel :-329.114219.
# Disp:291.428987.
# Best-fitting redshift z: 0.03386376989161266
#
# ####################
#
# 1.5124890735882286
#  Best Fit:       Vel     sigma
#  comp.  0:      -346       267
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 28; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 7
# Vel :-345.774434.
# Disp:266.829066.
# Best-fitting redshift z: 0.03380625236106538
#
# ####################
#
# 1.4734182876956872
#  Best Fit:       Vel     sigma
#  comp.  0:      -330       240
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 8
# Vel :-330.386362.
# Disp:240.424811.
# Best-fitting redshift z: 0.03385937796160543
#
# ####################
#
# 1.1799558294199146
#  Best Fit:       Vel     sigma
#  comp.  0:      -320       308
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 9
# Vel :-320.356471.
# Disp:308.230229.
# Best-fitting redshift z: 0.033894005040863595
#
# ####################
#
# 1.4026374335023277
#  Best Fit:       Vel     sigma
#  comp.  0:      -309       284
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 10
# Vel :-308.986564.
# Disp:283.711361.
# Best-fitting redshift z: 0.03393325837573702
#
# ####################
#
# 1.3776807625536065
#  Best Fit:       Vel     sigma
#  comp.  0:      -296       271
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 18 11
# Vel :-296.310410.
# Disp:270.806730.
# Best-fitting redshift z: 0.033977021381643935
#
# ####################
#
# 1.3693798426205146
#  Best Fit:       Vel     sigma
#  comp.  0:      -300       305
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 12
# Vel :-300.216164.
# Disp:304.583913.
# Best-fitting redshift z: 0.03396353720222578
#
# ####################
#
# 1.3380876695896597
#  Best Fit:       Vel     sigma
#  comp.  0:      -348       281
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 13
# Vel :-348.070174.
# Disp:280.761811.
# Best-fitting redshift z: 0.03379832657532478
#
# ####################
#
# 1.4370079940251588
#  Best Fit:       Vel     sigma
#  comp.  0:      -340       243
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 18 14
# Vel :-339.662147.
# Disp:243.189450.
# Best-fitting redshift z: 0.03382735434784556
#
# ####################
#
# 1.20460349832795
#  Best Fit:       Vel     sigma
#  comp.  0:      -383       294
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  13 / 1273
# 18 15
# Vel :-383.046531.
# Disp:294.224159.
# Best-fitting redshift z: 0.0336775746042528
#
# ####################
#
# 1.384674611906148
#  Best Fit:       Vel     sigma
#  comp.  0:      -314       255
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 16
# Vel :-313.651843.
# Disp:255.255015.
# Best-fitting redshift z: 0.03391715201964218
#
# ####################
#
# 1.1945901341557152
#  Best Fit:       Vel     sigma
#  comp.  0:      -264       295
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 17
# Vel :-264.490526.
# Disp:295.460588.
# Best-fitting redshift z: 0.034086875981469644
#
# ####################
#
# 1.4216323687427375
#  Best Fit:       Vel     sigma
#  comp.  0:      -214       333
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 18
# Vel :-213.767885.
# Disp:332.583496.
# Best-fitting redshift z: 0.0342619902369079
#
# ####################
#
# 1.3654041452231558
#  Best Fit:       Vel     sigma
#  comp.  0:      -298       233
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18 19
# Vel :-298.288008.
# Disp:232.753200.
# Best-fitting redshift z: 0.03397019394509826
#
# ####################
#
# 1.644577118611428
#  Best Fit:       Vel     sigma
#  comp.  0:      -305       230
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  20 / 1273
# 19 0
# Vel :-305.038605.
# Disp:230.251036.
# Best-fitting redshift z: 0.03394688826243408
#
# ####################
#
# 1.468117369918134
#  Best Fit:       Vel     sigma
#  comp.  0:      -366       235
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 19 1
# Vel :-366.320980.
# Disp:234.503607.
# Best-fitting redshift z: 0.03373531770246996
#
# ####################
#
# 1.4770425849905653
#  Best Fit:       Vel     sigma
#  comp.  0:      -293       345
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 2
# Vel :-292.766243.
# Disp:345.023101.
# Best-fitting redshift z: 0.03398925722142265
#
# ####################
#
# 1.5334200419039015
#  Best Fit:       Vel     sigma
#  comp.  0:      -349       236
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 3
# Vel :-348.526922.
# Disp:235.623409.
# Best-fitting redshift z: 0.0337967497040883
#
# ####################
#
# 1.3145302233507388
#  Best Fit:       Vel     sigma
#  comp.  0:      -350       262
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 4
# Vel :-349.563119.
# Disp:261.900783.
# Best-fitting redshift z: 0.03379317234711032
#
# ####################
#
# 1.4352706694219366
#  Best Fit:       Vel     sigma
#  comp.  0:      -369       298
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  16 / 1273
# 19 5
# Vel :-368.820053.
# Disp:297.606617.
# Best-fitting redshift z: 0.033726689931401266
#
# ####################
#
# 1.3541750501000172
#  Best Fit:       Vel     sigma
#  comp.  0:      -328       252
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 6
# Vel :-328.374389.
# Disp:251.795659.
# Best-fitting redshift z: 0.033866324074415255
#
# ####################
#
# 1.3158576318804553
#  Best Fit:       Vel     sigma
#  comp.  0:      -360       294
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 7
# Vel :-359.975330.
# Disp:293.775546.
# Best-fitting redshift z: 0.03375722535223846
#
# ####################
#
# 1.5300470312662842
#  Best Fit:       Vel     sigma
#  comp.  0:      -258       314
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 8
# Vel :-258.385564.
# Disp:313.794970.
# Best-fitting redshift z: 0.03410795267838096
#
# ####################
#
# 1.6639853678881247
#  Best Fit:       Vel     sigma
#  comp.  0:      -323       212
# chi2/DOF: 1
# method = capfit; Jac calls: 7; Func calls: 25; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 9
# Vel :-322.866006.
# Disp:211.550314.
# Best-fitting redshift z: 0.03388534114951769
#
# ####################
#
# 1.6281565745463142
#  Best Fit:       Vel     sigma
#  comp.  0:      -272       280
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 19 10
# Vel :-271.864890.
# Disp:280.080427.
# Best-fitting redshift z: 0.03406141681257324
#
# ####################
#
# 1.443873042008896
#  Best Fit:       Vel     sigma
#  comp.  0:      -330       266
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 11
# Vel :-329.985438.
# Disp:265.732927.
# Best-fitting redshift z: 0.03386076210757749
#
# ####################
#
# 1.3648265618301896
#  Best Fit:       Vel     sigma
#  comp.  0:      -287       245
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 21; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 12
# Vel :-286.849478.
# Disp:244.527968.
# Best-fitting redshift z: 0.034009684194999945
#
# ####################
#
# 1.4998451770616847
#  Best Fit:       Vel     sigma
#  comp.  0:      -305       258
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 19 13
# Vel :-304.556508.
# Disp:257.969901.
# Best-fitting redshift z: 0.03394855264902841
#
# ####################
#
# 1.4226949254820156
#  Best Fit:       Vel     sigma
#  comp.  0:      -264       300
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 19 14
# Vel :-263.987790.
# Disp:299.967205.
# Best-fitting redshift z: 0.034088611618257714
#
# ####################
#
# 1.5086129812624685
#  Best Fit:       Vel     sigma
#  comp.  0:      -304       231
# chi2/DOF: 1
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 15
# Vel :-304.192821.
# Disp:230.527759.
# Best-fitting redshift z: 0.03394980823874594
#
# ####################
#
# 1.6583163961973315
#  Best Fit:       Vel     sigma
#  comp.  0:      -300       273
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 16
# Vel :-300.197476.
# Disp:272.947959.
# Best-fitting redshift z: 0.03396360171975532
#
# ####################
#
# 1.4773959817112026
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       253
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 19 17
# Vel :-321.900989.
# Disp:252.680901.
# Best-fitting redshift z: 0.033888672762880434
#
# ####################
#
# 1.2390176589471718
#  Best Fit:       Vel     sigma
#  comp.  0:      -258       251
# chi2/DOF: 1
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  11 / 1273
# 19 18
# Vel :-258.425531.
# Disp:250.777651.
# Best-fitting redshift z: 0.034107814699542605
#
# ####################
#
# 1.5888711310241839
#  Best Fit:       Vel     sigma
#  comp.  0:      -290       271
# chi2/DOF: 1
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  14 / 1273
# 19 19
# Vel :-289.963486.
# Disp:271.081614.
# Best-fitting redshift z: 0.03399893343036786
#
# ####################

# %%
np.savetxt('Output_Ppxf with chi2.txt',table, header= 'y_px x_px vel(km/s) disp(km/s) chi2/DOF 1-sigma', fmt='%i %i %.18e %.18e %.18e %.18e',delimiter=' ')
