# %%
import time
import os

os.environ["OMP_NUM_THREADS"] = "1"


import numpy as np
import matplotlib.pyplot as plt
from plotbin.plot_velfield import plot_velfield
from plotbin.symmetrize_velfield import symmetrize_velfield
from My_Jampy import JAM                          #My class for jampy


from astropy.cosmology import Planck15 as cosmo
from astropy.cosmology import z_at_value
import astropy.units as u

from schwimmbad import MPIPool, MultiPool

boundary = {"ml": [0.5, 15], "qinc": [0.051, 0.468808], "beta": [-3, 3],
                "log_mbh": [7, 11], "kappa_s": [0, 1], "qDM":[0.1, 1]}

# %%
class Model(object):
    def __init__(self, Jam_model):
        self.Jam_model = Jam_model

    def prior_transform(self, theta):
        ml, qinc, beta, log_mbh, kappa_s, qDM = theta
        parsDic = {"ml":ml, "qinc":qinc, "beta":beta, "log_mbh":log_mbh, "kappa_s":kappa_s, "qDM":qDM }
        for key in parsDic:
            parsDic[key] = boundary[key][0] + parsDic[key]*(boundary[key][1] - boundary[key][0])
        
        return np.array(list(parsDic.values()))

    def log_likelihood(self, theta):
        ml, qinc, beta, log_mbh, kappa_s, qDM = theta    
        # Sample inclination using min(q), with Equation (14) of Cappellari (2008)
        qmin = np.min(self.Jam_model.qobs_lum)
        inc_model = np.degrees(np.arctan(np.sqrt((1 - qmin**2)/(qmin**2 -qinc**2))))
        
        surf_dm_model = (kappa_s) * self.Jam_model.surf_dm
        qdm_proj      = np.sqrt( (np.sin(np.radians(inc_model)) * qDM )**2  + np.cos( np.radians(inc_model))**2     )     #Projected DM axial ratio
        qDM_model     = np.ones_like(self.Jam_model.qobs_dm)*qdm_proj

        beta_model  = np.ones_like(self.Jam_model.surf_lum)*beta
        ml_model    = ml
        mbh_model   = 10**log_mbh
        
        self.Jam_model.upt(surf_dm=surf_dm_model, qobs_dm=qDM_model, inc=inc_model,
                            ml=ml_model, beta=beta_model, mbh=mbh_model)
        
        rmsModel, ml, chi2, chi2T = self.Jam_model.run(quiet=True, plot=False)
        
        
        return -0.5 * chi2T

    def __call__(self, pars):
        return self.log_likelihood(pars)

def resume_dlogz(sampler):
        results = sampler.results
        logz_remain = np.max(sampler.live_logl) + results.logvol[-1]
        delta_logz = np.logaddexp(results.logz[-1], logz_remain) - results.logz[-1]
        
        return delta_logz

# %%
# Reading Data
x, y, vrms, erms              = np.loadtxt("Input/Vrms_map_rot_BadAss_boots.txt", unpack=True)          #vrms data
surf_lum, sigma_lum, qobs_lum = np.loadtxt("Input/JAM_Input.txt", unpack=True)              #MGE decomposition
surf_dm, sigma_dm , qobs_dm   = np.loadtxt("Input/eNFW.txt", unpack=True)                   #DM component
norm_psf, sigma_psf           = np.loadtxt("Input/MUSE_Psf_model.txt", unpack=True)         #PSF

# Defing some inputs
z_l     = 0.299                                                         #Redshift
D_l     = cosmo.angular_diameter_distance(z_l).value                    #Distance to Lens [Mpc] 
mbh     = 1e9                                                           #mass of black hole [log10(M_sun)]
beta    = np.full_like(surf_lum, -0.15)                                 #anisotropy [ad]
inc     = 65                                                            #inclination [deg]
kappa_s = 0.075                                                         #kappa_s of DM profile
ml      = 7.00                                                          #mass to light ratio
inc_rad = np.radians(inc)
qinc    = np.sqrt(np.min(qobs_lum)**2 - 
                        (1 - np.min(qobs_lum)**2)/np.tan(inc_rad)**2)   #Deprojected axial ratio for inclination
qDM     = np.sqrt( qobs_dm[0]**2 - np.cos(inc_rad)**2)/np.sin(inc_rad)  #Deprojected DM axial ratio

pixsize = 0.2    #MUSE pixel size

# Now we start our Jampy class
Jam_model = JAM(ybin=y*pixsize, xbin=x*pixsize, inc=inc, distance=D_l, mbh=mbh, beta=beta, rms=vrms, erms=erms,
                normpsf=norm_psf, sigmapsf=sigma_psf*pixsize, pixsize=pixsize)

#Add Luminosity component
Jam_model.luminosity_component(surf_lum=surf_lum, sigma_lum=sigma_lum,
                                    qobs_lum=qobs_lum, ml=ml)
#Add DM component
Jam_model.DM_component(surf_dm=kappa_s * surf_dm, sigma_dm=sigma_dm, qobs_dm=qobs_dm)

model = Model(Jam_model=Jam_model)

print("Testing Inputs...")
p0 = np.array([ml, qinc, beta[0], np.log10(mbh), kappa_s, qDM])
chi2 = model(p0)
print("Likelihood Value:", chi2)

from dynesty import NestedSampler
import _pickle  as pickle
import time
# Out:
# Testing Inputs...
# Likelihood Value: -3474.4535911685907

# %%
with open(f'dynesty_jam.pickle','rb') as f:
    sample_load = pickle.load(f)

# %%
plt.plot(sample_load.results.scale)
sample_load.results.scale[-1]
# Out:
# 0.029555818774823436

# %%
results = sample_load.results
results.summary()
# Out:
# Summary
# =======
# nlive: 150
# niter: 2159
# ncall: 26077
# eff(%):  8.232
# logz: -581.913 +/-  0.454

# %%
sample_load.results.keys()
# Out:
# dict_keys(['nlive', 'niter', 'ncall', 'eff', 'samples', 'samples_id', 'samples_it', 'samples_u', 'logwt', 'logl', 'logvol', 'logz', 'logzerr', 'information', 'bound', 'bound_iter', 'samples_bound', 'scale'])

# %%
plt.plot(sample_load.results.bound_iter)

# %%
plt.plot(sample_load.results.ncall)

# %%
plt.plot(sample_load.results.samples)
# Out:
# [<matplotlib.lines.Line2D at 0x7f5b1e79a210>,
#  <matplotlib.lines.Line2D at 0x7f5b1e79a410>,
#  <matplotlib.lines.Line2D at 0x7f5b1e79a5d0>,
#  <matplotlib.lines.Line2D at 0x7f5b1e79a790>,
#  <matplotlib.lines.Line2D at 0x7f5b1e79a950>,
#  <matplotlib.lines.Line2D at 0x7f5b1e79ab10>,
#  <matplotlib.lines.Line2D at 0x7f5b1e79ad50>,
#  <matplotlib.lines.Line2D at 0x7f5b1e79af10>,
#  <matplotlib.lines.Line2D at 0x7f5b1e79a910>,
#  <matplotlib.lines.Line2D at 0x7f5b1e79ab50>,
#  <matplotlib.lines.Line2D at 0x7f5b1e7e8d50>,
#  <matplotlib.lines.Line2D at 0x7f5b1e7a0590>,
#  <matplotlib.lines.Line2D at 0x7f5b1e7a0750>,
#  <matplotlib.lines.Line2D at 0x7f5b1e7a0910>]

# %%
resume_dlogz(sample_load)
# Out:
# 50.26865382572589

# %%
sample_load.results.summary()
# Out:
# Summary
# =======
# nlive: 150
# niter: 1759
# ncall: 21567
# eff(%):  8.100
# logz: -612.891 +/-  0.425

# %%
from dynesty import plotting as dyplot
from dynesty import utils as dyfunc

sample_load.sampling
sample_load.add_final_live()
# Out:
# iter: 2159 | +150 | bound: 85 | nc: 1 | ncall: 26227 | eff(%):  8.804 | loglstar:   -inf < -539.597 <    inf | logz: -559.053 +/-  0.840 | dlogz:  0.741 >  0.010

# %%
fig, axes = dyplot.runplot(sample_load.results)

# %%
# Generate a new set of results with statistical+sampling uncertainties.
results_sim = sample_load.results


samples_sim = results_sim.samples
weights = np.exp(results_sim.logwt - results_sim.logz[-1])  # normalized weights
mean, cov = dyfunc.mean_and_cov(samples_sim, weights)
mean, cov
# Out:
# (array([ 4.5167475 ,  0.27243193,  0.39552674, -2.3487757 , -1.96033669,
#          0.41337774, -0.59108344, -0.88087707,  1.12409723,  0.26082002,
#          0.84680774,  8.43392981,  0.38477099,  0.89686989]),
#  array([[ 1.11723817e-03, -1.75930621e-04, -4.93788146e-03,
#          -4.96786526e-03, -1.95031748e-02, -2.86204091e-04,
#          -6.45362453e-03,  1.31339521e-02, -2.14094576e-04,
#          -1.43908238e-02, -2.38659101e-04,  4.87234348e-03,
#           3.92048736e-05,  4.53204576e-04],
#         [-1.75930621e-04,  8.01254607e-04,  9.67007775e-03,
#           8.94515714e-03,  2.67425680e-02,  3.64742506e-04,
#           1.49463560e-03, -2.63438990e-02,  6.40422760e-04,
#           2.14218330e-02,  2.90079350e-04, -4.30517665e-03,
#           2.44600084e-03, -1.70999774e-03],
#         [-4.93788146e-03,  9.67007775e-03,  1.24130243e-01,
#           1.15825860e-01,  3.58342177e-01,  4.91736032e-03,
#           3.40689694e-02, -3.37192403e-01,  7.92283004e-03,
#           2.83746637e-01,  3.95592328e-03, -6.22295061e-02,
#           2.80336325e-02, -2.08326706e-02],
#         [-4.96786526e-03,  8.94515714e-03,  1.15825860e-01,
#           1.08252957e-01,  3.36574484e-01,  4.63377269e-03,
#           3.37477862e-02, -3.14621081e-01,  7.35620884e-03,
#           2.66156254e-01,  3.72570318e-03, -5.90067739e-02,
#           2.57074790e-02, -1.93097024e-02],
#         [-1.95031748e-02,  2.67425680e-02,  3.58342177e-01,
#           3.36574484e-01,  1.06509408e+00,  1.47451634e-02,
#           1.27227080e-01, -9.72276793e-01,  2.23098433e-02,
#           8.37634698e-01,  1.18955779e-02, -1.93328012e-01,
#           7.43544269e-02, -5.80807274e-02],
#         [-2.86204091e-04,  3.64742506e-04,  4.91736032e-03,
#           4.63377269e-03,  1.47451634e-02,  2.22463247e-04,
#           1.85387974e-03, -1.33501506e-02,  3.03763098e-04,
#           1.16072479e-02,  1.65713508e-04, -2.69980827e-03,
#           9.95378127e-04, -7.93115799e-04],
#         [-6.45362453e-03,  1.49463560e-03,  3.40689694e-02,
#           3.37477862e-02,  1.27227080e-01,  1.85387974e-03,
#           3.76480025e-02, -9.08579884e-02,  1.61027993e-03,
#           9.48679179e-02,  1.53281665e-03, -3.03469964e-02,
#           1.29609233e-03, -3.61752568e-03],
#         [ 1.31339521e-02, -2.63438990e-02, -3.37192403e-01,
#          -3.14621081e-01, -9.72276793e-01, -1.33501506e-02,
#          -9.08579884e-02,  9.16396404e-01, -2.15628872e-02,
#          -7.70351374e-01, -1.07294844e-02,  1.68329491e-01,
#          -7.65172750e-02,  5.67572399e-02],
#         [-2.14094576e-04,  6.40422760e-04,  7.92283004e-03,
#           7.35620884e-03,  2.23098433e-02,  3.03763098e-04,
#           1.61027993e-03, -2.15628872e-02,  5.17195995e-04,
#           1.77847418e-02,  2.43795241e-04, -3.70924778e-03,
#           1.91648283e-03, -1.37251028e-03],
#         [-1.43908238e-02,  2.14218330e-02,  2.83746637e-01,
#           2.66156254e-01,  8.37634698e-01,  1.16072479e-02,
#           9.48679179e-02, -7.70351374e-01,  1.77847418e-02,
#           6.60052309e-01,  9.33136887e-03, -1.50349934e-01,
#           6.01927550e-02, -4.64497827e-02],
#         [-2.38659101e-04,  2.90079350e-04,  3.95592328e-03,
#           3.72570318e-03,  1.18955779e-02,  1.65713508e-04,
#           1.53281665e-03, -1.07294844e-02,  2.43795241e-04,
#           9.33136887e-03,  1.33474524e-04, -2.19514248e-03,
#           7.91602889e-04, -6.32184082e-04],
#         [ 4.87234348e-03, -4.30517665e-03, -6.22295061e-02,
#          -5.90067739e-02, -1.93328012e-01, -2.69980827e-03,
#          -3.03469964e-02,  1.68329491e-01, -3.70924778e-03,
#          -1.50349934e-01, -2.19514248e-03,  3.74411733e-02,
#          -1.10499037e-02,  9.46819080e-03],
#         [ 3.92048736e-05,  2.44600084e-03,  2.80336325e-02,
#           2.57074790e-02,  7.43544269e-02,  9.95378127e-04,
#           1.29609233e-03, -7.65172750e-02,  1.91648283e-03,
#           6.01927550e-02,  7.91602889e-04, -1.10499037e-02,
#           7.78099545e-03, -5.17631276e-03],
#         [ 4.53204576e-04, -1.70999774e-03, -2.08326706e-02,
#          -1.93097024e-02, -5.80807274e-02, -7.93115799e-04,
#          -3.61752568e-03,  5.67572399e-02, -1.37251028e-03,
#          -4.64497827e-02, -6.32184082e-04,  9.46819080e-03,
#          -5.17631276e-03,  3.65888347e-03]]))

# %%
labels = ["ml", "qInc", "beta","beta","beta","beta","beta","beta","beta","beta","beta", "log_mbh",
                    "kappa_s", "qDM"]
cfig, caxes = dyplot.cornerplot(results_sim,show_titles=True,labels=labels,
                               )

# %%
rfig, raxes = dyplot.traceplot(results_sim, labels=labels,
                               show_titles=True, connect=True, )
plt.tight_layout()

# %%
 model(mean)
plt.tight_layout()

# %%
vrmsModel, a, b, c = Jam_model.run(plot=True, quiet=False)
plt.tight_layout()
# Out:
# jam_axi_rms elapsed time sec: 1.86
# inc=66.6 beta_z=0.40 M/L=1 BH=2.72e+08 chi2/DOF=4.02
# Total mass MGE: 4.157e+11

# %%
sym = symmetrize_velfield(xbin=x,ybin=y,vel_bin=vrms,sym=2)

# %%
plot_velfield(x=x*pixsize, y=y*pixsize, vel=vrms, colorbar=True)

# %%
plot_velfield(x=x*pixsize, y=y*pixsize, vel=sym, colorbar=True)

# %%
plot_velfield(x=x*pixsize, y=y*pixsize, vel=vrmsModel, vmax=252, vmin=216,colorbar=True)

# %%
plot_velfield(x=x*pixsize, y=y*pixsize, vel=100*abs(vrmsModel-vrms)/vrms, colorbar=True, )

# %%
from dynesty import NestedSampler
from multiprocessing import Pool

# %%
with open(f'dynesty_jam.pickle','rb') as f:
    sample_load = pickle.load(f)

# %%
sample_load.pool =Pool()
sample_load.M   = Pool().map
sample_load.rstate = np.random
sample_load.loglikelihood = model.log_likelihood
# Out:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-33:
# Traceback (most recent call last):
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-38:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-41:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-45:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-46:
# Traceback (most recent call last):
# Process ForkPoolWorker-47:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/carlos/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
sample_load.run_nested(maxiter=1000)
# Out:
# 893it [52:45,  3.55s/it, +40 | bound: 183 | nc: 1 | ncall: 13009 | eff(%):  7.172 | loglstar:   -inf < -826.602 <    inf | logz: -845.625 +/-  0.871 | dlogz:  0.001 >  0.049]

# %%
sample_load.results.summary()
# Out:
# Summary
# =======
# nlive: 40
# niter: 893
# ncall: 13009
# eff(%):  7.172
# logz: -845.625 +/-  0.871

# %%
results_sim = sample_load.results


samples_sim = results_sim.samples
weights = np.exp(results_sim.logwt - results_sim.logz[-1])  # normalized weights
mean, cov = dyfunc.mean_and_cov(samples_sim, weights)
mean, cov
# Out:
# (array([ 5.2519847 ,  0.45903915, -0.30871636,  7.42114437,  0.95173246,
#          0.91376842]),
#  array([[ 5.62200960e-04,  6.16920284e-06, -1.79436094e-04,
#          -3.70166928e-05, -2.97564350e-05, -2.50912368e-04],
#         [ 6.16920284e-06,  8.98925589e-05,  1.09868107e-05,
#           3.69846693e-04,  9.24924999e-06,  2.72646344e-05],
#         [-1.79436094e-04,  1.09868107e-05,  7.49873288e-04,
#          -5.70951589e-04, -2.27923772e-05,  2.36271878e-04],
#         [-3.70166928e-05,  3.69846693e-04, -5.70951589e-04,
#           8.01429923e-02,  1.28183445e-04, -2.44191230e-04],
#         [-2.97564350e-05,  9.24924999e-06, -2.27923772e-05,
#           1.28183445e-04,  2.23741094e-03,  2.50615971e-04],
#         [-2.50912368e-04,  2.72646344e-05,  2.36271878e-04,
#          -2.44191230e-04,  2.50615971e-04,  5.25962707e-03]]))

# %%
sample_load.results.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/dynesty/results.py in __getattr__(self, name)
#     180         try:
# --> 181             return self[name]
#     182         except KeyError:
#
# KeyError: 'nell'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-270b5ec8b020> in <module>
# ----> 1 sample_load.results.nell
#
# ~/anaconda3/lib/python3.7/site-packages/dynesty/results.py in __getattr__(self, name)
#     181             return self[name]
#     182         except KeyError:
# --> 183             raise AttributeError(name)
#     184
#     185     __setattr__ = dict.__setitem__
#
# AttributeError: nell

# %%
Jam_model.upt(beta=beta)

# %%
vrms, a, b ,c = Jam_model.run(plot=True, quiet=False)
# Out:
# jam_axi_rms elapsed time sec: 0.59
# inc=83.8 beta_z=-0.30 M/L=1 BH=2.64e+07 chi2/DOF=8.28
# Total mass MGE: 3.294e+12

# %%
mean
# Out:
# array([ 5.2519847 ,  0.45903915, -0.30871636,  7.42114437,  0.95173246,
#         0.91376842])

# %%
sigma_lum
# Out:
# array([0.04569 , 0.13247 , 0.263819, 0.554257, 0.691878, 1.070566,
#        1.479681, 2.651813, 2.651813])
