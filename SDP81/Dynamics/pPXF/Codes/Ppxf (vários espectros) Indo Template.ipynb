# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 05/27/2020
#
# Obj: Perform the modeling of spectrum based on pPXF method by Cappellari,and obtein the kinematics./Realizar o modelamento de espectros baeado no código pPXF de Cappellari, e obter a cinemática.

# %%
import glob
from os import path

from astropy.io import fits
from scipy import ndimage
import numpy as np

import ppxf as ppxf_package
from ppxf.ppxf import ppxf
import ppxf.ppxf_util as util

import matplotlib.pyplot as plt

# %%
ppxf_dir = '/home/carlos/Desktop/ppxf' #Directory of stellar library/Diretória da biblioteca estelar


stellar_lib = '/home/carlos/Downloads/Bibliotecas Estelares/BINTABLE'
stellar_G = '/home/carlos/Downloads/Bibliotecas Estelares/G'
Indo = glob.glob(stellar_lib + '/*.fits')
FWHM_tem = 1.35


for i in range(48):
     #READING THE SPECTRUM/LENDO UM ESPECTRO
    file = ('/home/carlos/Desktop/SDP/Dynamics/pPXF/BinSpec/Bin%d.fits'%i) #Path and name of the spectrum/Caminho e nome do arquivo do espectro
    hdu = fits.open(file) #Opening the .fits file/Abrindo o arquivo.fits
    gal_lin = hdu[1].data #Read the data/Lendo os dados
    h1 = hdu[1].header    #Read the header/Lendo o header dos dados
    
    #READING THE VARIANCE/LENDO A VARIÂNCIA DO ESPECTRO
    var = hdu[2].data     #Read the variance/Lendo a variância
    h_var = hdu[2].header #Read the variance header/Lendo o header da variância
    
    #LOG-REBIN THE SPECTRUM AND VARIANCE/LOGARITMIZANDO O ESPECTRO E A VARIÂNCIA
        #SPECTRUM/ESPECTRO
    FWHM_gal = 2.71  #FWHM of telescope in Angstrons/FWHM do telescópio em Angstrons
    lambRange1 = h1['CRVAL1'] + np.array([0.,h1['CDELT1']*(h1['NAXIS1']-1)]) #Generating the wavelengths/Está linha gera os comprimentos de onda
                                #pois a variável gal_lin armazena em um array apenas as intensidades, mas não os comprimentos de onda
        
    #De-redshift
    z = 0.299 # Initial estimate of the galaxy redshift
    lambRange1 = lambRange1/(1+z) # Compute approximate restframe wavelength range
    FWHM_gal = FWHM_gal/(1+z)   # Adjust resolution in Angstrom
    #Depois do passo acima, a galáxia passa a estar no restframe, logo é preeciso setar
    z = 0.
    
    
    galaxy, logLam1, velscale = util.log_rebin(lambRange1, gal_lin) #Log-rebin the spectrum/Logaritimizando o espectro da galáxia
    median_galaxy = np.median(galaxy) #Mean of spectrum for normalization/Média do espectro, pois vamos normalizá-lo pela média
    galaxy = galaxy/median_galaxy        #Normalizing the spectrum/Normalizando o espectro pela média
    lam = np.exp(logLam1)                #Recovering the wavelength in Ansgstrons/Recuperando o comprimento de onda em unidades do SI
        
    #VARIANCE/VARIÂNCIA
    lamRange_var = h_var['CRVAL1'] + np.array([0.,h_var['CDELT1']*(h_var['NAXIS1']-1)])
    erro = np.sqrt(var) #1-sigma error from variance/1-sigma erro da variância
    erro, loglam_var, velscale_var = util.log_rebin(lamRange_var, erro)
    noise = erro/median_galaxy         #Normalizing the error/Normalizando o erro        
        
    #READING ONE TEMPLATE FOR DETERMINE THE LENGHT/LENDO UM TEMPLATE PARA SABER O TAMANHO DO VETOR FINAL
        #The ideia is make a empty array to after complete with the informations about the templates of the stellar libary/
                    #A ideia é crirar um array vazio para que mais tarde seja preenchido com as informações de todos os templetes.

    
    
    
    velscale_ratio = 2
    hdu = fits.open(Indo[0])
    data = hdu[1].data
    ssp = data[0][1]
    h2 = hdu[0].header
    
    #Log_rebin TEMPLATE/LOGARITMIZANDO O TEMPLATE
    lamRange2 = np.array([data[0][0][0], data[0][0][len(data[0][0]) - 1]]) 
    sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
    templates = np.empty((sspNew.size, len(Indo)))  #Array com o tamanho necessário

    #FINAL FWHM FOR GALAXY AND TEMPLATE CONVOLUTION/CALCULANDO A FWHM FINAL PARA REALIZAR A CONVOLUÇÃO DO TEMPLATE E GALÁXIA
    FWHM_dif = np.sqrt(FWHM_gal**2 - FWHM_tem**2)
    sigma = FWHM_dif/2.355/0.4 #New sigma PSF/Novo sigma da PSF.
    
    #READING ALL TEMPLATES/LENDO TODOS OS TEMPLATES E JÁ LOGARITMIZANDO
    for j, file in enumerate(Indo):
        hdu = fits.open(file)
        data = hdu[1].data
        ssp = data[0][1]
        ssp = ndimage.gaussian_filter1d(ssp, sigma) #Realizando a convolução
        sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
        templates[:, j] = sspNew/np.median(sspNew)
    
    

    #ADICIONANDO UM SHIFT PARA COINCIDIR OS COMPRIMENTOS DE ONDA DO ESPECTRO E DO TEMPLATE
        #Artificial shift for the galaxy and templates wavelenght may coincide.    
        #Nem sempre os comprimentos de onda do templete e do espectro coincidem, por esse motivo é dado um 
        #shift artificial ao templete, mas que após o ajuste é retirado.
    c = 299792.458 #Speed of light/Velocidade da Luz
    dv = (np.mean(logLam2[:velscale_ratio]) - logLam1[0])*c #Shift
    goodPixels = util.determine_goodpixels(logLam1, lamRange2, z)  #Mask bad emission lines/Máscaras para linhas de emissão
    vel = c*np.log(1 + z)
    start = [vel, 200.] #Inicial guess/Chute inicial
    
    #START OF FIT/INÍCIO DO AJUSTE
       #For each spectrum the modeling is done. After the best solution is printed 
       #(velocity, velocity dispersion, another moments). Then, a table is write with the information about the
       #pixel position, velocity, velocity dispersion, chi²/DOF and 1-sigma error. The table is saved with name
       #'Output_Ppxf.txt'.  
        
       #Para cada espectro ele realiza o ajuste e printa abaixo o nome do px em que foi realizado o ajuste,
       #bem como as infomações do melhor ajuste (qui², Velocidade, Dispersão, Demais momentos). Então cria uma
       #tabela com as informações necessárias e a salva com o nome 'Output_Ppxf.txt'.
    pp = ppxf(templates, galaxy, noise, velscale, start,
                lam = lam, plot=False, moments=2,
                  degree=6,vsyst=dv, goodpixels=goodPixels, velscale_ratio=velscale_ratio)
        #For more informations about the method, visit the paper of Cappellari avaible in README
        #Para mais informações sobre o método, visite o paper de Cappellari disponível no README
        
        #Plot and save the best model/Plota e salva o melhor modelo
    pp.plot() #Plot the fit/Plota o fit
    plt.savefig('/home/carlos/Desktop/SDP/Dynamics/pPXF/Indo_SpecFit/Bin%d.png'%i,format='png', dpi=600)
    plt.clf()
    print(i)
    print('Vel :%f.\nDisp:%f.'%(pp.sol[0],pp.sol[1]))
    print('Best-fitting redshift z:', (0.299 + 1)*(1 + pp.sol[0]/c) - 1)
    error = pp.error*np.sqrt(pp.chi2) #Formal Error. dV = error[0], dsigma = error[1]
    #ESCREVENDO UMA TABELA COM OS DADOS DE Bin  VELOCIDADE(KM/S) DISPERSÃO(KM/S) chi2 dV dsigma
    newrow = [np.int(i), pp.sol[0], pp.sol[1], pp.chi2, error[0], error[1]]
    if i == 0:
        table = np.array([np.int(i), pp.sol[0], pp.sol[1],pp.chi2, error[0], error[1]])
    else:
        table = np.vstack([table,newrow])
    print('\n####################\n')
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:       162       238
# chi2/DOF: 0.8888
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 0
# Vel :162.121314.
# Disp:237.609925.
# Best-fitting redshift z: 0.2997024712642731
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       150       245
# chi2/DOF: 0.9333
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  25 / 1273
# 1
# Vel :149.545349.
# Disp:244.959577.
# Best-fitting redshift z: 0.29964797963852385
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       134       233
# chi2/DOF: 0.8899
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 2
# Vel :134.368070.
# Disp:232.740526.
# Best-fitting redshift z: 0.2995822165235349
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       153       265
# chi2/DOF: 0.8855
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 3
# Vel :153.127534.
# Disp:264.766829.
# Best-fitting redshift z: 0.29966350123709207
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       152       227
# chi2/DOF: 0.9437
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4
# Vel :151.822766.
# Disp:226.959339.
# Best-fitting redshift z: 0.29965784768211656
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       149       250
# chi2/DOF: 0.8505
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  25 / 1273
# 5
# Vel :148.527890.
# Disp:250.497976.
# Best-fitting redshift z: 0.29964357098995764
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       181       245
# chi2/DOF: 1.085
# method = capfit; Jac calls: 5; Func calls: 21; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  24 / 1273
# 6
# Vel :181.279415.
# Disp:244.855287.
# Best-fitting redshift z: 0.2997854832679858
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       160       225
# chi2/DOF: 1.104
# method = capfit; Jac calls: 4; Func calls: 18; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  22 / 1273
# 7
# Vel :159.889800.
# Disp:225.265067.
# Best-fitting redshift z: 0.2996928021201535
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       153       213
# chi2/DOF: 1.251
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 8
# Vel :152.802858.
# Disp:212.773908.
# Best-fitting redshift z: 0.29966209441752256
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       155       188
# chi2/DOF: 1.138
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  28 / 1273
# 9
# Vel :154.610903.
# Disp:188.175005.
# Best-fitting redshift z: 0.29966992866992026
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       180       207
# chi2/DOF: 1.34
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  25 / 1273
# 10
# Vel :180.162958.
# Disp:207.130938.
# Best-fitting redshift z: 0.29978064566529206
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       154       206
# chi2/DOF: 1.279
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  24 / 1273
# 11
# Vel :154.342670.
# Disp:205.525230.
# Best-fitting redshift z: 0.29966876641721907
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       161       239
# chi2/DOF: 1.086
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 12
# Vel :161.439211.
# Disp:239.160846.
# Best-fitting redshift z: 0.29969951571199993
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       171       196
# chi2/DOF: 1.15
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 13
# Vel :170.587476.
# Disp:195.911443.
# Best-fitting redshift z: 0.2997391551216477
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       160       223
# chi2/DOF: 1.04
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  29 / 1273
# 14
# Vel :159.645549.
# Disp:223.375879.
# Best-fitting redshift z: 0.2996917437783031
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       148       200
# chi2/DOF: 1.262
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 15
# Vel :148.222351.
# Disp:200.281106.
# Best-fitting redshift z: 0.29964224709012766
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       167       228
# chi2/DOF: 1.068
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 16
# Vel :167.012965.
# Disp:228.308505.
# Best-fitting redshift z: 0.29972366677425466
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       163       229
# chi2/DOF: 0.8837
# method = capfit; Jac calls: 6; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 17
# Vel :162.706597.
# Disp:228.821058.
# Best-fitting redshift z: 0.29970500729263394
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       212       210
# chi2/DOF: 1.326
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 18
# Vel :211.526882.
# Disp:209.753188.
# Best-fitting redshift z: 0.2999165454725252
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       140       249
# chi2/DOF: 0.8255
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  22 / 1273
# 19
# Vel :140.043206.
# Disp:248.899684.
# Best-fitting redshift z: 0.2996068068731579
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       146       232
# chi2/DOF: 1.184
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 20
# Vel :146.287611.
# Disp:232.427703.
# Best-fitting redshift z: 0.2996338638652898
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       157       237
# chi2/DOF: 1.004
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 21
# Vel :157.060833.
# Disp:236.686905.
# Best-fitting redshift z: 0.29968054421258694
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       149       252
# chi2/DOF: 0.9882
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  22 / 1273
# 22
# Vel :149.270034.
# Disp:252.310193.
# Best-fitting redshift z: 0.2996467866995849
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       169       226
# chi2/DOF: 0.8856
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  22 / 1273
# 23
# Vel :168.655268.
# Disp:225.749354.
# Best-fitting redshift z: 0.29973078287087307
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       152       223
# chi2/DOF: 0.9211
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  25 / 1273
# 24
# Vel :151.759338.
# Disp:223.288026.
# Best-fitting redshift z: 0.29965757284565253
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       163       249
# chi2/DOF: 0.8819
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 25
# Vel :162.642759.
# Disp:249.103978.
# Best-fitting redshift z: 0.29970473068178083
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       153       238
# chi2/DOF: 1.204
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  20 / 1273
# 26
# Vel :153.240828.
# Disp:238.483469.
# Best-fitting redshift z: 0.29966399213861994
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       174       235
# chi2/DOF: 0.8633
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 27
# Vel :173.540844.
# Disp:235.493846.
# Best-fitting redshift z: 0.2997519520584826
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       158       250
# chi2/DOF: 0.8744
# method = capfit; Jac calls: 5; Func calls: 19; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 28
# Vel :157.899980.
# Disp:249.584271.
# Best-fitting redshift z: 0.2996841802343695
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       159       234
# chi2/DOF: 1.16
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  27 / 1273
# 29
# Vel :159.459008.
# Disp:234.323193.
# Best-fitting redshift z: 0.29969093549627046
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       170       211
# chi2/DOF: 1.103
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  22 / 1273
# 30
# Vel :170.156822.
# Disp:210.792743.
# Best-fitting redshift z: 0.29973728909940034
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       157       226
# chi2/DOF: 0.9073
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 31
# Vel :157.001590.
# Disp:225.875163.
# Best-fitting redshift z: 0.2996802875121991
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       141       234
# chi2/DOF: 0.8957
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 32
# Vel :140.890518.
# Disp:234.146604.
# Best-fitting redshift z: 0.29961047827506304
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       153       232
# chi2/DOF: 0.907
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 33
# Vel :153.397165.
# Disp:231.770741.
# Best-fitting redshift z: 0.2996646695475995
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       149       224
# chi2/DOF: 1.161
# method = capfit; Jac calls: 5; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 34
# Vel :149.497150.
# Disp:224.297870.
# Best-fitting redshift z: 0.29964777079024363
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       162       231
# chi2/DOF: 0.9193
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  19 / 1273
# 35
# Vel :161.895770.
# Disp:230.743010.
# Best-fitting redshift z: 0.2997014939808349
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       160       208
# chi2/DOF: 1.331
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 36
# Vel :160.091207.
# Disp:208.316198.
# Best-fitting redshift z: 0.29969367481646914
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       135       232
# chi2/DOF: 1.054
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 37
# Vel :135.428958.
# Disp:231.694565.
# Best-fitting redshift z: 0.29958681334795845
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       161       216
# chi2/DOF: 1.113
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  23 / 1273
# 38
# Vel :161.177700.
# Disp:216.332999.
# Best-fitting redshift z: 0.2996983825877977
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       176       225
# chi2/DOF: 1.028
# method = capfit; Jac calls: 6; Func calls: 22; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  24 / 1273
# 39
# Vel :175.563610.
# Disp:224.880379.
# Best-fitting redshift z: 0.29976071669980486
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       163       227
# chi2/DOF: 1.26
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 40
# Vel :162.702202.
# Disp:226.820512.
# Best-fitting redshift z: 0.29970498825027403
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       189       217
# chi2/DOF: 1.243
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  22 / 1273
# 41
# Vel :189.273947.
# Disp:217.180934.
# Best-fitting redshift z: 0.29982012355780197
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       133       228
# chi2/DOF: 1.344
# method = capfit; Jac calls: 4; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  20 / 1273
# 42
# Vel :132.732346.
# Disp:228.355422.
# Best-fitting redshift z: 0.29957512893833793
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       160       216
# chi2/DOF: 1.183
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  25 / 1273
# 43
# Vel :160.124767.
# Disp:216.402362.
# Best-fitting redshift z: 0.2996938202315049
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       162       216
# chi2/DOF: 1.346
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  24 / 1273
# 44
# Vel :161.687020.
# Disp:216.064651.
# Best-fitting redshift z: 0.299700589467788
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       141       236
# chi2/DOF: 1.381
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  24 / 1273
# 45
# Vel :140.629168.
# Disp:236.410995.
# Best-fitting redshift z: 0.2996093458464437
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       164       224
# chi2/DOF: 1.317
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  21 / 1273
# 46
# Vel :164.183891.
# Disp:224.447997.
# Best-fitting redshift z: 0.299711408405275
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:       157       212
# chi2/DOF: 1.39
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 47
# Vel :156.847682.
# Disp:211.785972.
# Best-fitting redshift z: 0.2996796206281036
#
# ####################

# %%
np.savetxt('Output_Ppxf_IndoTemplate.txt',table, header= 'Bin vel(km/s) disp(km/s) chi2/DOF dV dsigma', fmt='%i %i %.18e %.18e %.18e %.18e',delimiter=' ')
