# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 09/04/2020
#
# Obj: Create a mask

# %%
import autofit as af
import autolens as al
import autolens.plot as aplt
import scribbler
import numpy as np

# %%
from pyprojroot import here

workspace_path = str(here())
print("Workspace Path: ", workspace_path)
# Out:
# Workspace Path:  /home/carlos/autolens_workspace

# %% [markdown]
# Create the path where the mask will be output,

# %%
dataset_type = "Data"


dataset_path = af.util.create_path(
    path=workspace_path, folders=["SDP81", dataset_type]
)

# %% [markdown]
# First, load the imaging dataset, so that the mask can be plotted over the strong lens image.

# %%
pixel_scales = 0.09

image = al.Array.from_fits(
    file_path=f"{dataset_path}/F160w_img.fits", pixel_scales=pixel_scales, h
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-1d1e5aa8d95d> in <module>
#       2
#       3 image = al.Array.from_fits(
# ----> 4     file_path=f"{dataset_path}/F160w_img.fits", pixel_scales=pixel_scales
#       5 )
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/structures/arrays/arrays.py in from_fits(cls, file_path, hdu, pixel_scales, sub_size, origin, store_in_1d)
#     456             stored in 2D as an ndarray of shape [total_y_pixels, total_x_pixels].
#     457         """
# --> 458         array_2d = array_util.numpy_array_2d_from_fits(file_path=file_path, hdu=hdu)
#     459         return cls.manual_2d(
#     460             array=array_2d,
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/util/array_util.py in numpy_array_2d_from_fits(file_path, hdu)
#     363     """
#     364     hdu_list = fits.open(file_path)
# --> 365     return np.flipud(np.array(hdu_list[hdu].data)).astype("float64")
#     366
#     367
#
# <__array_function__ internals> in flipud(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/twodim_base.py in flipud(m)
#     148     m = asanyarray(m)
#     149     if m.ndim < 1:
# --> 150         raise ValueError("Input must be >= 1-d.")
#     151     return m[::-1, ...]
#     152
#
# ValueError: Input must be >= 1-d.

# %%
#Select and drawn the mask
scribbler = scribbler.Scribbler(image=image.in_2d)

# %%
mask = scribbler.show_mask()

# %%
mask = al.Mask.manual(mask=np.invert(mask), pixel_scales=pixel_scales)

# %%
# %matplotlib inline
aplt.Array(array=image, mask=mask)

# %%
#Save in fits file
mask.output_to_fits(file_path=f"{dataset_path}/mask gui.fits", overwrite=True)

# %% [markdown]
# Now we load the mask and data to see how it works.

# %%
#Reading data

dataset_type = "ESO325"
dataset_name = "Data"
dataset_path = f"{workspace_path}/{dataset_type}/{dataset_name}"

imaging = al.Imaging.from_fits(
    image_path=f"{dataset_path}/arcs_resized.fits",
    noise_map_path=f"{dataset_path}/noise_map_resized.fits",
    psf_path=f"{dataset_path}/psf.fits",
    pixel_scales=0.04,
)

# %%
#Load mask

mask_custom = al.Mask.from_fits(
    file_path=f"{dataset_path}/mask gui.fits", hdu=0, pixel_scales=pixel_scales
)

masked_imaging = al.MaskedImaging(imaging=imaging, mask=mask_custom)

# %%
# %matplotlib inline
#Plot

aplt.Imaging.subplot_imaging(
    imaging=imaging, mask=mask_custom, include=aplt.Include(border=True),
)

# %%
masked_imaging.grid.shape
# Out:
# (4506, 2)
