# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 09/04/2020
#
# Obj: Create a mask

# %%
import autofit as af
import autolens as al
import autolens.plot as aplt
import scribbler
import numpy as np

# %%
from pyprojroot import here

workspace_path = str(here())
print("Workspace Path: ", workspace_path)
# Out:
# Workspace Path:  /home/carlos/Documents/GitHub/Master-Degree

# %% [markdown]
# Create the path where the mask will be output,

# %%
dataset_type = "Autolens/ALMA/Data"


dataset_path = af.util.create_path(
    path=workspace_path, folders=["SDP81", dataset_type]
)

# %%
dataset_path
# Out:
# '/home/carlos/Documents/GitHub/Master-Degree/SDP81/Autolens/ALMA/Data/'

# %% [markdown]
# First, load the imaging dataset, so that the mask can be plotted over the strong lens image.

# %%
pixel_scales = 0.01

image = al.Array.from_fits(hdu=1,
    file_path=f"{dataset_path}/Alma_with_lens_center.fits", pixel_scales=pixel_scales,
)

# %%
#Select and drawn the mask
scribbler = scribbler.Scribbler(image=image.in_2d/3e-6)

# %%
mask = scribbler.show_mask()

# %%
mask = al.Mask.manual(mask=np.invert(mask), pixel_scales=pixel_scales)

# %%
# %matplotlib inline
aplt.Array(array=image, mask=mask)

# %%
#Save in fits file
mask.output_to_fits(file_path=f"{dataset_path}/mask2.fits", overwrite=True)

# %% [markdown]
# Now we load the mask and data to see how it works.

# %%
#Reading data
from os import path


imaging = al.Imaging.from_fits(
    image_path=path.join(dataset_path, "Alma_with_lens_center.fits"),
    noise_map_path=path.join(dataset_path, "rms_noise_map.fits"),
    psf_path=path.join(dataset_path, "Alma_psf_rot.fits"),
    pixel_scales=0.01,
    image_hdu=1, noise_map_hdu=1, psf_hdu=1,
)

# %%
#Load mask

mask_custom = al.Mask.from_fits(
    file_path=f"{dataset_path}/mask2.fits", hdu=0, pixel_scales=pixel_scales
)

masked_imaging = al.MaskedImaging(imaging=imaging, mask=mask_custom)

# %%
# %matplotlib inline
#Plot
positions = al.GridCoordinates(
    coordinates=[[(0.0, 0.0)]]
)
aplt.Imaging.subplot_imaging(
    imaging=imaging, mask=mask_custom, include=aplt.Include(border=False),positions=positions,
)
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/autoarray/dataset/abstract_dataset.py:87: RuntimeWarning: invalid value encountered in less
#   signal_to_noise_map[signal_to_noise_map < 0] = 0

# %%
positions = al.GridCoordinates(
    coordinates=[[(0.0, 0.0)]]
)
aplt.Imaging.image(masked_imaging, positions=positions)

# %%
masked_imaging.grid.shape
# Out:
# (10212, 2)

# %%
masked_imaging.grid.shape
# Out:
# (10212, 2)

# %%
from mpdaf.obj import Image
import numpy as np
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
img   = Image("/home/carlos/Documents/GitHub/Master-Degree/SDP81/Autolens/SDP81/Data/Alma_with_lens_center.fits")
noise = Image("/home/carlos/Documents/GitHub/Master-Degree/SDP81/Autolens/SDP81/Data/rms_noise_map.fits")
# Out:
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'.

# %%
sn_map = img/noise.data.data[0][0]

# %%
# %matplotlib inline
sn_map.plot(colorbar='v')

# %%
mask = (sn_map.data.data > 20) & (sn_map.data.data < 35)

# %%
# %matplotlib inline

new_mask = sn_map * mask
new_mask.plot(colorbar='v')

# %%
new_mask.data.data[np.where(new_mask.data.data != 0)] = 1

# %%
new_mask.write("/home/carlos/Documents/GitHub/Master-Degree/SDP81/Autolens/SDP81/Data/new_mask.fits")

# %% [markdown]
# # Testing new mask

# %%
import autofit as af
import autolens as al
import autolens.plot as aplt
import scribbler
import numpy as np

# %%
dataset_path = "/home/carlos/Documents/GitHub/Master-Degree/SDP81/Autolens/SDP81/Data/"
from os import path

imaging = al.Imaging.from_fits(
    image_path=path.join(dataset_path, "Alma_with_lens_center.fits"),
    noise_map_path=path.join(dataset_path, "rms_noise_map.fits"),
    psf_path=path.join(dataset_path, "Alma_psf_rot.fits"),
    pixel_scales=0.01,
    image_hdu=1, noise_map_hdu=1, psf_hdu=1,
)

# %%
#Load mask

mask_custom = al.Mask.from_fits(
    file_path=f"{dataset_path}/new_mask.fits", hdu=1, pixel_scales=imaging.pixel_scales
)

masked_imaging = al.MaskedImaging(imaging=imaging, mask=mask_custom)
# Out:
# ---------------------------------------------------------------------------
# MaskException                             Traceback (most recent call last)
# <ipython-input-34-365c88666d43> in <module>
#       5 )
#       6
# ----> 7 masked_imaging = al.MaskedImaging(imaging=imaging, mask=mask_custom)
#
# ~/anaconda3/lib/python3.7/site-packages/autolens/dataset/imaging.py in __init__(self, imaging, mask, grid_class, grid_inversion_class, fractional_accuracy, sub_steps, pixel_scales_interp, psf_shape_2d, inversion_pixel_limit, inversion_uses_border, inversion_stochastic, positions_threshold, renormalize_psf, preload_sparse_grids_of_planes)
#      66             inversion_pixel_limit=inversion_pixel_limit,
#      67             inversion_uses_border=inversion_uses_border,
# ---> 68             renormalize_psf=renormalize_psf,
#      69         )
#      70
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/dataset/imaging.py in __init__(self, imaging, mask, grid_class, grid_inversion_class, fractional_accuracy, sub_steps, pixel_scales_interp, psf_shape_2d, inversion_pixel_limit, inversion_uses_border, renormalize_psf)
#     253             )
#     254
# --> 255             self.convolver = convolver.Convolver(mask=mask, kernel=self.psf)
#     256
#     257             if mask.pixel_scales is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/operators/convolver.py in __init__(self, mask, kernel)
#     222
#     223         self.blurring_mask = mask_util.blurring_mask_from(
# --> 224             mask=mask, kernel_shape_2d=kernel.shape_2d
#     225         )
#     226
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/util/mask_util.py in blurring_mask_from()
#     484                         else:
#     485                             raise exc.MaskException(
# --> 486                                 "setup_blurring_mask extends beyond the sub_size "
#     487                                 "of the mask - pad the datas array before masking"
#     488                             )
#
# MaskException: setup_blurring_mask extends beyond the sub_size of the mask - pad the datas array before masking

# %%
#Plot
# %matplotlib inline

aplt.Imaging.subplot_imaging(
    imaging=imaging, mask=mask_custom, include=aplt.Include(border=False),
)

# %%
masked_imaging.grid.shape
# Out:
# (14807, 2)
