# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 12/09/2020
#
# Goal: Create a RMS noise map for the ALMA data after ressample.
# - The value was found using CASA and following the doc Image_analysis2.pdf.
# - We found a value of 3e-05 J/beam.
# - This should be done in resampled ALMA image.

# %%
from mpdaf.obj import Image
from astropy import units as u

# %%
#Open image of ALMA  just for using same grid

grid = Image("/home/carlos/Desktop/HST Data Reduction/Data Alma/Alma_with_lens_center.fits")
#For each px give the value of RMS noise.
grid.data.data[:] = 4.8e-5
grid.info()
# Out:
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# [INFO] 275 x 275 Image (/home/carlos/Desktop/HST Data Reduction/Data Alma/Alma_with_lens_center.fits)
# [INFO] .data(275 x 275) (no unit), no noise
# [INFO] center:(00:39:06.5456,09:03:11.5746) size:(5.500",5.500") step:(0.020",0.020") rot:78.4 deg frame:FK5

# %%
#Save
grid.write("/home/carlos/Desktop/HST Data Reduction/Data Alma/rms_noise_map.fits")
