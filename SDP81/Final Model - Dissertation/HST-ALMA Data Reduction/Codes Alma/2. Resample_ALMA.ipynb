# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 12/09/2020
#
# Goal: Resample ALMA image from 0.005'' to 0.01''.

# %%
from mpdaf.obj import Image
from astropy import units as u

# %%
#Open original image

img = Image("/home/carlos/Desktop/HST Data Reduction/Data Alma/ALMA.fits")
img.info()
img.plot(use_wcs=True, zscale=True,  colorbar='v')
# Out:
# WARNING: MpdafUnitsWarning: No physical unit in the FITS header: missing BUNIT keyword. [mpdaf.obj.data]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# [INFO] 841 x 841 Image (/home/carlos/Desktop/HST Data Reduction/Data Alma/ALMA.fits)
# [INFO] .data(841 x 841) (no unit), no noise
# [INFO] center:(00:39:06.545,09:03:11.5603) size:(4.205",4.205") step:(0.005",0.005") rot:-0.0 deg frame:FK5

# %%
#Resample img

resampled_img = img.resample(newdim=211, newstart=None, newstep=0.02, unit_step=u.arcsec, flux=True)

# %%
resampled_img.info()
resampled_img.plot(use_wcs=True, zscale=True, colorbar='v')
resampled_img.data.data.sum()
# Out:
# [INFO] 211 x 211 Image (no name)
# [INFO] .data(211 x 211) (no unit), no noise
# [INFO] center:(00:39:06.5525,09:03:11.5598) size:(4.220",4.220") step:(0.020",0.020") rot:-0.0 deg frame:FK5
# 4.1054467257723815

# %%
resampled_img.write("/home/carlos/Desktop/HST Data Reduction/Data Alma/ALMA_resampled.fits")
