# %%
#Import important packages

import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from os import path

import mgefit
from mgefit.find_galaxy import find_galaxy
from mgefit.mge_fit_1d import mge_fit_1d
from mgefit.sectors_photometry import sectors_photometry
from mgefit.mge_fit_sectors import mge_fit_sectors
from mgefit.mge_print_contours import mge_print_contours
from mgefit.mge_fit_sectors_twist import mge_fit_sectors_twist
from mgefit.sectors_photometry_twist import sectors_photometry_twist
from mgefit.mge_print_contours_twist import mge_print_contours_twist

from mgefit.mge_fit_sectors import mge_fit_sectors
from mgefit.mge_fit_sectors_twist import mge_fit_sectors_twist

from mgefit.mge_fit_sectors_regularized import mge_fit_sectors_regularized

from mpdaf.obj import Image
data_path = "/home/carlos/Desktop/HST Data Reduction/Data/Centered/"

# %%
def dist_circle(xc, yc, s):
    """
    Returns an array in which the value of each element is its distance from
    a specified center. Useful for masking inside a circular aperture.

    The (xc, yc) coordinates are the ones one can read on the figure axes
    e.g. when plotting the result of my find_galaxy() procedure.

    """
    x, y = np.ogrid[:s[0], :s[1]] - np.array([yc, xc])  # note yc before xc
    rad = np.sqrt(x**2 + y**2)

    return rad

# %%
#Open the file with the psf

file = data_path+'HST_final.fits'
hdu = fits.open(file)               #Abrindo imagem
img = hdu[1].data                   #Pega os dados da img
img_data = hdu[1].data              #Pega os dados da img

where_are_NaNs = np.isnan(img)
img[where_are_NaNs] = 0

# %%
minlevel = 0.4    #counts/px
sky = 0.3         #counts/px
scale = 0.09      #arcsec/pxz
img = img - sky

# %%
#MGE PSF for F160w, after build an ePSF with DAOPHOT

normpsf, sigmapsf = np.loadtxt("Psf_model.txt", unpack=True)

print(normpsf.sum()) # Should total(normpsf)=1
# Out:
# 1.0

# %%
    # Here we use FIND_GALAXY directly inside the procedure. Usually you may want
    # to experiment with different values of the FRACTION keyword, before adopting
    # given values of Eps, Ang, Xc, Yc.
    
plt.clf()
f = find_galaxy(img, fraction=0.1, plot=1)
# Out:
#  Pixels used: 1266
#  Peak Img[j, k]: 58 54
#  Mean (j, k): 57.74 54.16
#  Theta (deg): 78.4
#  Astro PA (deg): 11.6
#  Eps: 0.150
#  Major axis (pix): 22.5

# %%
r = dist_circle(35, 103, img.shape)  # 
mask = r > 5

# %%
# Perform galaxy photometry
plt.clf()
s = sectors_photometry(img, f.eps, f.theta, f.xpeak, f.ypeak,
                           minlevel=0.04, plot=1,mask=mask)

# %%
# Do the actual MGE fit
    # *********************** IMPORTANT ***********************************
    # For the final publication-quality MGE fit one should include the line
    # "from mge_fit_sectors_regularized import mge_fit_sectors_regularized"
    # at the top of this file, rename mge_fit_sectors() into
    # mge_fit_sectors_regularized() and re-run the procedure.
    # See the documentation of mge_fit_sectors_regularized for details.
    # *********************************************************************
plt.clf()
m = mge_fit_sectors_regularized(s.radius, s.angle, s.counts, f.eps,
                       ngauss= 20, sigmapsf=sigmapsf, normpsf=normpsf,
                        scale=scale, plot=1)
# Out:
# Iteration: 1  chi2: 2.85  Nonzero: 8/20
# Iteration: 11  chi2: 0.8926  Nonzero: 9/20
# Iteration: 21  chi2: 0.7687  Nonzero: 11/20
# Iteration: 31  chi2: 0.6259  Nonzero: 8/20
# Iteration: 41  chi2: 0.6145  Nonzero: 8/20
# Nonzero Gaussians: 8/20
# Eliminating not useful Gaussians...
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.6142  Nonzero: 8/8
# Nonzero Gaussians: 8/8
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 3.30 seconds
#   Total Iterations:  43
#  Nonzero Gaussians:  8
#   Unused Gaussians:  12
#  Sectors used in the fit:  19
#  Total number of points fitted:  477
#  Chi2: 0.6138
#  STDEV: 0.03585
#  MEANABSDEV: 0.02397
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       119.615     0.507669     0.709804
#       277.483      1.45405      0.59181
#       196.308      3.03091     0.827799
#       375.744      6.13401            1
#        142.72       7.4899     0.468326
#        561.57      11.4259            1
#       253.712      19.0302     0.485998
#       1133.43      29.5068     0.780333
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.0000 1.0000
# ############################################
# Iteration: 1  chi2: 2.85  Nonzero: 8/20
# Iteration: 11  chi2: 0.8926  Nonzero: 9/20
# Iteration: 21  chi2: 0.7687  Nonzero: 11/20
# Iteration: 31  chi2: 0.
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.2500 1.0000
# ############################################
# Iteration: 1  chi2: 2.85  Nonzero: 8/20
# Iteration: 11  chi2: 0.8926  Nonzero: 9/20
# Iteration: 21  chi2: 0.7687  Nonzero: 11/20
# Iteration: 31  chi2: 0.6272  Nonzero: 8/20
# Iteration: 41  chi2: 0.6176  Nonzero: 8/20
# Iteration: 51  chi2: 0.614  Nonzero: 9/20
# Nonzero Gaussians: 8/20
# Eliminating not useful Gaussians...
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.6139  Nonzero: 8/8
# Nonzero Gaussians: 8/8
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 4.00 seconds
#   Total Iterations:  53
#  Nonzero Gaussians:  8
#   Unused Gaussians:  12
#  Sectors used in the fit:  19
#  Total number of points fitted:  477
#  Chi2: 0.6139
#  STDEV: 0.03585
#  MEANABSDEV: 0.02402
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       116.953     0.507669     0.703097
#       272.712      1.42811     0.582926
#        198.84      2.96429     0.823269
#       374.979      6.08112            1
#       143.711      7.47064     0.469186
#       565.674      11.3966            1
#       253.843       19.018     0.486149
#       1133.95      29.5068     0.780328
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.3000 1.0000
# ############################################
# Iteration: 1  chi2: 2.85  Nonzero: 8/20
# Iteration: 11  chi2: 0.8926  Nonzero: 9/20
# Iteration: 21  chi2: 0.7675  Nonzero: 11/20
# Iteration: 31  chi2: 0.6317  Nonzero: 9/20
# Iteration: 41  chi2: 0.6199  Nonzero: 8/20
# Iteration: 51  chi2: 0.6177  Nonzero: 8/20
# Iteration: 61  chi2: 0.6143  Nonzero: 8/20
# Nonzero Gaussians: 8/20
# Eliminating not useful Gaussians...
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.6143  Nonzero: 8/8
# Nonzero Gaussians: 8/8
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 4.74 seconds
#   Total Iterations:  62
#  Nonzero Gaussians:  8
#   Unused Gaussians:  12
#  Sectors used in the fit:  19
#  Total number of points fitted:  477
#  Chi2: 0.6138
#  STDEV: 0.03585
#  MEANABSDEV: 0.02398
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       121.149     0.507669     0.708745
#       275.834      1.45921     0.589454
#       195.608      3.02404     0.828037
#       375.371       6.1211            1
#       142.663      7.49315     0.467656
#       562.808      11.4172            1
#       253.677      19.0352     0.485924
#       1133.48      29.5068      0.78038
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.3500 1.0000
# ############################################
# Iteration: 1  chi2: 2.85  Nonzero: 8/20
# Iteration: 11  chi2: 0.8926  Nonzero: 9/20
# Iteration: 21  chi2: 0.7713  Nonzero: 9/20
# Iteration: 31  chi2: 0.6186  Nonzero: 10/20
# Iteration: 41  chi2: 0.6133  Nonzero: 9/20
# Nonzero Gaussians: 9/20
# Eliminating not useful Gaussians...
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.6131  Nonzero: 9/9
# Iteration: 11  chi2: 0.5988  Nonzero: 9/9
# Iteration: 21  chi2: 0.5283  Nonzero: 9/9
# Nonzero Gaussians: 9/9
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 3.94 seconds
#   Total Iterations:  43
#  Nonzero Gaussians:  9
#   Unused Gaussians:  11
#  Sectors used in the fit:  19
#  Total number of points fitted:  477
#  Chi2: 0.5272
#  STDEV: 0.03323
#  MEANABSDEV: 0.02266
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       117.021     0.507669     0.714217
#       272.015      1.42936      0.57246
#       196.798      2.92472     0.855975
#       130.569      6.33144     0.508615
#       430.955      6.52479            1
#       605.371       12.644     0.942165
#       121.147      15.7033          0.4
#       603.211      29.5068     0.592755
#       610.576      29.5068            1
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.4000 1.0000
# ############################################
# Iteration: 1  chi2: 2.85  Nonzero: 8/20
# Iteration: 11  chi2: 0.8926  Nonzero: 9/20
# Iteration: 21  chi2: 0.7746  Nonzero: 8/20
# Iteration: 31  chi2: 0.769  Nonzero: 8/20
# Nonzero Gaussians: 9/20
# Eliminating not useful Gaussians...
# ngauss: 8           chi2: 0.769
# ngauss: 7           chi2: 0.769
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.7689  Nonzero: 7/7
# Iteration: 11  chi2: 0.7687  Nonzero: 7/7
# Iteration: 21  chi2: 0.7687  Nonzero: 7/7
# Iteration: 31  chi2: 0.7686  Nonzero: 7/7
# Nonzero Gaussians: 7/7
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 3.19 seconds
#   Total Iterations:  37
#  Nonzero Gaussians:  7
#   Unused Gaussians:  13
#  Sectors used in the fit:  19
#  Total number of points fitted:  477
#  Chi2: 0.7686
#  STDEV: 0.04011
#  MEANABSDEV: 0.02633
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       128.507     0.507669     0.735256
#       308.025       1.5634      0.62616
#       249.391       3.7657     0.844352
#       481.106      7.43484            1
#       120.314      8.11025         0.45
#       611.085      14.5786     0.772997
#       1160.46      29.5068     0.766898
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.4500 1.0000
# ############################################
# Iteration: 1  chi2: 2.85  Nonzero: 8/20
# Iteration: 11  chi2: 0.8926  Nonzero: 9/20
# Iteration: 21  chi2: 0.8042  Nonzero: 8/20
# Nonzero Gaussians: 7/20
# Eliminating not useful Gaussians...
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.8009  Nonzero: 7/7
# Nonzero Gaussians: 7/7
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 2.02 seconds
#   Total Iterations:  26
#  Nonzero Gaussians:  7
#   Unused Gaussians:  13
#  Sectors used in the fit:  19
#  Total number of points fitted:  477
#  Chi2: 0.7993
#  STDEV: 0.0409
#  MEANABSDEV: 0.02712
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       112.582     0.507669     0.704232
#       292.017      1.42326     0.613219
#        242.49      3.40513     0.795246
#       493.413      6.92631         0.95
#       82.6155      8.73771          0.4
#       665.793      13.8811     0.806498
#       1169.08      29.5068     0.761989
# ++++++++++++++++++++++++++++++++++++++++++++
# (maxloop) qbounds=0.4000 0.9500
# ############################################
# ############################################
# Final Regularized MGE Solution:
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       117.021     0.507669     0.714217
#       272.015      1.42936      0.57246
#       196.798      2.92472     0.855975
#       130.569      6.33144     0.508615
#       430.955      6.52479            1
#       605.371       12.644     0.942165
#       121.147      15.7033          0.4
#       603.211      29.5068     0.592755
#       610.576      29.5068            1
# ++++++++++++++++++++++++++++++++++++++++++++
# Final qbounds=0.4000 1.0000
# ############################################

# %%
plt.clf()
plt.figure(figsize=(15,15))
plt.subplot(121)
ctc, model = mge_print_contours(img, f.theta, f.xmed+0.15, f.ymed,m.sol, scale=scale,
                        sigmapsf=sigmapsf, normpsf=normpsf, magrange=8, mask=mask)


n = 5
img_sub = img[f.xpeak-n:f.xpeak+n, f.ypeak-n:f.ypeak+n]
xc, yc = n - f.xpeak + f.xmed, n - f.ypeak + f.ymed
plt.subplot(122)
ctc2, model2 = mge_print_contours(img_sub, f.theta, xc+0.1, yc+0.09, m.sol,
                       sigmapsf=sigmapsf, normpsf=normpsf, scale=scale)

plt.show()

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig, axes = plt.subplots(1,3, figsize=(25, 7))
plt.subplots_adjust(hspace=0.0, wspace=0.3)

#Image
origial_plt = axes[0].imshow(img, origin='lower', vmin=0.0123, vmax=1., cmap="hot")
axes[0].set_title("Original")

divider = make_axes_locatable(axes=axes[0])
cax = divider.append_axes("right", size="5%", pad=0.05)

fig.colorbar(origial_plt, ax=axes[0], cax=cax)


#Model
model_plt = axes[1].imshow(model, origin='lower',vmin=0.0123, vmax=1., cmap="hot")
axes[1].set_title("Model")

divider = make_axes_locatable(axes=axes[1])
cax = divider.append_axes("right", size="5%", pad=0.05)

fig.colorbar(model_plt, ax=axes[1], cax=cax)


#Residual
diff_plt = axes[2].imshow(img - model, origin='lower', vmin=0, vmax=0.1, cmap="hot")
axes[2].set_title("Residual")

divider = make_axes_locatable(axes=axes[2])
cax = divider.append_axes("right", size="5%", pad=0.05)

fig.colorbar(diff_plt, ax=axes[2], cax=cax)

#plt.savefig("SDP81_MGE_with_arcs.png",
#                    fmt="png", bbox_inches='tight', dpi=200)

# %%
# Save model and diff in fits files


fits.writeto(filename=data_path+"model.fits", data=model, overwrite=True)
fits.writeto(filename=data_path+"F160w_difference.fits", data=(img - model), overwrite=True)

# %%
#Save MGE components
np.savetxt('MGE_Output_with_arcs.txt', np.column_stack([m.sol[0], m.sol[1], m.sol[2]]),
           fmt=b'\t%10.6f\t %10.6f\t %10.6f\t ', 
           header='\tTotal_Counts\t Sigma_Pixels\t     qObs\t', delimiter='\t')
