# %%
#Import important packages

import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from os import path

import mgefit
from mgefit.find_galaxy import find_galaxy
from mgefit.mge_fit_1d import mge_fit_1d
from mgefit.sectors_photometry import sectors_photometry
from mgefit.mge_fit_sectors import mge_fit_sectors
from mgefit.mge_print_contours import mge_print_contours
from mgefit.mge_fit_sectors_twist import mge_fit_sectors_twist
from mgefit.sectors_photometry_twist import sectors_photometry_twist
from mgefit.mge_print_contours_twist import mge_print_contours_twist

from mgefit.mge_fit_sectors import mge_fit_sectors
from mgefit.mge_fit_sectors_twist import mge_fit_sectors_twist

from mgefit.mge_fit_sectors_regularized import mge_fit_sectors_regularized

from mpdaf.obj import Image
data_path = "/home/carlos/Desktop/HST Data Reduction/Data/MGE Models/"

# %%
def dist_circle(xc, yc, s):
    """
    Returns an array in which the value of each element is its distance from
    a specified center. Useful for masking inside a circular aperture.

    The (xc, yc) coordinates are the ones one can read on the figure axes
    e.g. when plotting the result of my find_galaxy() procedure.

    """
    x, y = np.ogrid[:s[0], :s[1]] - np.array([yc, xc])  # note yc before xc
    rad = np.sqrt(x**2 + y**2)

    return rad

# %%
#Open the file with the psf

file = data_path+'HST_cubic_interpolation.fits'
hdu = fits.open(file)               #Abrindo imagem
img = hdu[1].data                   #Pega os dados da img
img_data = hdu[1].data              #Pega os dados da img

where_are_NaNs = np.isnan(img)
img[where_are_NaNs] = 0

# %%
minlevel = 0.4    #counts/px
sky = 0.3         #counts/px
scale = 0.09      #arcsec/pxz
img = img - sky

# %%
#MGE PSF for F160w, after build an ePSF with DAOPHOT

normpsf, sigmapsf = np.loadtxt("Psf_model.txt", unpack=True)

print(normpsf.sum()) # Should total(normpsf)=1
# Out:
# 1.0

# %%
    # Here we use FIND_GALAXY directly inside the procedure. Usually you may want
    # to experiment with different values of the FRACTION keyword, before adopting
    # given values of Eps, Ang, Xc, Yc.
    
plt.clf()
f = find_galaxy(img, fraction=0.1, plot=1)
# Out:
#  Pixels used: 1266
#  Peak Img[j, k]: 58 54
#  Mean (j, k): 57.75 54.17
#  Theta (deg): 78.2
#  Astro PA (deg): 11.8
#  Eps: 0.152
#  Major axis (pix): 22.5

# %%
r = dist_circle(35, 106, img.shape)  # 
mask = r > 6

# %%
# Perform galaxy photometry
plt.clf()
s = sectors_photometry(img, f.eps, f.theta, f.xpeak, f.ypeak,
                           minlevel=0.04, plot=1,mask=mask)

# %%
# Do the actual MGE fit
    # *********************** IMPORTANT ***********************************
    # For the final publication-quality MGE fit one should include the line
    # "from mge_fit_sectors_regularized import mge_fit_sectors_regularized"
    # at the top of this file, rename mge_fit_sectors() into
    # mge_fit_sectors_regularized() and re-run the procedure.
    # See the documentation of mge_fit_sectors_regularized for details.
    # *********************************************************************
plt.clf()
m = mge_fit_sectors_regularized(s.radius, s.angle, s.counts, f.eps,
                       ngauss= 20, sigmapsf=sigmapsf, normpsf=normpsf,
                        scale=scale, plot=1)
# Out:
# Iteration: 1  chi2: 2.622  Nonzero: 9/20
# Iteration: 11  chi2: 0.7138  Nonzero: 10/20
# Iteration: 21  chi2: 0.6152  Nonzero: 9/20
# Iteration: 31  chi2: 0.4972  Nonzero: 11/20
# Iteration: 41  chi2: 0.4562  Nonzero: 10/20
# Iteration: 51  chi2: 0.4404  Nonzero: 9/20
# Nonzero Gaussians: 9/20
# Eliminating not useful Gaussians...
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.4034  Nonzero: 9/9
# Iteration: 11  chi2: 0.4031  Nonzero: 9/9
# Iteration: 21  chi2: 0.4031  Nonzero: 9/9
# Iteration: 31  chi2: 0.403  Nonzero: 9/9
# Nonzero Gaussians: 9/9
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 5.38 seconds
#   Total Iterations:  59
#  Nonzero Gaussians:  9
#   Unused Gaussians:  11
#  Sectors used in the fit:  19
#  Total number of points fitted:  480
#  Chi2: 0.403
#  STDEV: 0.02896
#  MEANABSDEV: 0.01957
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       129.124     0.507669     0.716419
#       259.947      1.47179     0.612206
#       198.998      2.92513     0.820632
#       406.594      6.15825            1
#       149.246      7.68231     0.469009
#       501.396       11.895            1
#       239.563       16.435     0.571875
#       607.565      29.4646     0.612255
#       590.424      29.4646            1
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.0000 1.0000
# ############################################
# Iteration: 1  chi2: 2.622  Nonzero: 9/20
# Iteration: 11  chi2: 0.7138  Nonzero: 10/20
# Iteration: 21  chi2: 0.6152  Nonzero: 9/20
# Iteration: 31  chi2: 0.4972  Nonzero: 11/20
# Iteration: 41  chi2: 0.4562  Nonzero: 10/20
# Iteration: 51  chi2: 0.4404  Nonzero: 9/20
# Nonzero Gaussians: 9/20
# Eliminating not useful Gaussians...
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.4034  Nonzero: 9/9
# Iteration: 11  chi2: 0.4031  Nonzero: 9/9
# Iteration: 21  chi2: 0.4031  Nonzero: 9/9
# Iteration: 31  chi2: 0.403  Nonzero: 9/9
# Nonzero Gaussians: 9/9
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 5.44 seconds
#   Total Iterations:  59
#  Nonzero Gaussians:  9
#   Unused Gaussians:  11
#  Sectors used in the fit:  19
#  Total number of points fitted:  480
#  Chi2: 0.403
#  STDEV: 0.02896
#  MEANABSDEV: 0.01957
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       129.124     0.507669     0.716419
#       259.947      1.47179     0.612206
#       198.998      2.92513     0.820632
#       406.594      6.15825            1
#       149.246      7.68231     0.469009
#       501.396       11.895            1
#       239.563       16.435     0.571875
#       607.565      29.4646     0.612255
#       590.424      29.4646            1
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.0500 1.0000
# ############################################
# Iteration: 1  chi2: 2.622  Nonzero: 9/20
# Iteration: 11  chi2: 0.7138  Nonzero: 10/20
# Iteration: 21  chi2: 0.6152  Nonzero: 9/20
# Iteration: 31  chi2: 0.4972  Nonzero: 11/20
# Iteration: 41  chi2: 0.4562  Nonzero: 10/20
# Iteration: 51  chi2: 0.4404  Nonzero: 9/20
# Nonzero Gaussians: 9/20
# Eliminating not useful Gaussians...
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.4034  Nonzero: 9/9
# Iteration: 11  chi2: 0.4031  Nonzero: 9/9
# Iteration: 21  chi2: 0.4031  Nonzero: 9/9
# Iteration: 31  chi2: 0.403  Nonzero: 9/9
# Nonzero Gaussians: 9/9
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 5.43 seconds
#   Total Iterations:  59
#  Nonzero Gaussians:  9
#   Unused Gaussians:  11
#  Sectors used in the fit:  19
#  Total number of points fitted:  480
#  Chi2: 0.403
#  STDEV: 0.02896
#  MEANABSDEV: 0.01957
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       129.124     0.507669     0.716419
#       259.947      1.47179     0.612206
#       198.998      2.92513     0.820632
#       406.594      6.15825            1
#       149.246      7.68231     0.469009
#       501.396       11.895            1
#       239.563       16.435     0.571875
#       607.565      29.4646     0.612255
#       590.424      29.4646            1
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.1000 1.0000
# ############################################
# Iteration: 1  chi2: 2.622  Nonzero: 9/20
# Iteration: 11  chi2: 0.7138  Nonzero: 10/20
# Iteration: 21  chi2: 0.6152  Nonzero: 9/20
# Iteration: 31  chi2: 0.4972  Nonzero: 11/20
# Iteration: 41  chi2: 0.4562  Nonzero: 10/20
# Iteration: 51  chi2: 0.4404  Nonzero: 9/20
# Nonzero Gaussians: 9/20
# Eliminating not useful Gaussians...
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.4034  Nonzero: 9/9
# Iteration: 11  chi2: 0.4031  Nonzero: 9/9
# Iteration: 21  chi2: 0.4031  Nonzero: 9/9
# Iteration: 31  chi2: 0.403  Nonzero: 9/9
# Nonzero Gaussians: 9/9
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 5.53 seconds
#   Total Iterations:  59
#  Nonzero Gaussians:  9
#   Unused Gaussians:  11
#  Sectors used in the fit:  19
#  Total number of points fitted:  480
#  Chi2: 0.403
#  STDEV: 0.02896
#  MEANABSDEV: 0.01957
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       129.124     0.507669     0.716419
#       259.947      1.47179     0.612206
#       198.998      2.92513     0.820632
#       406.594      6.15825            1
#       149.246      7.68231     0.469009
#       501.396       11.895            1
#       239.563       16.435     0.571875
#       607.565      29.4646     0.612255
#       590.424      29.4646            1
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.1500 1.0000
# ############################################
# Iteration: 1  chi2: 2.622  Nonzero: 9/20
# Iteration: 11  chi2: 0.7138  Nonzero: 10/20
# Iteration: 21  chi2: 0.6152  Nonzero: 9/20
# Iteration: 31  chi2: 0.4959  Nonzero: 11/20
# Iteration: 41  chi2: 0.4531  Nonzero: 9/20
# Iteration: 51  chi2: 0.413  Nonzero: 11/20
# Iteration: 61  chi2: 0.4021  Nonzero: 11/20
# Iteration: 71  chi2: 0.4012  Nonzero: 11/20
# Iteration: 81  chi2: 0.3941  Nonzero: 10/20
# Iteration: 91  chi2: 0.3834  Nonzero: 11/20
# Iteration: 101  chi2: 0.3764  Nonzero: 11/20
# Nonzero Gaussians: 12/20
# Eliminating not useful Gaussians...
# ngauss: 11           chi2: 0.375
# ngauss: 10           chi2: 0.375
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.3752  Nonzero: 10/10
# Nonzero Gaussians: 10/10
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 8.60 seconds
#   Total Iterations:  105
#  Nonzero Gaussians:  10
#   Unused Gaussians:  10
#  Sectors used in the fit:  19
#  Total number of points fitted:  480
#  Chi2: 0.3747
#  STDEV: 0.02793
#  MEANABSDEV: 0.01889
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       134.626     0.507669      0.70883
#       246.338      1.48723     0.587387
#       198.208      2.79932     0.830273
#       164.635      6.41781     0.597064
#       398.609      6.45768            1
#       355.972      11.5496            1
#       323.276      14.8807     0.772858
#        60.898      15.8611     0.276025
#       584.237      29.4646     0.597328
#       617.767      29.4646            1
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.2000 1.0000
# ############################################
# Iteration: 1  chi2: 2.622  Nonzero: 9/20
# Iteration: 11  chi2: 0.7138  Nonzero: 10/20
# Iteration: 21  chi2: 0.6152  Nonzero: 9/20
# Iteration: 31  chi2: 0.5125  Nonzero: 9/20
# Iteration: 41  chi2: 0.4621  Nonzero: 9/20
# Iteration: 51  chi2: 0.4114  Nonzero: 9/20
# Iteration: 61  chi2: 0.4032  Nonzero: 9/20
# Nonzero Gaussians: 9/20
# Eliminating not useful Gaussians...
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.
# ++++++++++++++++++++++++++++++++++++++++++++
# (minloop) qbounds=0.4500 1.0000
# ############################################
# Iteration: 1  chi2: 2.622  Nonzero: 9/20
# Iteration: 11  chi2: 0.7138  Nonzero: 10/20
# Iteration: 21  chi2: 0.644  Nonzero: 8/20
# Nonzero Gaussians: 8/20
# Eliminating not useful Gaussians...
# ngauss: 7           chi2: 0.634
# Starting nonlinear fit...
# Iteration: 1  chi2: 0.6345  Nonzero: 7/7
# Nonzero Gaussians: 7/7
# Eliminating not useful Gaussians...
# All Gaussians are needed!
# ############################################
#  Computation time: 2.15 seconds
#   Total Iterations:  26
#  Nonzero Gaussians:  7
#   Unused Gaussians:  13
#  Sectors used in the fit:  19
#  Total number of points fitted:  480
#  Chi2: 0.6311
#  STDEV: 0.03624
#  MEANABSDEV: 0.02355
# ############################################
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       127.868     0.507669      0.73101
#       286.262       1.5055     0.640487
#       226.042      3.38141     0.821533
#       489.957      6.87811         0.95
#       89.1275      8.28458          0.4
#       670.158      13.9893     0.797326
#       1165.54      29.4646     0.764517
# ++++++++++++++++++++++++++++++++++++++++++++
# (maxloop) qbounds=0.4000 0.9500
# ############################################
# ############################################
# Final Regularized MGE Solution:
#   Total_Counts  Sigma_Pixels      qObs
# ############################################
#       128.562     0.507669     0.718002
#       261.324      1.47189     0.616098
#       198.361      2.93132     0.819906
#       406.638      6.15842            1
#       149.078      7.68753     0.468808
#       501.574      11.8952            1
#       239.359      16.4409     0.571622
#       607.562      29.4646     0.612282
#        590.38      29.4646            1
# ++++++++++++++++++++++++++++++++++++++++++++
# Final qbounds=0.4000 1.0000
# ############################################

# %%
plt.clf()
plt.figure(figsize=(15,15))
plt.subplot(121)
ctc, model = mge_print_contours(img, f.theta, f.xmed+0.15, f.ymed,m.sol, scale=scale,
                        sigmapsf=sigmapsf, normpsf=normpsf, magrange=8, mask=mask)


n = 5
img_sub = img[f.xpeak-n:f.xpeak+n, f.ypeak-n:f.ypeak+n]
xc, yc = n - f.xpeak + f.xmed, n - f.ypeak + f.ymed
plt.subplot(122)
ctc2, model2 = mge_print_contours(img_sub, f.theta, xc+0.1, yc+0.0, m.sol,
                       sigmapsf=sigmapsf, normpsf=normpsf, scale=scale)

plt.show()

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig, axes = plt.subplots(1,3, figsize=(25, 7))
plt.subplots_adjust(hspace=0.0, wspace=0.3)

#Image
origial_plt = axes[0].imshow(img, origin='lower', vmin=0.0123, vmax=1., cmap="hot")
axes[0].set_title("Original")

divider = make_axes_locatable(axes=axes[0])
cax = divider.append_axes("right", size="5%", pad=0.05)

fig.colorbar(origial_plt, ax=axes[0], cax=cax)


#Model
model_plt = axes[1].imshow(model, origin='lower',vmin=0.0123, vmax=1., cmap="hot")
axes[1].set_title("Model")

divider = make_axes_locatable(axes=axes[1])
cax = divider.append_axes("right", size="5%", pad=0.05)

fig.colorbar(model_plt, ax=axes[1], cax=cax)


#Residual
diff_plt = axes[2].imshow(img - model, origin='lower', vmin=0, vmax=0.1, cmap="hot")
axes[2].set_title("Residual")

divider = make_axes_locatable(axes=axes[2])
cax = divider.append_axes("right", size="5%", pad=0.05)

fig.colorbar(diff_plt, ax=axes[2], cax=cax)

#plt.savefig("SDP81_MGE_with_arcs.png",
#                    fmt="png", bbox_inches='tight', dpi=200)

# %%
# Save model and diff in fits files
save_path = "/home/carlos/Desktop/HST Data Reduction/Data/MGE Models/Final Model/"

fits.writeto(filename=save_path+"Model_no_arcs.fits", data=model, overwrite=True)
fits.writeto(filename=save_path+"NoArcs_Resisual.fits", data=(img - model), overwrite=True)

# %%
#Save MGE components
np.savetxt('MGE_Output_no_arcs.txt', np.column_stack([m.sol[0], m.sol[1], m.sol[2]]),
           fmt=b'\t%10.6f\t %10.6f\t %10.6f\t ', 
           header='\tTotal_Counts\t Sigma_Pixels\t     qObs\t', delimiter='\t')
