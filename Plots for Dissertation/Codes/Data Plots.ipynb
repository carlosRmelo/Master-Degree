# %% [markdown]
# # Plot dataset for dissertation
#
# To save the images with high quality and better adjusted, press the left mouse button and choose "Save Image As ...".

# %%
from mpdaf.obj import Image
import matplotlib.pyplot as plt

# Import CMasher to register colormaps
import cmasher as cmr

save_folder = "/home/carlos/Documents/GitHub/Master-Degree/Plots for Dissertation/Images"

# %%
f160w = Image("/home/carlos/Desktop/HST Data Reduction/Data/Centered/HST_final.fits")
f160w.info()
f160w.data.data[:] = (f160w.data.data/f160w.data.max())
# Out:
# [INFO] 115 x 111 Image (/home/carlos/Desktop/HST Data Reduction/Data/Centered/HST_final.fits)
# [INFO] .data(115 x 111) (no unit), no noise
# [INFO] center:(00:39:06.4789,09:03:11.5679) size:(10.018",10.033") step:(0.087",0.090") rot:-0.2 deg frame:ICRS
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
# ...

# %%
plt.figure(figsize=(12,8))
cmap = cmr.pride

fig = f160w.plot(use_wcs=True, cmap=cmap, colorbar="v", scale="log", vmin=1.35e-2 )

ax =  plt.subplot(projection=f160w.wcs.wcs)

ax.arrow(10, 10, 10, 0,
         head_width=0, head_length=0,
         fc='white', ec='white', width=0.1,
         )
plt.text(11.5, 7, ' 0.9" ',
         color='white', rotation=0,weight='bold'
         )

cb = plt.colorbar(fig,  pad=-0.2)
cb.set_label(label="Flux Normalized by the Maximum ",weight='bold')
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
plt.xlabel(r"pos.eq.ra", fontsize=15)
plt.ylabel(r"pos.eq.dec", fontsize=15)
#plt.tight_layout()
#plt.savefig(save_folder+"/F160W_Original.png", fmt="png", dpi=150)
plt.show()
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
alma = Image("/home/carlos/Desktop/HST Data Reduction/Data Alma/ALMA.fits")
alma.info()
alma.data.data[:] = (alma.data.data/alma.data.max())
# Out:
# WARNING: MpdafUnitsWarning: No physical unit in the FITS header: missing BUNIT keyword. [mpdaf.obj.data]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -67.754929 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -23.022886 from OBSGEO-[XYZ].
# Set OBSGEO-H to     5053.796 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# [INFO] 841 x 841 Image (/home/carlos/Desktop/HST Data Reduction/Data Alma/ALMA.fits)
# [INFO] .data(841 x 841) (no unit), no noise
# [INFO] center:(00:39:06.545,09:03:11.5603) size:(4.205",4.205") step:(0.005",0.005") rot:-0.0 deg frame:FK5

# %%
plt.figure(figsize=(12,8))

fig = alma.plot(use_wcs=True, cmap=cmap, colorbar="v")

ax =  plt.subplot(projection=alma.wcs.wcs)

ax.arrow(100, 75, 100, 0,
         head_width=0, head_length=0,
         fc='black', ec='black', width=2,
         )
plt.text(125, 50, ' 0.5" ',
         color='black', rotation=0,weight='bold'
         )

cb = plt.colorbar(fig,  pad=-0.22)
cb.set_label(label="Flux Normalized by the Maximum ",weight='bold')
#plt.savefig(save_folder+"/ALMA_Original.png", fmt="png", dpi=150)
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
plt.xlabel(r"pos.eq.ra", fontsize=15)
plt.ylabel(r"pos.eq.dec", fontsize=15)
plt.show()
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %%
muse = Image("/home/carlos/Documents/GitHub/Master-Degree/SDP81/Final Model - Dissertation/pPXF/Data/Muse_Image.fits")
muse.info()
muse.data.data[:] = (muse.data.data/muse.data.max())
# Out:
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'CDELT1' is not FITS standard (invalid value string: '-5.55556e-05').  Fixed 'CDELT1' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'CDELT2' is not FITS standard (invalid value string: '5.55556e-05').  Fixed 'CDELT2' card to meet the FITS standard. [astropy.io.fits.verify]
# [INFO] 60 x 60 Image (/home/carlos/Documents/GitHub/Master-Degree/SDP81/Final Model - Dissertation/pPXF/Data/Muse_Image.fits)
# [INFO] .data(60 x 60) (1e-20 erg / (Angstrom cm2 s)), no noise
# [INFO] center:(00:39:06.5987,09:03:11.5707) size:(12.000",12.000") step:(0.200",0.200") rot:-0.0 deg frame:FK5

# %%
plt.figure(figsize=(12,8))

fig = muse.plot(use_wcs=True, cmap=cmap, colorbar="v", scale="log", vmin=-.8e-2)

ax =  plt.subplot(projection=muse.wcs.wcs)

ax.arrow(5, 10, 5, 0,
         head_width=0, head_length=0,
         fc='black', ec='black', width=0.1,
         )
plt.text(6.5, 8, ' 1" ',
         color='black', rotation=0,weight='bold'
         )

cb = plt.colorbar(fig,  pad=-0.22)
cb.set_label(label="Flux Normalized by the Maximum ",weight='bold')
#plt.savefig(save_folder+"/MUSE_Original.png", fmt="png", dpi=150)
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
plt.xlabel(r"pos.eq.ra", fontsize=15)
plt.ylabel(r"pos.eq.dec", fontsize=15)
plt.show()
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %%
arcs = Image("/home/carlos/Desktop/HST Data Reduction/Data/MGE Models/Arcs/Total_Arcs_wcs.fits")
arcs.info()
arcs.data.data[:] = (arcs.data.data/arcs.data.max())
# Out:
# [INFO] 115 x 111 Image (/home/carlos/Desktop/HST Data Reduction/Data/MGE Models/Arcs/Total_Arcs_wcs.fits)
# [INFO] .data(115 x 111) (no unit), no noise
# [INFO] center:(00:39:06.4789,09:03:11.5679) size:(10.018",10.033") step:(0.087",0.090") rot:-0.2 deg frame:ICRS

# %%
plt.figure(figsize=(12,8))

fig = arcs.plot(use_wcs=True, cmap=cmap, colorbar="v", vmin=-2e-2)

ax =  plt.subplot(projection=arcs.wcs.wcs)

ax.arrow(10, 10, 10, 0,
         head_width=0, head_length=0,
         fc='white', ec='white', width=0.1,
         )
plt.text(11.5, 7, ' 0.9" ',
         color='white', rotation=0,weight='bold'
         )

cb = plt.colorbar(fig,  pad=-0.2)
cb.set_label(label="Flux Normalized by the Maximum ",weight='bold')

#plt.savefig(save_folder+"/Arcs_HST.png", fmt="png", dpi=150)
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)
plt.xlabel(r"pos.eq.ra", fontsize=15)
plt.ylabel(r"pos.eq.dec", fontsize=15)
plt.show()
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """
