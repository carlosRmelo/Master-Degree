# %% [markdown]
# Tutorial 3: Realism and Complexity
# ==================================
#
# Up to now, we've fitted some fairly crude and unrealistic lens models. For example, we've modeled the lens galaxy's
# mass as a sphere. Given most lens galaxies are 'elliptical's we should probably model their mass as elliptical! We've
# also omitted the lens galaxy's light, which typically outshines the source galaxy.
#
# In this example, we'll start using a more realistic lens model.
#
# In my experience, the simplest lens model (e.g. that has the fewest parameters) that provides a good fit to real
# strong lenses is as follows:
#
#     1) An _EllipticalSersic _LightProfile_ for the lens galaxy's light.
#     2) A _EllipticalIsothermal_ (SIE) _MassProfile_ for the lens galaxy's mass.
#     3) An _EllipticalExponential_ _LightProfile_ for the source-galaxy's light (to be honest, this is too simple,
#         but lets worry about that later).
#
# This has a total of 18 non-linear parameters, which is over double the number of parameters we've fitted up to now.
# In future exercises, we'll fit even more complex models, with some 20-30+ non-linear parameters.

# %%
# %matplotlib inline

from autoconf import conf
import autolens as al
import autolens.plot as aplt
import autofit as af
from pyprojroot import here

workspace_path = str(here())
print("Workspace Path: ", workspace_path)

conf.instance = conf.Config(
    config_path=f"{workspace_path}/howtolens/config",
    output_path=f"{workspace_path}/howtolens/output",
)
# Out:
# Workspace Path:  /home/carlos/autolens_workspace

# %% [markdown]
# We’ll use new strong lensing data, where:
#
#     The lens galaxy’s LightProfile is an EllipticalSersic.
#     The lens galaxy’s MassProfile is an EllipticalIsothermal.
#     The source galaxy’s LightProfile is an EllipticalExponential.

# %%
from howtolens.simulators.chapter_2 import (
    lens_sersic_sie__source_exp,
)

dataset_type = "chapter_2"
dataset_name = "lens_sersic_sie__source_exp"
dataset_path = f"{workspace_path}/howtolens/dataset/{dataset_type}/{dataset_name}"

imaging = al.Imaging.from_fits(
    image_path=f"{dataset_path}/image.fits",
    noise_map_path=f"{dataset_path}/noise_map.fits",
    psf_path=f"{dataset_path}/psf.fits",
    pixel_scales=0.1,
)

# %% [markdown]
# We’ll create and use a 2.5” Mask.

# %%
mask = al.Mask.circular(
    shape_2d=imaging.shape_2d, pixel_scales=imaging.pixel_scales, radius=2.5
)

# %% [markdown]
# When plotted, the lens light’s is clearly visible in the centre of the image.

# %%
aplt.Imaging.subplot_imaging(imaging=imaging, mask=mask)

# %% [markdown]
# Like in the previous tutorial, we use a_PhaseSettingsImaging_ object to specify our model-fitting procedure uses a regular Grid.

# %%
settings = al.PhaseSettingsImaging(grid_class=al.Grid, sub_size=2)

# %% [markdown]
# Now lets fit the dataset using a phase.

# %%
phase = al.PhaseImaging(
    phase_name="phase_t3_realism_and_complexity",
    settings=settings,
    galaxies=dict(
        lens_galaxy=al.GalaxyModel(
            redshift=0.5, light=al.lp.EllipticalSersic, mass=al.mp.EllipticalIsothermal
        ),
        source_galaxy=al.GalaxyModel(redshift=1.0, light=al.lp.EllipticalExponential),
    ),
    search=af.DynestyStatic(n_live_points=80),
)

# %% [markdown]
# Lets run the phase.

# %%
print(
    "Dynesty has begun running - checkout the autolens_workspace/output/3_realism_and_complexity"
    "folder for live output of the results, images and lens model."
    "This Jupyter notebook cell with progress once Dynesty has completed - this could take some time!"
)

result =  phase.run(dataset=imaging, mask=mask)

print("Dynesty has finished run - you may now continue the notebook.")
# Out:
# Dynesty has begun running - checkout the autolens_workspace/output/3_realism_and_complexityfolder for live output of the results, images and lens model.This Jupyter notebook cell with progress once Dynesty has completed - this could take some time!
# INFO:root:Generating initial samples of model, which are subject to prior limits and other constraints.
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/dynesty.py:373: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# INFO:root:No Dynesty samples found, beginning new non-linear search.
# 296it [00:56,  5.26it/s, +80 | bound: 0 | nc: 1 | ncall: 2610 | eff(%): 14.406 | loglstar:   -inf < -3843.478 <    inf | logz: -3852.243 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:2500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 297it [00:00, 379.48it/s, bound: 0 | nc: 36 | ncall: 2646 | eff(%): 11.224 | loglstar:   -inf < -12179.881 <    inf | logz: -12187.952 +/-    nan | dlogz: 8406.799 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 309it [00:10,  4.17it/s, bound: 1 | nc: 5 | ncall: 3082 | eff(%): 10.026 | loglstar:   -inf < -11829.301 <    inf | logz: -11838.215 +/-    nan | dlogz: 8037.067 >  0.089]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 324it [00:12,  5.29it/s, bound: 2 | nc: 5 | ncall: 3181 | eff(%): 10.185 | loglstar:   -inf < -11402.158 <    inf | logz: -11411.245 +/-    nan | dlogz: 7568.743 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 336it [00:14,  6.19it/s, bound: 4 | nc: 5 | ncall: 3268 | eff(%): 10.282 | loglstar:   -inf < -11030.392 <    inf | logz: -11039.641 +/-    nan | dlogz: 7201.638 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 366it [00:19,  8.03it/s, bound: 7 | nc: 5 | ncall: 3472 | eff(%): 10.541 | loglstar:   -inf < -10281.142 <    inf | logz: -10290.704 +/-    nan | dlogz: 6543.312 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 388it [00:22,  8.62it/s, bound: 9 | nc: 5 | ncall: 3605 | eff(%): 10.763 | loglstar:   -inf < -9709.861 <    inf | logz: -9719.756 +/-    nan | dlogz: 5984.800 >  0.089]   /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 416it [00:26,  7.10it/s, bound: 12 | nc: 5 | ncall: 3796 | eff(%): 10.959 | loglstar:   -inf < -9092.035 <    inf | logz: -9102.264 +/-    nan | dlogz: 5355.667 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 454it [00:31,  8.05it/s, bound: 16 | nc: 5 | ncall: 4017 | eff(%): 11.302 | loglstar:   -inf < -7977.803 <    inf | logz: -7988.443 +/-    nan | dlogz: 4308.481 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 482it [00:35,  7.61it/s, bound: 18 | nc: 5 | ncall: 4163 | eff(%): 11.578 | loglstar:   -inf < -7123.960 <    inf | logz: -7135.023 +/-    nan | dlogz: 3532.795 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 504it [00:38,  7.29it/s, bound: 20 | nc: 5 | ncall: 4308 | eff(%): 11.699 | loglstar:   -inf < -6721.972 <    inf | logz: -6733.308 +/-    nan | dlogz: 4094.659 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 533it [00:42,  7.72it/s, bound: 24 | nc: 5 | ncall: 4466 | eff(%): 11.935 | loglstar:   -inf < -6200.620 <    inf | logz: -6212.317 +/-    nan | dlogz: 3580.039 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 539it [00:43,  6.41it/s, bound: 25 | nc: 5 | ncall: 4515 | eff(%): 11.938 | loglstar:   -inf < -6036.988 <    inf | logz: -6048.759 +/-    nan | dlogz: 3423.593 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 559it [00:46,  7.81it/s, bound: 27 | nc: 5 | ncall: 4638 | eff(%): 12.053 | loglstar:   -inf < -5739.115 <    inf | logz: -5751.131 +/-    nan | dlogz: 3194.418 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 570it [00:48,  7.89it/s, bound: 28 | nc: 5 | ncall: 4701 | eff(%): 12.125 | loglstar:   -inf < -5543.346 <    inf | logz: -5555.100 +/-    nan | dlogz: 2993.550 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 608it [00:54,  7.34it/s, bound: 33 | nc: 5 | ncall: 4956 | eff(%): 12.268 | loglstar:   -inf < -4963.501 <    inf | logz: -4976.090 +/-    nan | dlogz: 2552.640 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 618it [00:56,  7.21it/s, bound: 34 | nc: 6 | ncall: 5032 | eff(%): 12.281 | loglstar:   -inf < -4826.558 <    inf | logz: -4839.310 +/-    nan | dlogz: 2430.916 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 628it [00:57, 10.83it/s, +80 | bound: 36 | nc: 1 | ncall: 5113 | eff(%): 13.847 | loglstar:   -inf < -2419.849 <    inf | logz: -2432.738 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 629it [00:00, 2532.35it/s, bound: 36 | nc: 11 | ncall: 5124 | eff(%): 12.276 | loglstar:   -inf < -4691.769 <    inf | logz: -4703.962 +/-    nan | dlogz: 2281.965 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 740it [00:18,  8.52it/s, bound: 49 | nc: 5 | ncall: 5917 | eff(%): 12.506 | loglstar:   -inf < -3555.231 <    inf | logz: -3568.891 +/-    nan | dlogz: 1413.040 >  0.089]   /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 753it [00:21,  4.73it/s, bound: 51 | nc: 14 | ncall: 6049 | eff(%): 12.448 | loglstar:   -inf < -3451.812 <    inf | logz: -3466.073 +/-    nan | dlogz: 1311.030 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 774it [00:25,  7.71it/s, bound: 53 | nc: 5 | ncall: 6210 | eff(%): 12.464 | loglstar:   -inf < -3247.259 <    inf | logz: -3261.949 +/-    nan | dlogz: 1159.819 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 813it [00:32,  6.73it/s, bound: 58 | nc: 6 | ncall: 6525 | eff(%): 12.460 | loglstar:   -inf < -2995.308 <    inf | logz: -3010.482 +/-    nan | dlogz: 1016.795 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 837it [00:36,  4.33it/s, bound: 61 | nc: 7 | ncall: 6719 | eff(%): 12.457 | loglstar:   -inf < -2835.608 <    inf | logz: -2851.081 +/-    nan | dlogz: 932.303 >  0.089]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 861it [00:40,  6.74it/s, bound: 63 | nc: 5 | ncall: 6891 | eff(%): 12.495 | loglstar:   -inf < -2706.941 <    inf | logz: -2722.628 +/-    nan | dlogz: 793.355 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 906it [00:48,  7.03it/s, bound: 69 | nc: 5 | ncall: 7201 | eff(%): 12.582 | loglstar:   -inf < -2502.309 <    inf | logz: -2517.677 +/-    nan | dlogz: 606.614 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 958it [00:57,  4.19it/s, bound: 75 | nc: 13 | ncall: 7610 | eff(%): 12.589 | loglstar:   -inf < -2342.159 <    inf | logz: -2358.427 +/-    nan | dlogz: 723.366 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 959it [00:59, 16.23it/s, +80 | bound: 75 | nc: 1 | ncall: 7670 | eff(%): 13.546 | loglstar:   -inf < -1624.522 <    inf | logz: -1641.522 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:7500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 960it [00:00, 8474.18it/s, bound: 76 | nc: 5 | ncall: 7675 | eff(%): 12.508 | loglstar:   -inf < -2327.752 <    inf | logz: -2344.059 +/-    nan | dlogz: 719.161 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1248it [00:50,  6.64it/s, bound: 110 | nc: 5 | ncall: 9957 | eff(%): 12.534 | loglstar:   -inf < -1706.885 <    inf | logz: -1726.750 +/-    nan | dlogz: 412.887 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1265it [00:53,  6.00it/s, bound: 112 | nc: 5 | ncall: 10110 | eff(%): 12.512 | loglstar:   -inf < -1688.205 <    inf | logz: -1708.571 +/-    nan | dlogz: 394.838 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1266it [00:57, 22.11it/s, +80 | bound: 112 | nc: 1 | ncall: 10260 | eff(%): 13.119 | loglstar:   -inf < -1118.597 <    inf | logz: -1139.411 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1267it [00:00, 5640.99it/s, bound: 113 | nc: 10 | ncall: 10270 | eff(%): 12.337 | loglstar:   -inf < -1684.994 <    inf | logz: -1704.993 +/-    nan | dlogz: 572.829 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1484it [00:37,  5.18it/s, bound: 137 | nc: 5 | ncall: 11858 | eff(%): 12.515 | loglstar:   -inf < -1298.471 <    inf | logz: -1320.992 +/-    nan | dlogz: 584.061 >  0.089]   /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1495it [00:39,  5.64it/s, bound: 139 | nc: 5 | ncall: 11936 | eff(%): 12.525 | loglstar:   -inf < -1268.042 <    inf | logz: -1291.550 +/-    nan | dlogz: 703.960 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1561it [00:51,  5.91it/s, bound: 147 | nc: 7 | ncall: 12450 | eff(%): 12.538 | loglstar:   -inf < -1088.731 <    inf | logz: -1112.859 +/-    nan | dlogz: 1175.413 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1573it [00:53,  4.46it/s, bound: 148 | nc: 17 | ncall: 12546 | eff(%): 12.538 | loglstar:   -inf < -1062.075 <    inf | logz: -1085.809 +/-    nan | dlogz: 1147.476 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1580it [00:55,  5.54it/s, bound: 149 | nc: 5 | ncall: 12614 | eff(%): 12.526 | loglstar:   -inf < -1048.606 <    inf | logz: -1072.847 +/-    nan | dlogz: 1135.250 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1600it [00:58, 27.31it/s, +80 | bound: 151 | nc: 1 | ncall: 12765 | eff(%): 13.161 | loglstar:   -inf < 134.551 <    inf | logz: 109.587 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:12500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1601it [00:00, 11099.40it/s, bound: 151 | nc: 6 | ncall: 12771 | eff(%): 12.536 | loglstar:   -inf < -992.135 <    inf | logz: -1016.338 +/-    nan | dlogz: 1133.740 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1741it [00:24,  7.07it/s, bound: 168 | nc: 5 | ncall: 13769 | eff(%): 12.644 | loglstar:   -inf < -388.619 <    inf | logz: -414.842 +/-    nan | dlogz: 1852.679 >  0.089]    /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1747it [00:26,  5.42it/s, bound: 170 | nc: 6 | ncall: 13829 | eff(%): 12.633 | loglstar:   -inf < -368.899 <    inf | logz: -395.658 +/-    nan | dlogz: 1836.424 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1795it [00:36,  5.80it/s, bound: 175 | nc: 5 | ncall: 14221 | eff(%): 12.622 | loglstar:   -inf < -108.240 <    inf | logz: -135.593 +/-    nan | dlogz: 1575.418 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1824it [00:41,  8.01it/s, bound: 179 | nc: 5 | ncall: 14437 | eff(%): 12.634 | loglstar:   -inf < 101.640 <    inf | logz: 73.908 +/-    nan | dlogz: 1367.913 >  0.089]    /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1834it [00:44,  5.94it/s, bound: 180 | nc: 5 | ncall: 14572 | eff(%): 12.586 | loglstar:   -inf < 186.114 <    inf | logz: 158.256 +/-    nan | dlogz: 1297.791 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1854it [00:48,  6.91it/s, bound: 184 | nc: 5 | ncall: 14742 | eff(%): 12.576 | loglstar:   -inf < 273.139 <    inf | logz: 246.416 +/-    nan | dlogz: 1325.958 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1885it [00:54,  7.14it/s, bound: 187 | nc: 5 | ncall: 14976 | eff(%): 12.587 | loglstar:   -inf < 408.640 <    inf | logz: 380.156 +/-    nan | dlogz: 1233.427 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1922it [01:01, 31.13it/s, +80 | bound: 191 | nc: 1 | ncall: 15266 | eff(%): 13.114 | loglstar:   -inf < 1631.412 <    inf | logz: 1602.491 +/-    nan | dlogz:  1.071 >  0.089]
# INFO:root:15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1923it [00:00, 15571.86it/s, bound: 191 | nc: 5 | ncall: 15271 | eff(%): 12.592 | loglstar:   -inf < 620.144 <    inf | logz: 591.874 +/-    nan | dlogz: 1029.093 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2048it [00:21,  5.70it/s, bound: 208 | nc: 5 | ncall: 16147 | eff(%): 12.683 | loglstar:   -inf < 1190.659 <    inf | logz: 1160.458 +/-    nan | dlogz: 803.734 >  0.089]   /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2079it [00:26,  7.84it/s, bound: 211 | nc: 5 | ncall: 16356 | eff(%): 12.711 | loglstar:   -inf < 1307.154 <    inf | logz: 1276.260 +/-    nan | dlogz: 694.772 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2094it [00:29,  6.31it/s, bound: 214 | nc: 5 | ncall: 16459 | eff(%): 12.723 | loglstar:   -inf < 1362.651 <    inf | logz: 1332.006 +/-    nan | dlogz: 635.277 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2121it [00:33,  6.07it/s, bound: 217 | nc: 5 | ncall: 16635 | eff(%): 12.750 | loglstar:   -inf < 1457.807 <    inf | logz: 1426.678 +/-    nan | dlogz: 540.498 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2150it [00:39,  7.12it/s, bound: 220 | nc: 5 | ncall: 16876 | eff(%): 12.740 | loglstar:   -inf < 1576.934 <    inf | logz: 1545.151 +/-    nan | dlogz: 549.166 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2152it [00:40,  4.90it/s, bound: 221 | nc: 5 | ncall: 16900 | eff(%): 12.734 | loglstar:   -inf < 1577.959 <    inf | logz: 1547.295 +/-    nan | dlogz: 538.483 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2195it [00:46,  6.46it/s, bound: 225 | nc: 5 | ncall: 17172 | eff(%): 12.782 | loglstar:   -inf < 1654.882 <    inf | logz: 1623.704 +/-    nan | dlogz: 472.405 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2205it [00:49,  3.18it/s, bound: 227 | nc: 11 | ncall: 17286 | eff(%): 12.756 | loglstar:   -inf < 1698.727 <    inf | logz: 1667.479 +/-    nan | dlogz: 428.747 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2213it [00:51,  5.83it/s, bound: 228 | nc: 5 | ncall: 17346 | eff(%): 12.758 | loglstar:   -inf < 1721.743 <    inf | logz: 1689.422 +/-    nan | dlogz: 407.705 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2265it [00:59,  4.18it/s, bound: 233 | nc: 5 | ncall: 17693 | eff(%): 12.802 | loglstar:   -inf < 1819.445 <    inf | logz: 1787.635 +/-    nan | dlogz: 368.083 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2273it [01:01, 36.86it/s, +80 | bound: 234 | nc: 1 | ncall: 17775 | eff(%): 13.238 | loglstar:   -inf < 2273.258 <    inf | logz: 2239.934 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:17500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2274it [00:00, 18335.95it/s, bound: 234 | nc: 5 | ncall: 17780 | eff(%): 12.790 | loglstar:   -inf < 1841.212 <    inf | logz: 1808.919 +/-    nan | dlogz: 437.351 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2390it [00:20, 18335.95it/s, bound: 249 | nc: 13 | ncall: 18599 | eff(%): 12.850 | loglstar:   -inf < 2026.675 <    inf | logz: 1992.342 +/-    nan | dlogz: 274.876 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2396it [00:21,  6.52it/s, bound: 250 | nc: 6 | ncall: 18663 | eff(%): 12.838 | loglstar:   -inf < 2043.103 <    inf | logz: 2009.185 +/-    nan | dlogz: 257.041 >  0.089]    /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2416it [00:25,  5.95it/s, bound: 253 | nc: 9 | ncall: 18818 | eff(%): 12.839 | loglstar:   -inf < 2070.770 <    inf | logz: 2035.719 +/-    nan | dlogz: 233.061 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2432it [00:27,  7.15it/s, bound: 254 | nc: 5 | ncall: 18913 | eff(%): 12.859 | loglstar:   -inf < 2086.877 <    inf | logz: 2052.516 +/-    nan | dlogz: 213.285 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2472it [00:34,  5.53it/s, bound: 260 | nc: 7 | ncall: 19197 | eff(%): 12.877 | loglstar:   -inf < 2126.242 <    inf | logz: 2091.450 +/-    nan | dlogz: 221.566 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2562it [00:48,  7.19it/s, bound: 269 | nc: 5 | ncall: 19768 | eff(%): 12.960 | loglstar:   -inf < 2202.826 <    inf | logz: 2167.005 +/-    nan | dlogz: 155.102 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2599it [00:55,  7.34it/s, bound: 274 | nc: 5 | ncall: 20030 | eff(%): 12.976 | loglstar:   -inf < 2230.210 <    inf | logz: 2194.379 +/-    nan | dlogz: 127.031 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2618it [00:59,  5.68it/s, bound: 276 | nc: 7 | ncall: 20183 | eff(%): 12.971 | loglstar:   -inf < 2241.719 <    inf | logz: 2205.757 +/-    nan | dlogz: 115.256 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2629it [01:01, 42.67it/s, +80 | bound: 277 | nc: 1 | ncall: 20279 | eff(%): 13.359 | loglstar:   -inf < 2353.126 <    inf | logz: 2315.380 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2630it [00:00, 20759.43it/s, bound: 278 | nc: 5 | ncall: 20284 | eff(%): 12.966 | loglstar:   -inf < 2248.213 <    inf | logz: 2212.658 +/-    nan | dlogz: 108.062 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2822it [00:31,  7.10it/s, bound: 299 | nc: 5 | ncall: 21568 | eff(%): 13.084 | loglstar:   -inf < 2319.835 <    inf | logz: 2281.572 +/-    nan | dlogz: 62.233 >  0.089]    /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2837it [00:33,  7.56it/s, bound: 301 | nc: 5 | ncall: 21669 | eff(%): 13.092 | loglstar:   -inf < 2324.806 <    inf | logz: 2286.411 +/-    nan | dlogz: 57.220 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2866it [00:38,  7.56it/s, bound: 304 | nc: 5 | ncall: 21860 | eff(%): 13.111 | loglstar:   -inf < 2333.410 <    inf | logz: 2294.939 +/-    nan | dlogz: 48.291 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2877it [00:40,  7.48it/s, bound: 305 | nc: 5 | ncall: 21924 | eff(%): 13.123 | loglstar:   -inf < 2336.068 <    inf | logz: 2297.394 +/-    nan | dlogz: 45.685 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2893it [00:42,  6.34it/s, bound: 307 | nc: 7 | ncall: 22026 | eff(%): 13.134 | loglstar:   -inf < 2339.173 <    inf | logz: 2300.223 +/-    nan | dlogz: 42.628 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2931it [00:50,  3.27it/s, bound: 311 | nc: 27 | ncall: 22336 | eff(%): 13.122 | loglstar:   -inf < 2350.236 <    inf | logz: 2310.670 +/-    nan | dlogz: 31.819 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2956it [00:54,  6.31it/s, bound: 314 | nc: 6 | ncall: 22515 | eff(%): 13.129 | loglstar:   -inf < 2352.930 <    inf | logz: 2313.998 +/-    nan | dlogz: 30.062 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 2969it [01:01, 48.14it/s, +80 | bound: 316 | nc: 1 | ncall: 22804 | eff(%): 13.370 | loglstar:   -inf < 2410.000 <    inf | logz: 2368.030 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:22500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2970it [00:00, 22968.76it/s, bound: 317 | nc: 5 | ncall: 22809 | eff(%): 13.021 | loglstar:   -inf < 2355.043 <    inf | logz: 2315.857 +/-    nan | dlogz: 57.392 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 3075it [00:19, 22968.76it/s, bound: 329 | nc: 9 | ncall: 23619 | eff(%): 13.019 | loglstar:   -inf < 2367.512 <    inf | logz: 2327.395 +/-    nan | dlogz: 44.504 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 3086it [00:22,  7.18it/s, bound: 331 | nc: 5 | ncall: 23727 | eff(%): 13.006 | loglstar:   -inf < 2368.470 <    inf | logz: 2328.323 +/-    nan | dlogz: 43.433 >  0.089]   /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 3179it [00:41,  6.07it/s, bound: 343 | nc: 5 | ncall: 24491 | eff(%): 12.980 | loglstar:   -inf < 2375.806 <    inf | logz: 2334.844 +/-    nan | dlogz: 35.733 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 3219it [00:49,  4.33it/s, bound: 349 | nc: 15 | ncall: 24826 | eff(%): 12.966 | loglstar:   -inf < 2378.578 <    inf | logz: 2337.017 +/-    nan | dlogz: 33.068 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 3234it [01:01, 52.98it/s, +80 | bound: 351 | nc: 1 | ncall: 25314 | eff(%): 13.092 | loglstar:   -inf < 2410.000 <    inf | logz: 2364.738 +/-    nan | dlogz:  1.098 >  0.089]
# INFO:root:25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3235it [00:00, 24218.96it/s, bound: 352 | nc: 5 | ncall: 25319 | eff(%): 12.777 | loglstar:   -inf < 2379.471 <    inf | logz: 2337.901 +/-    nan | dlogz: 31.975 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 3374it [00:26,  6.42it/s, bound: 368 | nc: 5 | ncall: 26366 | eff(%): 12.797 | loglstar:   -inf < 2386.483 <    inf | logz: 2343.472 +/-    nan | dlogz: 31.032 >  0.089]   /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 3402it [00:31,  5.42it/s, bound: 372 | nc: 5 | ncall: 26570 | eff(%): 12.804 | loglstar:   -inf < 2387.791 <    inf | logz: 2344.507 +/-    nan | dlogz: 39.197 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 3497it [01:00,  3.01it/s, bound: 387 | nc: 25 | ncall: 27767 | eff(%): 12.594 | loglstar:   -inf < 2390.708 <    inf | logz: 2346.658 +/-    nan | dlogz: 66.454 >  0.089] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 3498it [01:04, 54.02it/s, +80 | bound: 388 | nc: 1 | ncall: 27948 | eff(%): 12.802 | loglstar:   -inf < 2456.518 <    inf | logz: 2407.977 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:27500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3612it [00:35,  3.84it/s, bound: 406 | nc: 8 | ncall: 29365 | eff(%): 12.300 | loglstar:   -inf < 2398.229 <    inf | logz: 2351.648 +/-    nan | dlogz: 60.082 >  0.089]    /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 3709it [01:02, 59.50it/s, +80 | bound: 420 | nc: 1 | ncall: 30452 | eff(%): 12.443 | loglstar:   -inf < 2457.472 <    inf | logz: 2406.888 +/-    nan | dlogz:  0.752 >  0.089]
# INFO:root:30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3931it [00:59, 65.79it/s, +80 | bound: 456 | nc: 1 | ncall: 32954 | eff(%): 12.172 | loglstar:   -inf < 2522.822 <    inf | logz: 2469.178 +/-    nan | dlogz:  0.923 >  0.089]
# INFO:root:32500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4114it [00:59, 69.06it/s, +80 | bound: 485 | nc: 1 | ncall: 35456 | eff(%): 11.829 | loglstar:   -inf < 2581.589 <    inf | logz: 2525.395 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:35000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4291it [01:03, 68.10it/s, +80 | bound: 514 | nc: 1 | ncall: 37958 | eff(%): 11.515 | loglstar:   -inf < 2664.564 <    inf | logz: 2606.171 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:37500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4430it [01:01, 71.49it/s, +80 | bound: 540 | nc: 1 | ncall: 40496 | eff(%): 11.137 | loglstar:   -inf < 2664.564 <    inf | logz: 2605.384 +/-    nan | dlogz:  0.577 >  0.089]
# INFO:root:40000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4431it [00:00, 19615.58it/s, bound: 540 | nc: 9 | ncall: 40505 | eff(%): 10.939 | loglstar:   -inf < 2594.983 <    inf | logz: 2537.035 +/-    nan | dlogz: 72.756 >  0.089]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 4576it [01:02, 73.73it/s, +80 | bound: 567 | nc: 1 | ncall: 43026 | eff(%): 10.821 | loglstar:   -inf < 2698.743 <    inf | logz: 2636.811 +/-    nan | dlogz:  1.098 >  0.089]
# INFO:root:42500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4686it [00:47,  2.45it/s, bound: 590 | nc: 27 | ncall: 44976 | eff(%): 10.419 | loglstar:   -inf < 2658.537 <    inf | logz: 2596.998 +/-    nan | dlogz: 58.639 >  0.089]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 4709it [01:01, 76.84it/s, +80 | bound: 595 | nc: 1 | ncall: 45531 | eff(%): 10.518 | loglstar:   -inf < 2730.872 <    inf | logz: 2667.291 +/-    nan | dlogz:  1.096 >  0.089]
# INFO:root:45000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4864it [01:01, 79.49it/s, +80 | bound: 626 | nc: 1 | ncall: 48052 | eff(%): 10.289 | loglstar:   -inf < 2738.845 <    inf | logz: 2674.388 +/-    nan | dlogz:  0.529 >  0.089]
# INFO:root:47500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5012it [01:02, 80.73it/s, +80 | bound: 654 | nc: 1 | ncall: 50680 | eff(%): 10.047 | loglstar:   -inf < 2759.102 <    inf | logz: 2692.229 +/-    nan | dlogz:  0.807 >  0.089]
# INFO:root:50000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5326it [01:00, 87.71it/s, +80 | bound: 692 | nc: 1 | ncall: 53184 | eff(%): 10.165 | loglstar:   -inf < 2859.308 <    inf | logz: 2788.058 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:52500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5616it [01:00, 93.18it/s, +80 | bound: 730 | nc: 1 | ncall: 55686 | eff(%): 10.229 | loglstar:   -inf < 3072.715 <    inf | logz: 2997.862 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:55000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5894it [01:00, 97.11it/s, +80 | bound: 771 | nc: 1 | ncall: 58187 | eff(%): 10.267 | loglstar:   -inf < 3220.447 <    inf | logz: 3142.157 +/-    nan | dlogz:  1.088 >  0.089]
# INFO:root:57500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6161it [00:59, 103.33it/s, +80 | bound: 808 | nc: 1 | ncall: 60690 | eff(%): 10.283 | loglstar:   -inf < 3434.970 <    inf | logz: 3353.348 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:60000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6437it [01:00, 106.54it/s, +80 | bound: 847 | nc: 1 | ncall: 63200 | eff(%): 10.312 | loglstar:   -inf < 3660.090 <    inf | logz: 3575.039 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:62500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6695it [01:01, 109.25it/s, +80 | bound: 885 | nc: 1 | ncall: 65704 | eff(%): 10.311 | loglstar:   -inf < 3759.571 <    inf | logz: 3671.316 +/-    nan | dlogz:  1.098 >  0.089]
# INFO:root:65000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6976it [01:00, 115.65it/s, +80 | bound: 924 | nc: 1 | ncall: 68210 | eff(%): 10.345 | loglstar:   -inf < 3952.187 <    inf | logz: 3860.440 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:67500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7260it [01:00, 120.99it/s, +80 | bound: 963 | nc: 1 | ncall: 70711 | eff(%): 10.380 | loglstar:   -inf < 4077.717 <    inf | logz: 3982.442 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:70000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7541it [01:00, 123.97it/s, +80 | bound: 1001 | nc: 1 | ncall: 73215 | eff(%): 10.409 | loglstar:   -inf < 4257.588 <    inf | logz: 4158.822 +/-    nan | dlogz:  1.098 >  0.089]
# INFO:root:72500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7825it [00:57, 136.85it/s, +80 | bound: 1040 | nc: 1 | ncall: 75717 | eff(%): 10.440 | loglstar:   -inf < 4387.491 <    inf | logz: 4285.198 +/-    nan | dlogz:  1.099 >  0.089]
# INFO:root:75000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8111it [00:58, 138.14it/s, +80 | bound: 1082 | nc: 1 | ncall: 78231 | eff(%): 10.470 | loglstar:   -inf < 4425.833 <    inf | logz: 4320.015 +/-    nan | dlogz:  1.079 >  0.089]
# INFO:root:77500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8392it [00:55, 150.13it/s, +80 | bound: 1122 | nc: 1 | ncall: 80735 | eff(%): 10.494 | loglstar:   -inf < 4499.657 <    inf | logz: 4390.346 +/-    nan | dlogz:  1.081 >  0.089]
# INFO:root:80000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8657it [00:55, 155.12it/s, +80 | bound: 1161 | nc: 1 | ncall: 83242 | eff(%): 10.496 | loglstar:   -inf < 4546.359 <    inf | logz: 4433.919 +/-    nan | dlogz:  0.976 >  0.089]
# INFO:root:82500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8923it [00:55, 160.01it/s, +80 | bound: 1199 | nc: 1 | ncall: 85745 | eff(%): 10.500 | loglstar:   -inf < 4580.743 <    inf | logz: 4464.861 +/-    nan | dlogz:  1.064 >  0.089]
# INFO:root:85000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9220it [00:56, 162.48it/s, +80 | bound: 1237 | nc: 1 | ncall: 88252 | eff(%): 10.538 | loglstar:   -inf < 4595.876 <    inf | logz: 4477.820 +/-    nan | dlogz:  0.349 >  0.089]
# INFO:root:87500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9507it [00:56, 168.68it/s, +80 | bound: 1276 | nc: 1 | ncall: 90763 | eff(%): 10.563 | loglstar:   -inf < 4605.699 <    inf | logz: 4484.121 +/-    nan | dlogz:  0.336 >  0.089]
# INFO:root:90000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9811it [00:56, 174.92it/s, +80 | bound: 1314 | nc: 1 | ncall: 93267 | eff(%): 10.605 | loglstar:   -inf < 4610.311 <    inf | logz: 4486.466 +/-    nan | dlogz:  0.085 >  0.089]
# INFO:root:92500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10104it [00:55, 180.59it/s, +80 | bound: 1353 | nc: 1 | ncall: 95774 | eff(%): 10.633 | loglstar:   -inf < 4613.127 <    inf | logz: 4487.083 +/-    nan | dlogz:  0.021 >  0.089]
# INFO:root:95000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10372it [00:55, 187.36it/s, +80 | bound: 1393 | nc: 1 | ncall: 98277 | eff(%): 10.635 | loglstar:   -inf < 4614.542 <    inf | logz: 4487.185 +/-    nan | dlogz:  0.003 >  0.089]
# INFO:root:97500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10491it [00:20, 502.82it/s, +80 | bound: 1408 | nc: 1 | ncall: 99209 | eff(%): 10.655 | loglstar:   -inf < 4615.096 <    inf | logz: 4487.192 +/-    nan | dlogz:  0.001 >  0.089]
# INFO:root:100000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10491it [00:00, 2406740.87it/s, +80 | bound: 1408 | nc: 1 | ncall: 99209 | eff(%): 10.655 | loglstar:   -inf < 4615.096 <    inf | logz: 4487.192 +/-    nan | dlogz:  0.001 >  0.089]
# INFO:root:102500 Iterations: Performing update (Visualization, outputting samples, etc.).
# INFO:root:105000 Iterations: Performing update (Visualization, outputting samples, etc.).
# Dynesty has finished run - you may now continue the notebook.

# %% [markdown]
# And lets look at the fit to the Imaging data, which as we are used to fits the data brilliantly!

# %%
aplt.FitImaging.subplot_fit_imaging(fit=result.max_log_likelihood_fit)

# %% [markdown]
# Up to now, all of our non-linear searches have been successes. They find a lens model that provides a visibly good fit to the data, minimizing the residuals and inferring a high log likelihood value.
#
# These solutions are called ‘global’ maxima, they correspond to the highest likelihood regions of the entirity of parameter space. There are no other lens models in parameter space that would give higher likelihoods - this is the model we wants to always infer!
#
# However, non-linear searches may not always successfully locate the global maxima lens models. They may instead infer a ‘local maxima’, a solution which has a high log likelihood value relative to the lens models near it in parameter space, but whose log likelihood is significantly below the ‘global’ maxima solution somewhere else in parameter space.
#
# Inferring such solutions is essentially a failure of our non-linear search and it is something we do not want to happen! Lets infer a local maxima, by reducing the number of ‘live points’ Dynesty uses to map out parameter space. We’re going to use so few that it has no hope of locating the global maxima, ultimating finding and inferring a local maxima instead.

# %%
phase = al.PhaseImaging(
    phase_name="phase_t3_realism_and_complexity__local_maxima",
    settings=settings,
    galaxies=dict(
        lens_galaxy=al.GalaxyModel(
            redshift=0.5, light=al.lp.EllipticalSersic, mass=al.mp.EllipticalIsothermal
        ),
        source_galaxy=al.GalaxyModel(redshift=1.0, light=al.lp.EllipticalExponential),
    ),
    search=af.DynestyStatic(n_live_points=5),
)

print(
    "Dynesty has begun running - checkout the autolens_workspace/output/3_realism_and_complexity"
    "folder for live output of the results, images and lens model."
    "This Jupyter notebook cell with progress once Dynesty has completed - this could take some time!"
)

result_local_maxima = phase.run(dataset=imaging, mask=mask)

print("Dynesty has finished run - you may now continue the notebook.")
# Out:
# Dynesty has begun running - checkout the autolens_workspace/output/3_realism_and_complexityfolder for live output of the results, images and lens model.This Jupyter notebook cell with progress once Dynesty has completed - this could take some time!
# INFO:root:Generating initial samples of model, which are subject to prior limits and other constraints.
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/dynesty.py:371: UserWarning: Beware! Having `nlive <= 2 * ndim` is extremely risky!
#   warnings.warn("Beware! Having `nlive <= 2 * ndim` is extremely risky!")
# INFO:root:No Dynesty samples found, beginning new non-linear search.
# 21it [00:04,  2.10it/s, bound: 0 | nc: 29 | ncall: 215 | eff(%):  9.767 | loglstar:   -inf < -12710.188 <    inf | logz: -12716.319 +/-    nan | dlogz: 4535.084 >  0.014] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 22it [00:05,  1.67it/s, bound: 1 | nc: 5 | ncall: 220 | eff(%): 10.000 | loglstar:   -inf < -12124.109 <    inf | logz: -12130.422 +/-    nan | dlogz: 3867.396 >  0.014] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 23it [00:05,  2.14it/s, bound: 2 | nc: 5 | ncall: 225 | eff(%): 10.222 | loglstar:   -inf < -11853.713 <    inf | logz: -11860.209 +/-    nan | dlogz: 3281.316 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 26it [00:06,  3.56it/s, bound: 5 | nc: 5 | ncall: 240 | eff(%): 10.833 | loglstar:   -inf < -10631.248 <    inf | logz: -10638.291 +/-    nan | dlogz: 1888.627 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 164it [00:56,  2.90it/s, +5 | bound: 143 | nc: 1 | ncall: 2510 | eff(%):  6.733 | loglstar:   -inf < -1752.117 <    inf | logz: -1784.278 +/-    nan | dlogz:  0.954 >  0.014]
# INFO:root:2500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 522it [00:56,  9.17it/s, +5 | bound: 501 | nc: 1 | ncall: 5022 | eff(%): 10.494 | loglstar:   -inf < -1572.193 <    inf | logz: -1665.780 +/-    nan | dlogz:  0.034 >  0.014]
# INFO:root:5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 851it [00:56, 15.17it/s, +5 | bound: 830 | nc: 1 | ncall: 7527 | eff(%): 11.372 | loglstar:   -inf < -1403.617 <    inf | logz: -1560.379 +/-    nan | dlogz:  0.605 >  0.014]
# INFO:root:7500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1155it [00:55, 20.66it/s, +5 | bound: 1134 | nc: 1 | ncall: 10031 | eff(%): 11.564 | loglstar:   -inf < -566.118 <    inf | logz: -778.884 +/-    nan | dlogz:  0.909 >  0.014]
# INFO:root:10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1291it [00:56, 23.00it/s, +5 | bound: 1270 | nc: 1 | ncall: 12609 | eff(%): 10.278 | loglstar:   -inf < 2332.344 <    inf | logz: 2094.505 +/-    nan | dlogz:  1.083 >  0.014]
# INFO:root:12500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1292it [00:01, 1042.32it/s, bound: 1271 | nc: 56 | ncall: 12665 | eff(%): 10.201 | loglstar:   -inf < 2315.000 <    inf | logz: 2077.980 +/-    nan | dlogz: 20.969 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1304it [00:26,  1.25s/it, bound: 1283 | nc: 84 | ncall: 13811 | eff(%):  9.442 | loglstar:   -inf < 2352.148 <    inf | logz: 2112.534 +/-    nan | dlogz: 22.899 >  0.014]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1308it [00:36,  1.91s/it, bound: 1287 | nc: 44 | ncall: 14290 | eff(%):  9.153 | loglstar:   -inf < 2360.973 <    inf | logz: 2120.599 +/-    nan | dlogz: 13.883 >  0.014] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1311it [00:49,  2.57s/it, bound: 1290 | nc: 5 | ncall: 14846 | eff(%):  8.831 | loglstar:   -inf < 2369.099 <    inf | logz: 2128.111 +/-    nan | dlogz:  9.052 >  0.014]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1312it [00:55, 23.77it/s, +5 | bound: 1291 | nc: 1 | ncall: 15119 | eff(%):  8.711 | loglstar:   -inf < 2374.417 <    inf | logz: 2133.820 +/-    nan | dlogz:  0.513 >  0.014]
# INFO:root:15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 0it [00:00, ?it/s]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1313it [00:05, 221.65it/s, bound: 1292 | nc: 270 | ncall: 15389 | eff(%):  8.532 | loglstar:   -inf < 2371.209 <    inf | logz: 2130.454 +/-    nan | dlogz:  6.295 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1329it [00:35,  1.03s/it, bound: 1308 | nc: 22 | ncall: 16736 | eff(%):  7.941 | loglstar:   -inf < 2382.549 <    inf | logz: 2138.447 +/-    nan | dlogz:  7.850 >  0.014]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1331it [00:42,  1.96s/it, bound: 1310 | nc: 5 | ncall: 17055 | eff(%):  7.804 | loglstar:   -inf < 2384.001 <    inf | logz: 2140.066 +/-    nan | dlogz:  5.513 >  0.014]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1333it [00:50,  2.88s/it, bound: 1312 | nc: 80 | ncall: 17443 | eff(%):  7.642 | loglstar:   -inf < 2384.148 <    inf | logz: 2140.829 +/-    nan | dlogz:  3.973 >  0.014] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1334it [01:00, 22.14it/s, +5 | bound: 1313 | nc: 1 | ncall: 17885 | eff(%):  7.487 | loglstar:   -inf < 2387.344 <    inf | logz: 2143.233 +/-    nan | dlogz:  0.342 >  0.014]
# INFO:root:17500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1335it [00:04, 332.47it/s, bound: 1314 | nc: 173 | ncall: 18058 | eff(%):  7.393 | loglstar:   -inf < 2385.357 <    inf | logz: 2141.452 +/-    nan | dlogz:  3.123 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1346it [00:25,  1.30s/it, bound: 1325 | nc: 69 | ncall: 18991 | eff(%):  7.088 | loglstar:   -inf < 2388.206 <    inf | logz: 2143.314 +/-    nan | dlogz:  2.974 >  0.014]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1347it [00:32,  3.18s/it, bound: 1326 | nc: 346 | ncall: 19337 | eff(%):  6.966 | loglstar:   -inf < 2388.603 <    inf | logz: 2143.431 +/-    nan | dlogz:  2.709 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1351it [00:45,  2.56s/it, bound: 1330 | nc: 67 | ncall: 19903 | eff(%):  6.788 | loglstar:   -inf < 2389.831 <    inf | logz: 2143.863 +/-    nan | dlogz:  1.683 >  0.014] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1353it [00:55,  3.73s/it, bound: 1332 | nc: 125 | ncall: 20379 | eff(%):  6.639 | loglstar:   -inf < 2390.611 <    inf | logz: 2144.132 +/-    nan | dlogz:  1.235 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1354it [01:08, 19.81it/s, +5 | bound: 1333 | nc: 1 | ncall: 20927 | eff(%):  6.494 | loglstar:   -inf < 2391.381 <    inf | logz: 2144.903 +/-    nan | dlogz:  0.107 >  0.014]
# INFO:root:20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1355it [00:01, 719.39it/s, bound: 1334 | nc: 86 | ncall: 21013 | eff(%):  6.448 | loglstar:   -inf < 2390.902 <    inf | logz: 2144.387 +/-    nan | dlogz:  0.829 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1356it [00:20, 719.39it/s, bound: 1335 | nc: 436 | ncall: 21449 | eff(%):  6.322 | loglstar:   -inf < 2391.276 <    inf | logz: 2144.500 +/-    nan | dlogz:  1.253 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1359it [00:51,  4.81s/it, bound: 1338 | nc: 216 | ncall: 23263 | eff(%):  5.842 | loglstar:   -inf < 2391.381 <    inf | logz: 2144.750 +/-    nan | dlogz:  0.730 >  0.014] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1360it [00:57, 23.61it/s, +5 | bound: 1339 | nc: 1 | ncall: 23558 | eff(%):  5.794 | loglstar:   -inf < 2392.349 <    inf | logz: 2145.059 +/-    nan | dlogz:  0.082 >  0.014]
# INFO:root:22500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1361it [00:00, 11827.38it/s, bound: 1340 | nc: 5 | ncall: 23563 | eff(%):  5.776 | loglstar:   -inf < 2391.477 <    inf | logz: 2144.847 +/-    nan | dlogz:  0.509 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1363it [00:20, 11827.38it/s, bound: 1342 | nc: 764 | ncall: 24332 | eff(%):  5.602 | loglstar:   -inf < 2391.705 <    inf | logz: 2144.918 +/-    nan | dlogz:  0.354 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1369it [00:33,  1.13it/s, bound: 1348 | nc: 25 | ncall: 25058 | eff(%):  5.463 | loglstar:   -inf < 2392.122 <    inf | logz: 2145.048 +/-    nan | dlogz:  0.115 >  0.014]    /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1378it [00:48,  1.45s/it, bound: 1357 | nc: 142 | ncall: 25761 | eff(%):  5.349 | loglstar:   -inf < 2392.348 <    inf | logz: 2145.116 +/-    nan | dlogz:  0.026 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1379it [00:57, 23.97it/s, +5 | bound: 1358 | nc: 1 | ncall: 26164 | eff(%):  5.290 | loglstar:   -inf < 2392.658 <    inf | logz: 2145.133 +/-    nan | dlogz:  0.003 >  0.014]
# INFO:root:25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1380it [00:01, 1199.10it/s, bound: 1359 | nc: 52 | ncall: 26216 | eff(%):  5.264 | loglstar:   -inf < 2392.365 <    inf | logz: 2145.121 +/-    nan | dlogz:  0.020 >  0.014]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1382it [00:07, 184.69it/s, +5 | bound: 1361 | nc: 1 | ncall: 26504 | eff(%):  5.233 | loglstar:   -inf < 2392.658 <    inf | logz: 2145.135 +/-    nan | dlogz:  0.002 >  0.014]
# INFO:root:27500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1382it [00:00, 1293290.52it/s, +5 | bound: 1361 | nc: 1 | ncall: 26504 | eff(%):  5.233 | loglstar:   -inf < 2392.658 <    inf | logz: 2145.135 +/-    nan | dlogz:  0.002 >  0.014]
# INFO:root:30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# INFO:root:32500 Iterations: Performing update (Visualization, outputting samples, etc.).
# Dynesty has finished run - you may now continue the notebook.

# %% [markdown]
# And lets look at the fit to the Imaging data, which is clearly worse than our original fit above.

# %%
aplt.FitImaging.subplot_fit_imaging(fit=result_local_maxima.max_log_likelihood_fit)

# %% [markdown]
# Finally, just to be sure we hit a local maxima, lets compare the maximum log likelihood values of the two results
#
# The local maxima value is significantly lower, confirming that our non-linear search simply failed to locate lens models which fit the data better when it searched parameter space.

# %%
print("Likelihood of Global Model:")
print(result.max_log_likelihood_fit.log_likelihood)
print("Likelihood of Local Model:")
print(result_local_maxima.max_log_likelihood_fit.log_likelihood)
# Out:
# Likelihood of Global Model:
# 4615.096128255619
# Likelihood of Local Model:
# 2392.6578296783737

# %% [markdown]
# In this example, we intentionally made our non-linear search fail, by using so few live points it had no hope of sampling parameter space thoroughly. For modeling real lenses we wouldn’t do this on purpose, but the risk of inferring a local maxima is still very real, especially as we make our lens model more complex.
#
# Lets think about ‘complexity’. As we make our lens model more realistic, we also made it more complex. For this tutorial, our non-linear parameter space went from 7 dimensions to 18. This means there was a much larger ‘volume’ of parameter space to search. As this volume grows, there becomes a higher chance that our non-linear search gets lost and infers a local maxima, especially if we don’t set it up with enough live points!
#
# At its core, lens modeling is all about learning how to get a non-linear search to find the global maxima region of parameter space, even when the lens model is extremely complex.
#
# And with that, we’re done. In the next exercise, we’ll learn how to deal with failure and begin thinking about how we can ensure our non-linear search finds the global-maximum log likelihood solution.
