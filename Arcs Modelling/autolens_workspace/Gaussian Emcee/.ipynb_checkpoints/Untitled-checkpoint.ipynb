# %%
import autolens as al
import autolens.plot as aplt
from pyprojroot import here
import numpy as np

from time import perf_counter as clock

from astropy.cosmology import Planck15 as cosmo
from astropy.constants import G, M_sun, c
import astropy.units as u

workspace_path = str(here())
print("Workspace Path: ", workspace_path)
# Out:
# ---------------------------------------------------------------------------
# NoSectionError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/autoconf/named.py in get(self, section_name, attribute_name, attribute_type)
#      48         try:
# ---> 49             string_value = self.parser.get(section_name, attribute_name)
#      50         except configparser.NoSectionError:
#
# ~/anaconda3/lib/python3.7/configparser.py in get(self, section, option, raw, vars, fallback)
#     779         try:
# --> 780             d = self._unify_values(section, vars)
#     781         except NoSectionError:
#
# ~/anaconda3/lib/python3.7/configparser.py in _unify_values(self, section, vars)
#    1145             if section != self.default_section:
# -> 1146                 raise NoSectionError(section) from None
#    1147         # Update with the entry specific variables
#
# NoSectionError: No section: 'general'
#
# During handling of the above exception, another exception occurred:
#
# NoSectionError                            Traceback (most recent call last)
# <ipython-input-1-954ffba1b11e> in <module>
# ----> 1 import autolens as al
#       2 import autolens.plot as aplt
#       3 from pyprojroot import here
#       4 import numpy as np
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/autolens/__init__.py in <module>
# ----> 1 from autoarray import conf
#       2 from autoarray import preprocess
#       3 from autoarray.dataset.imaging import Imaging
#       4 from autoarray.dataset.interferometer import Interferometer
#       5 from autoarray.mask.mask import Mask
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/__init__.py in <module>
#       1 from autoconf import conf
#       2 from . import exc
# ----> 3 from . import plot
#       4 from . import util
#       5 from .dataset import preprocess
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/plot/__init__.py in <module>
# ----> 1 from autoarray.plot.mat_objs import (
#       2     Units,
#       3     Figure,
#       4     ColorMap,
#       5     ColorBar,
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/plot/mat_objs.py in <module>
#       2 import matplotlib
#       3
# ----> 4 backend = conf.get_matplotlib_backend()
#       5
#       6 if not backend in "default":
#
# ~/anaconda3/lib/python3.7/site-packages/autoconf/conf.py in get_matplotlib_backend()
#       7
#       8 def get_matplotlib_backend():
# ----> 9     return instance.visualize_general.get("general", "backend", str)
#      10
#      11
#
# ~/anaconda3/lib/python3.7/site-packages/autoconf/named.py in get(self, section_name, attribute_name, attribute_type)
#      51             raise configparser.NoSectionError(
#      52                 "Could not find section {} in config at path {}".format(
# ---> 53                     section_name, self.path
#      54                 )
#      55             )
#
# NoSectionError: No section: 'Could not find section general in config at path /home/carlos/anaconda3/lib/python3.7/site-packages/autoconf/../autolens_workspace/config/visualize/general.ini'
