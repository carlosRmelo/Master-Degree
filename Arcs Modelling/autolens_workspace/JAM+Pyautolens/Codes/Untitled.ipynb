# %%
import emcee
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "Pyautolens+Jampy.h5"
reader = emcee.backends.HDFBackend(filename)

# %%
reader.iteration
tau = reader.get_autocorr_time()
tau
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/emcee/autocorr.py:36: RuntimeWarning: invalid value encountered in true_divide
#   acf /= acf[0]
# /home/carlos/anaconda3/lib/python3.7/site-packages/emcee/autocorr.py:41: RuntimeWarning: invalid value encountered in less
#   m = np.arange(len(taus)) < c * taus
# /home/carlos/anaconda3/lib/python3.7/site-packages/emcee/autocorr.py:99: RuntimeWarning: invalid value encountered in greater
#   flag = tol * tau_est > n_t
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan])

# %%
samples = reader.get_chain()
fig, axes = plt.subplots(20, figsize=(10, 50), sharex=True)
labels = ["ml1-2", "ml3", "ml4","ml5","ml6","ml7","b1", "b2", "b3", "b4","b5","b6","b7",
              "Inc", "qDM", "Log rho_s", "Log mbh", "Mag Shear", "Phi Shear", "gamma"]
for i in range(20):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");

# %%
tau = reader.get_autocorr_time()
print(tau)
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/emcee/autocorr.py:36: RuntimeWarning: invalid value encountered in true_divide
#   acf /= acf[0]
# /home/carlos/anaconda3/lib/python3.7/site-packages/emcee/autocorr.py:41: RuntimeWarning: invalid value encountered in less
#   m = np.arange(len(taus)) < c * taus
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
# /home/carlos/anaconda3/lib/python3.7/site-packages/emcee/autocorr.py:99: RuntimeWarning: invalid value encountered in greater
#   flag = tol * tau_est > n_t

# %%
flat_samples = reader.get_chain(discard=0, thin=1, flat=True)
print(flat_samples.shape)
# Out:
# (118850, 20)

# %%
import corner

fig = corner.corner(
    flat_samples, labels=labels
);
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# ...

# %%
from IPython.display import display, Math

values = []
for i in range(20):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    values.append(mcmc[1])
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{ml1-2} = 4.664_{-2.837}^{3.666}$
# $\displaystyle \mathrm{ml3} = 5.410_{-2.979}^{4.036}$
# $\displaystyle \mathrm{ml4} = 5.075_{-3.122}^{3.943}$
# $\displaystyle \mathrm{ml5} = 5.019_{-3.060}^{3.210}$
# $\displaystyle \mathrm{ml6} = 4.124_{-2.317}^{3.838}$
# $\displaystyle \mathrm{ml7} = 4.578_{-3.451}^{4.220}$
# $\displaystyle \mathrm{b1} = -0.135_{-0.372}^{0.377}$
# $\displaystyle \mathrm{b2} = -0.445_{-0.354}^{0.294}$
# $\displaystyle \mathrm{b3} = 0.896_{-0.217}^{0.258}$
# $\displaystyle \mathrm{b4} = -2.986_{-0.300}^{0.405}$
# $\displaystyle \mathrm{b5} = 0.951_{-0.423}^{0.274}$
# $\displaystyle \mathrm{b6} = 0.214_{-0.323}^{0.326}$
# $\displaystyle \mathrm{b7} = 0.795_{-0.323}^{0.408}$
# $\displaystyle \mathrm{Inc} = 90.854_{-3.488}^{3.140}$
# $\displaystyle \mathrm{qDM} = 0.722_{-0.257}^{0.187}$
# $\displaystyle \mathrm{Log rho_s} = 5.037_{-2.831}^{2.977}$
# $\displaystyle \mathrm{Log mbh} = 9.465_{-0.267}^{0.399}$
# ...
