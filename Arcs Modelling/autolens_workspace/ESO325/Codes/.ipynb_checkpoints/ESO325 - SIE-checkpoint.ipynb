# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 08/10/2020
#
# Obj: Modelar ESO325 com um perfil de An _EllipticalSersic LightProfile for the lens galaxy’s light e EllipticalIsothermal (SIE) MassProfile for the lens galaxy’s mass. A fonte será obtida a partir da inversão em uma grid regular.

# %%
from autoconf import conf
import autofit as af  # <- This library is used for non-linear fitting.
import autolens as al
import autolens.plot as aplt


from time import perf_counter as clock

from astropy.cosmology import Planck15 as cosmo
from astropy.constants import G, M_sun, c
import astropy.units as u
import numpy as np

# %%
from pyprojroot import here

workspace_path = str(here())
print("Workspace Path: ", workspace_path)

conf.instance = conf.Config(
    config_path=f"{workspace_path}/howtolens/config",
    output_path=f"{workspace_path}/ESO325/Output/Rectangular",
)
# Out:
# Workspace Path:  /home/carlos/autolens_workspace

# %%
#Reading data

dataset_type = "ESO325"
dataset_name = "Data"
dataset_path = f"{workspace_path}/{dataset_type}/{dataset_name}"

imaging = al.Imaging.from_fits(
    image_path=f"{dataset_path}/image.fits", image_hdu=1,
    noise_map_path=f"{dataset_path}/noise_map.fits",
    psf_path=f"{dataset_path}/psf.fits",
    pixel_scales=0.04,
)

# %%
plotter = aplt.SubPlotter(cmap=aplt.ColorMap.sub(norm_min=0, norm_max=10))

# %%
mask = al.Mask.circular(
    shape_2d=imaging.shape_2d, pixel_scales=imaging.pixel_scales, sub_size=1,radius=8 ,centre=(0, 0)
)

masked_imaging = al.MaskedImaging(imaging=imaging, mask=mask)

aplt.Imaging.subplot_imaging(sub_plotter=plotter,
    imaging=imaging, mask=mask, include=aplt.Include(border=True),
)

# %%
settings = al.PhaseSettingsImaging(grid_class=al.Grid, sub_size=2)

# %%
elliptical_comps = al.convert.elliptical_comps_from(axis_ratio=1-0.25, phi=45.0+90)

print(elliptical_comps)
# Out:
# (-0.14285714285714285, -2.6242431410300424e-17)

# %%
#Defindo os parâmetros da lente

lens_galaxy=al.GalaxyModel(redshift=0.035, mass=al.mp.EllipticalIsothermal, light=al.lp.EllipticalSersic)

#Componentes do perfil de luz
lens_galaxy.light.centre_0 = af.UniformPrior(lower_limit=-0.1, upper_limit=0.1)
lens_galaxy.light.centre_1 = af.UniformPrior(lower_limit=-0.1, upper_limit=0.1)
lens_galaxy.light.sersic_index = af.UniformPrior(lower_limit=0.5, upper_limit=5.0)
lens_galaxy.light.elliptical_comps_0 = af.GaussianPrior(mean=-0.14285714285714285, sigma=0.1, lower_limit=-1.0, upper_limit=1.0)
lens_galaxy.light.elliptical_comps_0 = af.GaussianPrior(mean=0, sigma=0.1, lower_limit=-1.0, upper_limit=1.0)

#Componentes do perfil de matéria
lens_galaxy.mass.einstein_radius = af.GaussianPrior(mean=2.95, sigma=0.5, lower_limit=0.0, upper_limit=np.inf)

# %%
phase = al.PhaseImaging(
        phase_name="ESO325_sie",
        galaxies=dict(
            lens=lens_galaxy,
            source=al.GalaxyModel(redshift=2.1, pixelization=al.pix.Rectangular(shape=(25,25)), regularization=al.reg.Constant),
        ),
        settings=settings,
        search=af.DynestyStatic(n_live_points=50),
    )

# %%
result =  phase.run(dataset=imaging, mask=mask)
# Out:
# INFO:root:Generating initial samples of model, which are subject to prior limits and other constraints.
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/dynesty.py:373: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# INFO:root:No Dynesty samples found, beginning new non-linear search.
# 163it [2:11:08, 158.71s/it, bound: 0 | nc: 49 | ncall: 1668 | eff(%):  9.772 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:    inf >  0.059]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 169it [2:15:45, 55.40s/it, bound: 2 | nc: 7 | ncall: 1714 | eff(%):  9.860 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:    inf >  0.059]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 175it [2:22:45, 59.52s/it, bound: 3 | nc: 8 | ncall: 1783 | eff(%):  9.815 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:    inf >  0.059] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 181it [2:28:47, 47.09s/it, bound: 5 | nc: 5 | ncall: 1834 | eff(%):  9.869 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:    inf >  0.059] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 198it [2:46:31, 43.69s/it, bound: 8 | nc: 5 | ncall: 1994 | eff(%):  9.930 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:    inf >  0.059]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 249it [4:02:42, 58.48s/it, +50 | bound: 19 | nc: 1 | ncall: 2553 | eff(%): 11.712 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# INFO:root:2500 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/profiles/mass_profiles/total_mass_profiles.py:522: UserWarning: [pyquad] Cannot reach tolerance because of roundoff error.
#   args=(self.axis_ratio, self.slope, self.core_radius),
# 267it [31:33, 100.33s/it, bound: 25 | nc: 13 | ncall: 2804 | eff(%):  9.522 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:    inf >  0.059]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 303it [1:37:08, 108.08s/it, bound: 34 | nc: 14 | ncall: 3349 | eff(%):  9.047 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:    inf >  0.059]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 421it [5:25:01, 46.32s/it, +50 | bound: 59 | nc: 1 | ncall: 5061 | eff(%):  9.306 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# INFO:root:5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/profiles/mass_profiles/total_mass_profiles.py:522: UserWarning: [pyquad] Cannot reach tolerance because of roundoff error.
#   args=(self.axis_ratio, self.slope, self.core_radius),
# 670it [5:10:48, 27.83s/it, +50 | bound: 112 | nc: 1 | ncall: 7564 | eff(%):  9.519 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:  1.099 >  0.059]
# INFO:root:7500 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/profiles/mass_profiles/total_mass_profiles.py:522: UserWarning: [pyquad] Cannot reach tolerance because of roundoff error.
#   args=(self.axis_ratio, self.slope, self.core_radius),
# 672it [01:15, 12.68s/it, bound: 112 | nc: 5 | ncall: 7574 | eff(%):  8.872 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-    nan | dlogz:    inf >  0.059]
