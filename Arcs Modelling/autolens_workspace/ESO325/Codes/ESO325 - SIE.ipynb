# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 08/10/2020
#
# Obj: Modelar ESO325 com um perfil de An _EllipticalSersic LightProfile for the lens galaxy’s light e EllipticalIsothermal (SIE) MassProfile for the lens galaxy’s mass. A fonte será obtida a partir da inversão em uma grid regular.

# %%
from autoconf import conf
import autofit as af  # <- This library is used for non-linear fitting.
import autolens as al
import autolens.plot as aplt


from time import perf_counter as clock

from astropy.cosmology import Planck15 as cosmo
from astropy.constants import G, M_sun, c
import astropy.units as u
import numpy as np

# %%
from pyprojroot import here

workspace_path = str(here())
print("Workspace Path: ", workspace_path)

conf.instance = conf.Config(
    config_path=f"{workspace_path}/howtolens/config",
    output_path=f"{workspace_path}/ESO325/Output/Rectangular",
)
# Out:
# Workspace Path:  /home/carlos/autolens_workspace

# %%
#Reading data

dataset_type = "ESO325"
dataset_name = "Data"
dataset_path = f"{workspace_path}/{dataset_type}/{dataset_name}"

imaging = al.Imaging.from_fits(
    image_path=f"{dataset_path}/image.fits", image_hdu=1,
    noise_map_path=f"{dataset_path}/noise_map.fits",
    psf_path=f"{dataset_path}/psf.fits",
    pixel_scales=0.04,
)

# %%
plotter = aplt.SubPlotter(cmap=aplt.ColorMap.sub(norm_min=0, norm_max=10))

# %%
mask = al.Mask.circular(
    shape_2d=imaging.shape_2d, pixel_scales=imaging.pixel_scales, sub_size=1,radius=8 ,centre=(0, 0)
)

masked_imaging = al.MaskedImaging(imaging=imaging, mask=mask)
'''
aplt.Imaging.subplot_imaging(sub_plotter=plotter,
    imaging=imaging, mask=mask, include=aplt.Include(border=True),
)
'''
# Out:
# '\naplt.Imaging.subplot_imaging(sub_plotter=plotter,\n    imaging=imaging, mask=mask, include=aplt.Include(border=True),\n)\n'

# %%
settings = al.PhaseSettingsImaging(grid_class=al.Grid, sub_size=2)

# %%
elliptical_comps = al.convert.elliptical_comps_from(axis_ratio=1-0.25, phi=45.0+90)

print(elliptical_comps)
# Out:
# (-0.14285714285714285, -2.6242431410300424e-17)

# %%
#Defindo os parâmetros da lente

lens_galaxy=al.GalaxyModel(redshift=0.035, mass=al.mp.EllipticalIsothermal, light=al.lp.EllipticalSersic)

#Componentes do perfil de luz
lens_galaxy.light.centre.centre_0 = af.UniformPrior(lower_limit=-0.1, upper_limit=0.1)
lens_galaxy.light.centre.centre_1 = af.UniformPrior(lower_limit=-0.1, upper_limit=0.1)
lens_galaxy.light.sersic_index = af.UniformPrior(lower_limit=0.5, upper_limit=5.0)
lens_galaxy.light.elliptical_comps.elliptical_comps_0 = af.GaussianPrior(mean=-0.14285714285714285, sigma=0.1, lower_limit=-1.0, upper_limit=1.0)
lens_galaxy.light.elliptical_comps.elliptical_comps_1 = af.GaussianPrior(mean=0, sigma=0.1, lower_limit=-1.0, upper_limit=1.0)

#Componentes do perfil de matéria
lens_galaxy.mass.einstein_radius = af.GaussianPrior(mean=2.95, sigma=0.5, lower_limit=0.0, upper_limit=np.inf)

print(lens_galaxy.light.info)
print(lens_galaxy.mass.info)
# Out:
# centre
#     centre_0                                                                              UniformPrior, lower_limit = -0.1, upper_limit = 0.1
#     centre_1                                                                              UniformPrior, lower_limit = -0.1, upper_limit = 0.1
# elliptical_comps
#     elliptical_comps_0                                                                    GaussianPrior, mean = -0.14285714285714285, sigma = 0.1
#     elliptical_comps_1                                                                    GaussianPrior, mean = 0.0, sigma = 0.1
# intensity                                                                                 LogUniformPrior, lower_limit = 1e-06, upper_limit = 1000000.0
# effective_radius                                                                          UniformPrior, lower_limit = 0.0, upper_limit = 30.0
# sersic_index                                                                              UniformPrior, lower_limit = 0.5, upper_limit = 5.0
# centre
#     centre_0                                                                              GaussianPrior, mean = 0.0, sigma = 0.3
#     centre_1                                                                              GaussianPrior, mean = 0.0, sigma = 0.3
# elliptical_comps
#     elliptical_comps_0                                                                    UniformPrior, lower_limit = -1.0, upper_limit = 1.0
#     elliptical_comps_1                                                                    UniformPrior, lower_limit = -1.0, upper_limit = 1.0
# einstein_radius                                                                           GaussianPrior, mean = 2.95, sigma = 0.5

# %%
phase = al.PhaseImaging(
        phase_name="ESO325_sie",
        galaxies=dict(
            lens=lens_galaxy,
            source=al.GalaxyModel(redshift=2.1, pixelization=al.pix.Rectangular(shape=(25,25)), regularization=al.reg.Constant),
        ),
        settings=settings,
        search=af.DynestyStatic(n_live_points=50),
    )

# %%
result =  phase.run(dataset=imaging, mask=mask)
# Out:
# INFO:root:Generating initial samples of model, which are subject to prior limits and other constraints.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-1071d05b07d7> in <module>
# ----> 1 result =  phase.run(dataset=imaging, mask=mask)
#
# ~/anaconda3/lib/python3.7/site-packages/autogalaxy/pipeline/phase/dataset/phase.py in run(self, dataset, mask, results, info)
#      77         self.save_phase_attributes(phase_attributes=phase_attributes)
#      78
# ---> 79         result = self.run_analysis(analysis=analysis, info=info)
#      80
#      81         return self.make_result(result=result, analysis=analysis)
#
# ~/anaconda3/lib/python3.7/site-packages/autofit/tools/phase.py in run_analysis(self, analysis, info)
#     149
#     150     def run_analysis(self, analysis, info=None):
# --> 151         return self.search.fit(model=self.model, analysis=analysis, info=info)
#     152
#     153     def make_phase_attributes(self, analysis):
#
# ~/anaconda3/lib/python3.7/site-packages/autofit/non_linear/abstract_search.py in fit(self, model, analysis, info)
#     228             self.timer.start()
#     229
# --> 230             self._fit(model=model, analysis=analysis)
#     231             open(self.paths.has_completed_path, "w+").close()
#     232
#
# ~/anaconda3/lib/python3.7/site-packages/autofit/non_linear/nest/dynesty.py in _fit(self, model, analysis)
#     294
#     295             sampler = self.sampler_fom_model_and_fitness(
# --> 296                 model=model, fitness_function=fitness_function
#     297             )
#     298
#
# ~/anaconda3/lib/python3.7/site-packages/autofit/non_linear/nest/dynesty.py in sampler_fom_model_and_fitness(self, model, fitness_function)
#     666
#     667         live_points = self.initial_live_points_from_model_and_fitness_function(
# --> 668             model=model, fitness_function=fitness_function
#     669         )
#     670
#
# ~/anaconda3/lib/python3.7/site-packages/autofit/non_linear/nest/dynesty.py in initial_live_points_from_model_and_fitness_function(self, model, fitness_function)
#     481             total_points=self.n_live_points,
#     482             model=model,
# --> 483             fitness_function=fitness_function,
#     484         )
#     485
#
# ~/anaconda3/lib/python3.7/site-packages/autofit/non_linear/initializer.py in initial_samples_from_model(self, total_points, model, fitness_function)
#      76             try:
#      77                 figure_of_merit = fitness_function.figure_of_merit_from_parameters(
# ---> 78                     parameters=parameters
#      79                 )
#      80                 initial_unit_parameters.append(unit_parameters)
#
# ~/anaconda3/lib/python3.7/site-packages/autofit/non_linear/nest/abstract_nest.py in figure_of_merit_from_parameters(self, parameters)
#     115             """
#     116             try:
# --> 117                 return self.log_likelihood_from_parameters(parameters=parameters)
#     118             except exc.FitException:
#     119                 raise exc.FitException
#
# ~/anaconda3/lib/python3.7/site-packages/autofit/non_linear/abstract_search.py in log_likelihood_from_parameters(self, parameters)
#     141         def log_likelihood_from_parameters(self, parameters):
#     142             instance = self.model.instance_from_vector(vector=parameters)
# --> 143             log_likelihood = self.fit_instance(instance)
#     144             return log_likelihood
#     145
#
# ~/anaconda3/lib/python3.7/site-packages/autofit/non_linear/abstract_search.py in fit_instance(self, instance)
#     123         def fit_instance(self, instance):
#     124
# --> 125             log_likelihood = self.analysis.log_likelihood_function(instance=instance)
#     126
#     127             if self.analysis.log_likelihood_cap is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/autolens/pipeline/phase/imaging/analysis.py in log_likelihood_function(self, instance)
#      76                 tracer=tracer,
#      77                 hyper_image_sky=hyper_image_sky,
# ---> 78                 hyper_background_noise=hyper_background_noise,
#      79             )
#      80
#
# ~/anaconda3/lib/python3.7/site-packages/autolens/pipeline/phase/imaging/analysis.py in masked_imaging_fit_for_tracer(self, tracer, hyper_image_sky, hyper_background_noise)
#      91             tracer=tracer,
#      92             hyper_image_sky=hyper_image_sky,
# ---> 93             hyper_background_noise=hyper_background_noise,
#      94         )
#      95
#
# ~/anaconda3/lib/python3.7/site-packages/autolens/fit/fit.py in __init__(self, masked_imaging, tracer, hyper_image_sky, hyper_background_noise)
#      64                 inversion_uses_border=masked_imaging.inversion_uses_border,
#      65                 preload_sparse_grids_of_planes=masked_imaging.preload_sparse_grids_of_planes,
# ---> 66                 inversion_stochastic=masked_imaging.inversion_stochastic,
#      67             )
#      68
#
# ~/anaconda3/lib/python3.7/site-packages/autolens/lens/ray_tracing.py in inversion_imaging_from_grid_and_data(self, grid, image, noise_map, convolver, inversion_uses_border, preload_sparse_grids_of_planes, inversion_stochastic)
#     802             convolver=convolver,
#     803             mapper=mappers_of_planes[-1],
# --> 804             regularization=self.regularizations_of_planes[-1],
#     805         )
#     806
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/operators/inversion/inversions.py in from_data_mapper_and_regularization(cls, image, noise_map, convolver, mapper, regularization, check_solution)
#     247
#     248         blurred_mapping_matrix = convolver.convolve_mapping_matrix(
# --> 249             mapping_matrix=mapper.mapping_matrix
#     250         )
#     251
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/operators/convolver.py in convolve_mapping_matrix(self, mapping_matrix)
#     448             image_frame_1d_indexes=self.image_frame_1d_indexes,
#     449             image_frame_1d_kernels=self.image_frame_1d_kernels,
# --> 450             image_frame_1d_lengths=self.image_frame_1d_lengths,
#     451         )
#     452
#
# KeyboardInterrupt:
