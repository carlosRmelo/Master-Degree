# %%
#General packages
import numpy as np
import emcee
import matplotlib.pyplot as plt

#Own packages
import My_Jampy
import model_data
from model_data import Global_Parameters as GP 
from model_data import Jampy_data as JP_data
from model_data import Autolens_data as AL_data
import emcee_probabilities
from emcee_probabilities import Probability 

#MPI packages and control paralelization
from time import perf_counter as clock
from multiprocessing import Pool
from schwimmbad import MPIPool
import time
import os

os.environ["OMP_NUM_THREADS"] = "1"

#Autolens Model packages

import autolens as al
import autolens.plot as aplt
#print("Pyautolens version:", al.__version__)

from pyprojroot import here

from time import perf_counter as clock

from astropy.cosmology import Planck15 as cosmo
from astropy.constants import G, M_sun, c
import astropy.units as u
workspace_path = str(here())
#print("Workspace Path: ", workspace_path)

# %%
# JAMPY MODEL

#Initializing the dynamic model
Jampy_Model = My_Jampy.Jam_axi_rms(ybin=JP_data.ybin, xbin=JP_data.xbin, beta=JP_data.beta, mbh=GP.mbh.value, distance=GP.distance.value, surf_lum=GP.surf_star_dat.value, sigma_lum=GP.sigma_star_dat_ARC.value, qobs_lum=GP.qstar_dat, surf_DM=GP.surf_DM_dat.value, sigma_DM=GP.sigma_DM_dat_ARC.value, qobs_DM=GP.qDM_dat, ml=GP.ML.value, goodBins=JP_data.goodBins, sigmapsf=JP_data.sigmapsf, rms=JP_data.rms, erms=JP_data.erms, pixsize=JP_data.pixsize, inc=GP.inc, quiet=False)
# Out:
# Jampy Class successfully initialized!!

# %%
# Pyautolens Model

### __Reading simulated data__

#Paths
dataset_type = "JAM+Pyautolens"
dataset_name = "Data"
dataset_path = f"/home/carlos/Documents/GitHub/Master-Degree/ESO325/Arcs Modelling/autolens_workspace/{dataset_type}/{dataset_name}"

#Load data
imaging = al.Imaging.from_fits(
    image_path=f"{dataset_path}/arcs_resized.fits",
    noise_map_path=f"{dataset_path}/noise_map_resized.fits",
    psf_path=f"{dataset_path}/psf.fits",
    pixel_scales=0.04,
)

#Load mask
mask_custom = al.Mask.from_fits(
    file_path=f"{dataset_path}/mask gui.fits", hdu=0, pixel_scales=imaging.pixel_scales
)

masked_imaging = al.MaskedImaging(imaging=imaging, mask=mask_custom)

#Plot
'''
aplt.Imaging.subplot_imaging(
    imaging=imaging, mask=mask_custom, include=aplt.Include(border=True)
)
'''

### __Defining the MGE mass model__

#Initializing the MGE  model for lens

mass_profile = al.mp.MGE(centre=(0.0, 0.0))                               #Defining the mass model
mass_profile.MGE_comps(M=AL_data.Total_Mass.value, sigma=AL_data.Total_sigma_RAD.value, q=AL_data.Total_q_proj.value, z_l=GP.z_lens, z_s=GP.z_source)        #Input data

mass_profile.MGE_Grid_parameters(masked_imaging.grid)               #Creating the parameter grid for the parallel calculation

#Lens Model
lens_galaxy = al.Galaxy(                                            
        redshift=GP.z_lens,
        mass=mass_profile,
        shear=al.mp.ExternalShear(elliptical_comps=(0,0)),
    )

# %%
### Priors
# parameter boundaries. [lower, upper]
boundary = {'inc': [70, 120], 'beta': [-5, 5], 'ml': [0.5, 15], 'log_mbh':[7, 11], 'qDM': [0.15, 1],
                'log_rho_s':[6, 13], 'mag_shear': [-0.2, 0.2], 'phi_shear': [-0.2, 0.2],
                'gamma': [-2, 2]
               }

# parameter gaussian priors. [mean, sigma]
prior = {'inc': [90, 10], 'beta': [0.0, 2], 'ml': [1.0, 5],'log_mbh':[8, 3], 'qDM': [0.5, 3e-1],
            'log_rho_s':[10, 4], 'mag_shear': [0, 0.1], 'phi_shear': [0, 0.1], 'gamma': [1.0, 0.5]
            }

# %%
ml = np.zeros((50,6))
ml[:] = np.array([9.5,8.5,3.8,3.4,3.2,2.8])
ml_noise = np.random.rand(50,6)

beta = np.zeros((50,7))
beta[:] = np.array([-0.6, -1.0, 0.34, -3.4, 0.39, -0.31, 0.36])
beta_noise = np.random.rand(50,7)

ml = ml + ml_noise                                                               #Between [2.8, 10.5]
beta = beta + beta_noise                                                         #Between [-3.4, 1.39]
inc = prior ['inc'][0] + (np.random.rand(50,1) -0.5)*10                          #Between [85, 95]
qDM = np.random.rand(50,1)*0.74+0.26                                             #Between [0.26, 1]
log_rho_s = np.random.rand(50,1)*prior['log_rho_s'][0]                           #Between [0, 10]
log_mbh =  np.random.rand(50,1)+9.0                                              #Between [9.0, 10]
mag_shear = (np.random.rand(50,1) - 0.5)*0.2                                     #Between [-0.1, 0.1]
phi_shear = (np.random.rand(50,1) - 0.5)*0.2                                     #Between [-0.1, 0.1]
gamma = (np.random.rand(50,1) - 0.5)*2                                           #Between [-1, 1]
    #50 walkers in a 21-D space
pos = np.append(ml, beta, axis=1)
pos = np.append(pos, inc, axis=1)
pos = np.append(pos, qDM, axis=1)
pos = np.append(pos, log_rho_s, axis=1)
pos = np.append(pos, log_mbh, axis=1)
pos = np.append(pos, mag_shear, axis=1)
pos = np.append(pos, phi_shear, axis=1)
pos = np.append(pos, gamma, axis=1)

nwalkers, ndim = pos.shape

# %%
pos = np.array([ 9.90519845e+00,  9.38761809e+00,  4.56670065e+00,  3.95540285e+00,
        4.09138376e+00,  3.03500598e+00, -1.23701618e-01, -5.95326160e-01,
        6.70712457e-01, -2.71696684e+00,  1.28491888e+00, -9.11095039e-02,
        6.93551706e-01,  8.50485764e+01,  5.45598952e-01,  8.21609655e+00,
        9.16380573e+00,  2.62978391e-02,  3.44317093e-02, -8.18626727e-01])

# %%
model = Probability(Jampy_Model=Jampy_Model, mass_profile=mass_profile, masked_imaging=masked_imaging)

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, model.log_probability)

# %%
sampler.run_mcmc(pos, 1, progress=True);
# Out:
# /home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/profiles/mass_profiles/total_mass_profiles.py:98: RuntimeWarning: invalid value encountered in sqrt
#   eta = np.sqrt(1 - q**2)
# /home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/profiles/mass_profiles/total_mass_profiles.py:120: RuntimeWarning: invalid value encountered in sqrt
#   eta = np.sqrt(1 - q**2)
# emcee: Exception while calling your likelihood function:
#   params: [ 9.87569315e+00  8.89821362e+00  4.58614834e+00  3.59263004e+00
#   4.04383537e+00  2.93268322e+00  3.87721023e-02 -9.70043145e-01
#   5.82364422e-01 -3.10794883e+00  6.59058992e-01  3.65881878e-01
#   5.76436395e-01  9.34566836e+01  5.73793773e-01  7.25652538e+00
#   9.51231057e+00 -5.54143885e-02 -5.34149651e-02  7.51963055e-02]
#   args: []
#   kwargs: {}
#   exception:
# Traceback (most recent call last):
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py", line 545, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/home/carlos/Documents/GitHub/Master-Degree/ESO325/Arcs Modelling/autolens_workspace/JAM+Pyautolens/Cluster_Codes/emcee_probabilities.py", line 266, in log_probability
#     return lp + self.Pyautolens_log_likelihood(parsDic) + self.JAM_log_likelihood(parsDic)
#   File "/home/carlos/Documents/GitHub/Master-Degree/ESO325/Arcs Modelling/autolens_workspace/JAM+Pyautolens/Cluster_Codes/emcee_probabilities.py", line 232, in Pyautolens_log_likelihood
#     source_plane_grid = tracer.traced_grids_of_planes_from_grid(grid=self.masked_imaging.grid)[1]
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py", line 157, in wrapper
#     result_list = func(profile, grid, *args, **kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autolens/lens/ray_tracing.py", line 347, in traced_grids_of_planes_from_grid
#     traced_deflections.append(plane.deflections_from_grid(grid=scaled_grid))
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py", line 70, in wrapper
#     result = func(profile, grid, *args, **kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/plane/plane.py", line 393, in deflections_from_grid
#     return sum(map(lambda g: g.deflections_from_grid(grid=grid), self.galaxies))
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/plane/plane.py", line 393, in <lambda>
#     return sum(map(lambda g: g.deflections_from_grid(grid=grid), self.galaxies))
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py", line 70, in wrapper
#     result = func(profile, grid, *args, **kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/galaxy/galaxy.py", line 545, in deflections_from_grid
#     map(lambda p: p.deflections_from_grid(grid=grid), self.mass_profiles)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/galaxy/galaxy.py", line 545, in <lambda>
#     map(lambda p: p.deflections_from_grid(grid=grid), self.mass_profiles)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py", line 70, in wrapper
#     result = func(profile, grid, *args, **kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py", line 200, in wrapper
#     cls, cls.transform_grid_to_reference_frame(grid), *args, **kwargs
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py", line 259, in wrapper
#     return func(cls, grid, *args, **kwargs)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/profiles/mass_profiles/total_mass_profiles.py", line 357, in deflections_from_grid
#     result_y[i] = quadva(alphay, [0., 1.], args=(self.Grid_parameters[i]),epsrel=1e-10)   #Integral em y
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/jampy/quadva.py", line 328, in quadva
#     nodes, wt, ewt, fun, a, b, args, plot)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/jampy/quadva.py", line 174, in _qva_Vadapt
#     fx, too_close = f(fun, x, a, b, args)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/jampy/quadva.py", line 83, in _qva_f1
#     too_close = _qva_check_spacing(Tt)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/jampy/quadva.py", line 74, in _qva_check_spacing
#     too_close = np.any(np.diff(x) <= EPS*np.maximum(ax[:-1], ax[1:]))
#   File "<__array_function__ internals>", line 6, in any
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 2317, in any
#     return _wrapreduction(a, np.logical_or, 'any', axis, None, out, keepdims=keepdims)
#   File "/home/carlos/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py", line 90, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-9124784fd93d> in <module>
# ----> 1 sampler.run_mcmc(pos, 1, progress=True);
#
# ~/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in run_mcmc(self, initial_state, nsteps, **kwargs)
#     382
#     383         results = None
# --> 384         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     385             pass
#     386
#
# ~/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress)
#     283             state.blobs = blobs0
#     284         if state.log_prob is None:
# --> 285             state.log_prob, state.blobs = self.compute_log_prob(state.coords)
#     286         if np.shape(state.log_prob) != (self.nwalkers,):
#     287             raise ValueError("incompatible input dimensions")
#
# ~/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in compute_log_prob(self, coords)
#     425                 map_func = map
#     426             results = list(
# --> 427                 map_func(self.log_prob_fn, (p[i] for i in range(len(p))))
#     428             )
#     429
#
# ~/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in __call__(self, x)
#     543     def __call__(self, x):
#     544         try:
# --> 545             return self.f(x, *self.args, **self.kwargs)
#     546         except:  # pragma: no cover
#     547             import traceback
#
# ~/Documents/GitHub/Master-Degree/ESO325/Arcs Modelling/autolens_workspace/JAM+Pyautolens/Cluster_Codes/emcee_probabilities.py in log_probability(self, pars)
#     264         lp = self.log_prior(parsDic)
#     265
# --> 266         return lp + self.Pyautolens_log_likelihood(parsDic) + self.JAM_log_likelihood(parsDic)
#
# ~/Documents/GitHub/Master-Degree/ESO325/Arcs Modelling/autolens_workspace/JAM+Pyautolens/Cluster_Codes/emcee_probabilities.py in Pyautolens_log_likelihood(self, parsDic)
#     230
#     231         tracer = al.Tracer.from_galaxies(galaxies=[lens_galaxy, al.Galaxy(redshift=GP.z_source)])
# --> 232         source_plane_grid = tracer.traced_grids_of_planes_from_grid(grid=self.masked_imaging.grid)[1]
#     233
#     234         #check if the integral converge. If not, return -np.inf
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py in wrapper(profile, grid, *args, **kwargs)
#     155             return grid.structure_list_from_result_list(result_list=result_list)
#     156         elif isinstance(grid, grids.Grid):
# --> 157             result_list = func(profile, grid, *args, **kwargs)
#     158             return grid.structure_list_from_result_list(result_list=result_list)
#     159
#
# ~/anaconda3/lib/python3.7/site-packages/autolens/lens/ray_tracing.py in traced_grids_of_planes_from_grid(self, grid, plane_index_limit)
#     345                     return traced_grids
#     346
# --> 347             traced_deflections.append(plane.deflections_from_grid(grid=scaled_grid))
#     348
#     349         return traced_grids
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py in wrapper(profile, grid, *args, **kwargs)
#      68             return grid.structure_from_result(result=result)
#      69         elif isinstance(grid, grids.Grid):
# ---> 70             result = func(profile, grid, *args, **kwargs)
#      71             return grid.structure_from_result(result=result)
#      72
#
# ~/anaconda3/lib/python3.7/site-packages/autogalaxy/plane/plane.py in deflections_from_grid(self, grid)
#     391     def deflections_from_grid(self, grid):
#     392         if self.galaxies:
# --> 393             return sum(map(lambda g: g.deflections_from_grid(grid=grid), self.galaxies))
#     394         return np.zeros(shape=(grid.shape[0], 2))
#     395
#
# ~/anaconda3/lib/python3.7/site-packages/autogalaxy/plane/plane.py in <lambda>(g)
#     391     def deflections_from_grid(self, grid):
#     392         if self.galaxies:
# --> 393             return sum(map(lambda g: g.deflections_from_grid(grid=grid), self.galaxies))
#     394         return np.zeros(shape=(grid.shape[0], 2))
#     395
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py in wrapper(profile, grid, *args, **kwargs)
#      68             return grid.structure_from_result(result=result)
#      69         elif isinstance(grid, grids.Grid):
# ---> 70             result = func(profile, grid, *args, **kwargs)
#      71             return grid.structure_from_result(result=result)
#      72
#
# ~/anaconda3/lib/python3.7/site-packages/autogalaxy/galaxy/galaxy.py in deflections_from_grid(self, grid)
#     543         if self.has_mass_profile:
#     544             return sum(
# --> 545                 map(lambda p: p.deflections_from_grid(grid=grid), self.mass_profiles)
#     546             )
#     547         return np.zeros((grid.shape[0], 2))
#
# ~/anaconda3/lib/python3.7/site-packages/autogalaxy/galaxy/galaxy.py in <lambda>(p)
#     543         if self.has_mass_profile:
#     544             return sum(
# --> 545                 map(lambda p: p.deflections_from_grid(grid=grid), self.mass_profiles)
#     546             )
#     547         return np.zeros((grid.shape[0], 2))
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py in wrapper(profile, grid, *args, **kwargs)
#      68             return grid.structure_from_result(result=result)
#      69         elif isinstance(grid, grids.Grid):
# ---> 70             result = func(profile, grid, *args, **kwargs)
#      71             return grid.structure_from_result(result=result)
#      72
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py in wrapper(cls, grid, *args, **kwargs)
#     198         if not isinstance(grid, (grids.GridTransformed, grids.GridTransformedNumpy)):
#     199             result = func(
# --> 200                 cls, cls.transform_grid_to_reference_frame(grid), *args, **kwargs
#     201             )
#     202
#
# ~/anaconda3/lib/python3.7/site-packages/autoarray/structures/grids/decorators.py in wrapper(cls, grid, *args, **kwargs)
#     257         grid[np.isnan(grid)] = grid_radial_minimum
#     258
# --> 259         return func(cls, grid, *args, **kwargs)
#     260
#     261     return wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/autogalaxy/profiles/mass_profiles/total_mass_profiles.py in deflections_from_grid(self, grid)
#     355             for i in range(len(grid)):                      #Começo do loop
#     356                 result_x[i] = quadva(alphax, [0., 1.], args=(self.Grid_parameters[i]),epsrel=1e-10)   #Integral em x
# --> 357                 result_y[i] = quadva(alphay, [0., 1.], args=(self.Grid_parameters[i]),epsrel=1e-10)   #Integral em y
#     358
#     359         else:
#
# ~/anaconda3/lib/python3.7/site-packages/jampy/quadva.py in quadva(fun, interval, epsrel, epsabs, plot, args)
#     326             tinterval = np.linspace(-1, 1, 11)
#     327         Ifx,errbnd,OK = _qva_Vadapt(_qva_f1, tinterval, rtol, atol, samples,
# --> 328                                     nodes, wt, ewt, fun, a, b, args, plot)
#     329     elif a != -np.Inf and b == np.Inf:
#     330         if nint > 2:
#
# ~/anaconda3/lib/python3.7/site-packages/jampy/quadva.py in _qva_Vadapt(f, tinterval, rtol, atol, samples, nodes, wt, ewt, fun, a, b, args, plot)
#     172         x = x.ravel()
#     173
# --> 174         fx, too_close = f(fun, x, a, b, args)
#     175
#     176         if plot:
#
# ~/anaconda3/lib/python3.7/site-packages/jampy/quadva.py in _qva_f1(fun, t, a, b, args)
#      81     """
#      82     Tt = 0.25*(b - a)*t*(3. - t**2) + 0.5*(b + a)
# ---> 83     too_close = _qva_check_spacing(Tt)
#      84     if  too_close:
#      85         y = []
#
# ~/anaconda3/lib/python3.7/site-packages/jampy/quadva.py in _qva_check_spacing(x)
#      72
#      73     ax = np.abs(x)
# ---> 74     too_close = np.any(np.diff(x) <= EPS*np.maximum(ax[:-1], ax[1:]))
#      75
#      76     return too_close
#
# <__array_function__ internals> in any(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in any(a, axis, out, keepdims)
#    2315
#    2316     """
# -> 2317     return _wrapreduction(a, np.logical_or, 'any', axis, None, out, keepdims=keepdims)
#    2318
#    2319
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
# ---> 90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      91
#      92
#
# KeyboardInterrupt:

# %%
for i in range(10):
    log = model.log_probability(pars=pos[i])
    print("Iteração %i" %i)
    print("log_prob %f" %log)
    print("------------------------")
# Out:
# Iteração 0
# log_prob -inf
# ------------------------
# Iteração 1
# log_prob -inf
# ------------------------
# /home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/profiles/mass_profiles/total_mass_profiles.py:98: RuntimeWarning: invalid value encountered in sqrt
#   eta = np.sqrt(1 - q**2)
# /home/carlos/anaconda3/lib/python3.7/site-packages/autogalaxy/profiles/mass_profiles/total_mass_profiles.py:120: RuntimeWarning: invalid value encountered in sqrt
#   eta = np.sqrt(1 - q**2)
# Iteração 2
# log_prob -155261.550205
# ------------------------
# Iteração 3
# log_prob -285234.281284
# ------------------------
# Iteração 4
# log_prob -7471.878843
# ------------------------
# Iteração 5
# log_prob -inf
# ------------------------
# Iteração 6
# log_prob -6843.718856
# ------------------------
# Iteração 7
# log_prob -15308.657555
# ------------------------
# Iteração 8
# log_prob -inf
# ------------------------
# Iteração 9
# log_prob -inf
# ------------------------

# %%
i = 10
print("Iteração %i" %i)
# Out:
# Iteração 10

# %%
pos
# Out:
# array([ 9.90519845e+00,  9.38761809e+00,  4.56670065e+00,  3.95540285e+00,
#         4.09138376e+00,  3.03500598e+00, -1.23701618e-01, -5.95326160e-01,
#         6.70712457e-01, -2.71696684e+00,  1.28491888e+00, -9.11095039e-02,
#         6.93551706e-01,  8.50485764e+01,  5.45598952e-01,  8.21609655e+00,
#         9.16380573e+00,  2.62978391e-02,  3.44317093e-02, -8.18626727e-01])
