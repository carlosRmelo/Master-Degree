# %% [markdown]
# Tutorial 1: Lens and Source
# ===========================
#
# As discussed in chapter 2, an effective strategy for modeling strong lenses is to break the model-fitting procedure
# down into a series of phases, linking the results of the phases to guide the non-linear search as to where to
# sample parameter space. In this chapter, we'll cover _Pipeline_'s, which provide a powerful means by which to
# link together many phases.
#
# In chapter 2, we fitted strong lens imaging which included the lens galaxy's light. We're going to fit this dataset
# again (I promise, this is the last time!). However, now we're using pipelines, we can perform a different (and
# significantly faster) model-fit.
#
# The crucial point to note is that for many lenses the lens galaxy's light can be fitted and subtracted reasonable well
# before we attempt to fit the source galaxy. This makes sense, as fitting the lens's light (which is an elliptical blob
# of light in the centre of the imaging) looks nothing like the source's light (which is a ring of light)! Formally,
# we would say that these two model components (the lens's light and source's light) are not covariant.
#
# So, as a newly trained lens modeler, what does the lack of covariance between these parameters make you think?
# Hopefully, you're thinking, why should I bother fitting the lens and source galaxy simultaneously? Surely we can
# find the right regions of non-linear parameter space by fitting each separately first? This is what we're going to do
# in this tutorial, using a pipeline composed of a modest 3 phases:
#
#     1) Fit the lens galaxy's light, ignoring the source.
#     2) Fit the source-galaxy's light (and therefore lens galaxy's mass), ignoring the len's light.
#     3) Fit both simultaneously, using these results to initialize our starting location in parameter space.
#
# Of course, given that we do not care for the errors in phases 1 and 2, we will set up our non-linear search to perform
# sampling as fast as possible!

# %%
import os

""" AUTOFIT + CONFIG SETUP """
# Out:
# ' AUTOFIT + CONFIG SETUP '

# %%
# %matplotlib inline
from autoconf import conf
from pyprojroot import here

workspace_path = str(here())
print("Workspace Path: ", workspace_path)

conf.instance = conf.Config(
    config_path=f"{workspace_path}/howtolens/config",
    output_path=f"{workspace_path}/howtolens/output",
)
# Out:
# Workspace Path:  /home/carlos/autolens_workspace

# %%
# %matplotlib inline

import autolens as al
import autolens.plot as aplt

# %% [markdown]
# We'll use strong lensing data, where:
#
#     The lens galaxy's LightProfile is an EllipticalSersic.
#     The lens galaxy's MassProfile is an EllipticalIsothermal.
#     The source galaxy's LightProfile is an EllipticalExponential.

# %%
from howtolens.simulators.chapter_3 import lens_sersic_sie__source_exp

dataset_type = "chapter_3"
dataset_name = "lens_sersic_sie__source_exp"
dataset_path = f"{workspace_path}/howtolens/dataset/{dataset_type}/{dataset_name}"

imaging = al.Imaging.from_fits(
    image_path=f"{dataset_path}/image.fits",
    noise_map_path=f"{dataset_path}/noise_map.fits",
    psf_path=f"{dataset_path}/psf.fits",
    pixel_scales=0.1,
)

# %% [markdown]
# We need to choose our mask for the analysis. Given the lens light is present in the image we'll need to include all of its light in the central regions of the image, so lets use a circular mask.

# %%
mask = al.Mask.circular(
    shape_2d=imaging.shape_2d, pixel_scales=imaging.pixel_scales, radius=3.0
)

aplt.Imaging.subplot_imaging(imaging=imaging, mask=mask)

# %% [markdown]
# __Settings__
#
# The *PhaseSettingsImaging* describe how the model is fitted to the data in the log likelihood function. We discussed
# these in chapter 2, and a full description of all settings can be found in the example script:
#
#     'autolens_workspace/examples/model/customize/settings.py'.
#
# The settings chosen here are applied to all phases in the pipeline.

# %%
settings = al.PhaseSettingsImaging(grid_class=al.Grid, sub_size=2)

# %% [markdown]
# __Pipeline_Setup_And_Tagging__:
#
# For this pipeline the pipeline setup customizes:
#
#  - If there is an external shear in the mass model or not.
#
# The pipeline setup 'tags' the output path of a pipeline. For example, if 'no_shear' is True, the pipeline's output
# paths are 'tagged' with the string 'no_shear'.
#
# This means you can run the same pipeline on the same data twice (with and without shear) and the results will go
# to different output folders and thus not clash with one another!

# %%
setup = al.PipelineSetup(no_shear=False, folders=["howtolens", "c3_t1_lens_and_source"])

# %% [markdown]
# __Pipeline Creation__
#
# To create a _Pipeline_, we call a 'make_pipeline' function, which is written in its own Python script:
#
#     'tutorial_1_pipeline_lens_and_source.py'.
#
# Before we check it out, lets get the pipeline running, by importing the script, running the 'make_pipeline' function
# to create the _Pipeline_ object and calling that objects 'run' function.
#
# The 'folders' below specify the path the pipeline results are written to, which is:
#
#     'autolens_workspace/output/howtolens/c3_t1_lens_and_source/pipeline_name/setup_tag/phase_name/settings_tag'

# %%
from howtolens.chapter_3_pipelines import tutorial_1_pipeline_lens_and_source

pipeline_lens_and_source = tutorial_1_pipeline_lens_and_source.make_pipeline(
    setup=setup, settings=settings
)

# Uncomment to run.
pipeline_lens_and_source.run(dataset=imaging, mask=mask)
# Out:
# INFO:autofit.tools.pipeline:Running Phase phase_1__lens_sersic (Number 0)
# INFO:root:Generating initial samples of model, which are subject to prior limits and other constraints.
# INFO:root:No Dynesty samples found, beginning new non-linear search.
# 268it [00:26, 10.11it/s, +30 | bound: 56 | nc: 1 | ncall: 2533 | eff(%): 11.765 | loglstar:   -inf < 71.066 <    inf | logz: 58.151 +/-    nan | dlogz:  1.099 >  5.000]
# INFO:root:2500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 576it [00:26, 21.83it/s, +30 | bound: 146 | nc: 1 | ncall: 5035 | eff(%): 12.036 | loglstar:   -inf < 3438.566 <    inf | logz: 3415.552 +/-    nan | dlogz:  1.099 >  5.000]
# INFO:root:5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 853it [00:26, 32.48it/s, +30 | bound: 237 | nc: 1 | ncall: 7539 | eff(%): 11.712 | loglstar:   -inf < 4311.386 <    inf | logz: 4279.304 +/-    nan | dlogz:  1.089 >  5.000]
# INFO:root:7500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1106it [00:23, 46.42it/s, +30 | bound: 311 | nc: 1 | ncall: 9765 | eff(%): 11.633 | loglstar:   -inf < 4351.036 <    inf | logz: 4312.769 +/-    nan | dlogz:  0.214 >  5.000]
# INFO:root:10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1106it [00:00, 377361.12it/s, +30 | bound: 311 | nc: 1 | ncall: 9765 | eff(%): 11.633 | loglstar:   -inf < 4351.036 <    inf | logz: 4312.769 +/-    nan | dlogz:  0.214 >  5.000]
# INFO:root:12500 Iterations: Performing update (Visualization, outputting samples, etc.).
# INFO:root:15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# INFO:autofit.tools.pipeline:Running Phase phase_2__lens_sie__source_sersic (Number 1)
# INFO:root:Generating initial samples of model, which are subject to prior limits and other constraints.
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/dynesty.py:373: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# INFO:root:No Dynesty samples found, beginning new non-linear search.
# 181it [00:41,  7.37it/s, bound: 2 | nc: 5 | ncall: 1771 | eff(%): 10.220 | loglstar:   -inf < 4354.394 <    inf | logz: 4350.059 +/- 27.554 | dlogz: 35.718 >  5.000]        /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 188it [00:42,  6.79it/s, bound: 4 | nc: 6 | ncall: 1822 | eff(%): 10.318 | loglstar:   -inf < 4354.757 <    inf | logz: 4350.349 +/- 27.555 | dlogz: 36.622 >  5.000] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 214it [00:47,  6.54it/s, bound: 8 | nc: 9 | ncall: 2038 | eff(%): 10.500 | loglstar:   -inf < 4357.427 <    inf | logz: 4351.722 +/- 27.555 | dlogz: 34.778 >  5.000] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 269it [00:59,  4.49it/s, +50 | bound: 21 | nc: 1 | ncall: 2555 | eff(%): 12.485 | loglstar:   -inf < 4441.297 <    inf | logz: 4431.345 +/- 27.584 | dlogz:  1.099 >  5.000]
# INFO:root:2500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 342it [00:29,  4.38it/s, bound: 42 | nc: 5 | ncall: 3865 | eff(%):  8.849 | loglstar:   -inf < 4394.161 <    inf | logz: 4384.611 +/- 27.559 | dlogz: 92.385 >  5.000]   /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 450it [00:57,  7.83it/s, +50 | bound: 64 | nc: 1 | ncall: 5058 | eff(%):  9.885 | loglstar:   -inf < 4669.672 <    inf | logz: 4656.135 +/- 27.570 | dlogz:  1.099 >  5.000]
# INFO:root:5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 743it [00:57, 12.82it/s, +50 | bound: 118 | nc: 1 | ncall: 7561 | eff(%): 10.488 | loglstar:   -inf < 4757.794 <    inf | logz: 4738.455 +/- 27.592 | dlogz:  1.099 >  5.000]
# INFO:root:7500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1021it [00:58, 17.51it/s, +50 | bound: 172 | nc: 1 | ncall: 10066 | eff(%): 10.640 | loglstar:   -inf < 4856.106 <    inf | logz: 4831.486 +/- 27.576 | dlogz:  0.955 >  5.000]
# INFO:root:10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1292it [00:58, 22.15it/s, +50 | bound: 224 | nc: 1 | ncall: 12571 | eff(%): 10.675 | loglstar:   -inf < 4974.036 <    inf | logz: 4943.827 +/- 27.595 | dlogz:  1.098 >  5.000]
# INFO:root:12500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1537it [00:58, 26.07it/s, +50 | bound: 273 | nc: 1 | ncall: 15111 | eff(%): 10.502 | loglstar:   -inf < 5098.843 <    inf | logz: 5063.781 +/- 27.606 | dlogz:  1.099 >  5.000]
# INFO:root:15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1770it [00:59, 29.73it/s, +50 | bound: 325 | nc: 1 | ncall: 17646 | eff(%): 10.314 | loglstar:   -inf < 5186.012 <    inf | logz: 5146.337 +/- 27.599 | dlogz:  1.098 >  5.000]
# INFO:root:17500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2030it [00:59, 34.37it/s, +50 | bound: 383 | nc: 1 | ncall: 20162 | eff(%): 10.316 | loglstar:   -inf < 5246.501 <    inf | logz: 5201.974 +/- 27.593 | dlogz:  0.911 >  5.000]
# INFO:root:20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2264it [00:59, 38.22it/s, +50 | bound: 436 | nc: 1 | ncall: 22678 | eff(%): 10.204 | loglstar:   -inf < 5275.039 <    inf | logz: 5226.430 +/- 27.598 | dlogz:  0.618 >  5.000]
# INFO:root:22500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2463it [00:58, 41.76it/s, +50 | bound: 483 | nc: 1 | ncall: 25213 | eff(%):  9.967 | loglstar:   -inf < 5291.090 <    inf | logz: 5238.311 +/- 27.612 | dlogz:  0.731 >  5.000]
# INFO:root:25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2614it [00:59, 44.27it/s, +50 | bound: 523 | nc: 1 | ncall: 27753 | eff(%):  9.599 | loglstar:   -inf < 5297.737 <    inf | logz: 5242.778 +/- 27.606 | dlogz:  0.391 >  5.000]
# INFO:root:27500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2707it [00:26, 100.82it/s, +50 | bound: 546 | nc: 1 | ncall: 28926 | eff(%):  9.531 | loglstar:   -inf < 5299.097 <    inf | logz: 5243.323 +/- 27.600 | dlogz:  0.158 >  5.000]
# INFO:root:30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2707it [00:00, 801099.34it/s, +50 | bound: 546 | nc: 1 | ncall: 28926 | eff(%):  9.531 | loglstar:   -inf < 5299.097 <    inf | logz: 5243.323 +/- 27.600 | dlogz:  0.158 >  5.000]
# INFO:root:32500 Iterations: Performing update (Visualization, outputting samples, etc.).
# INFO:root:35000 Iterations: Performing update (Visualization, outputting samples, etc.).
# INFO:autofit.tools.pipeline:Running Phase phase_3__lens_sersic_sie__source_sersic (Number 2)
# INFO:root:Generating initial samples of model, which are subject to prior limits and other constraints.
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/dynesty.py:373: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# INFO:root:No Dynesty samples found, beginning new non-linear search.
# 18it [00:00, 15.59it/s, bound: 1 | nc: 5 | ncall: 209 | eff(%):  8.612 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-  0.330 | dlogz:    inf >  0.109] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 38it [00:02,  9.90it/s, bound: 2 | nc: 6 | ncall: 310 | eff(%): 12.258 | loglstar:   -inf <   -inf <    inf | logz:   -inf +/-  0.336 | dlogz:    inf >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 48it [00:03,  9.45it/s, bound: 3 | nc: 5 | ncall: 360 | eff(%): 13.333 | loglstar:   -inf < -731085.081 <    inf | logz: -731090.857 +/-  0.339 | dlogz: 782429.594 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 61it [00:05, 10.57it/s, bound: 3 | nc: 5 | ncall: 425 | eff(%): 14.353 | loglstar:   -inf < -538983.792 <    inf | logz: -538989.697 +/-  0.343 | dlogz: 574883.607 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 77it [00:06,  9.19it/s, bound: 4 | nc: 5 | ncall: 507 | eff(%): 15.187 | loglstar:   -inf < -363468.731 <    inf | logz: -363474.795 +/-  0.347 | dlogz: 380766.311 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 93it [00:08,  8.89it/s, bound: 6 | nc: 5 | ncall: 587 | eff(%): 15.843 | loglstar:   -inf < -222251.089 <    inf | logz: -222257.313 +/-  0.352 | dlogz: 238329.937 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 109it [00:10,  9.23it/s, bound: 7 | nc: 5 | ncall: 671 | eff(%): 16.244 | loglstar:   -inf < -151772.235 <    inf | logz: -151778.618 +/-  0.356 | dlogz: 160256.452 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 122it [00:11, 11.74it/s, bound: 8 | nc: 5 | ncall: 739 | eff(%): 16.509 | loglstar:   -inf < -119347.924 <    inf | logz: -119354.436 +/-  0.360 | dlogz: 125807.129 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 126it [00:11, 10.36it/s, bound: 8 | nc: 13 | ncall: 775 | eff(%): 16.258 | loglstar:   -inf < -116501.688 <    inf | logz: -116508.240 +/-  0.361 | dlogz: 121368.661 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 143it [00:13, 10.27it/s, bound: 10 | nc: 5 | ncall: 870 | eff(%): 16.437 | loglstar:   -inf < -78320.750 <    inf | logz: -78327.472 +/-  0.366 | dlogz: 84518.233 >  0.109]   /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 165it [00:15, 11.60it/s, bound: 11 | nc: 8 | ncall: 983 | eff(%): 16.785 | loglstar:   -inf < -54805.188 <    inf | logz: -54812.122 +/-  0.371 | dlogz: 59177.393 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 178it [00:17,  9.70it/s, bound: 12 | nc: 5 | ncall: 1089 | eff(%): 16.345 | loglstar:   -inf < -33278.361 <    inf | logz: -33285.430 +/-  0.375 | dlogz: 39059.811 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 192it [00:18,  9.97it/s, bound: 13 | nc: 13 | ncall: 1227 | eff(%): 15.648 | loglstar:   -inf < -22987.581 <    inf | logz: -22994.790 +/-  0.379 | dlogz: 28349.066 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 208it [00:20, 10.17it/s, bound: 16 | nc: 5 | ncall: 1337 | eff(%): 15.557 | loglstar:   -inf < -14736.454 <    inf | logz: -14743.822 +/-  0.383 | dlogz: 19150.292 >  0.109] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 218it [00:21,  9.83it/s, bound: 16 | nc: 5 | ncall: 1410 | eff(%): 15.461 | loglstar:   -inf < -12242.043 <    inf | logz: -12249.511 +/-  0.385 | dlogz: 17061.149 >  0.109] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 233it [00:23,  8.47it/s, bound: 18 | nc: 5 | ncall: 1511 | eff(%): 15.420 | loglstar:   -inf < -8917.664 <    inf | logz: -8925.281 +/-  0.389 | dlogz: 13438.966 >  0.109]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 250it [00:25,  9.20it/s, bound: 19 | nc: 5 | ncall: 1611 | eff(%): 15.518 | loglstar:   -inf < -7283.832 <    inf | logz: -7290.762 +/-  0.361 | dlogz: 11650.589 >  0.109] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 263it [00:26,  8.36it/s, bound: 20 | nc: 5 | ncall: 1693 | eff(%): 15.535 | loglstar:   -inf < -5888.269 <    inf | logz: -5896.185 +/-  0.397 | dlogz: 10340.379 >  0.109] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 283it [00:29,  7.73it/s, bound: 22 | nc: 5 | ncall: 1832 | eff(%): 15.448 | loglstar:   -inf < -4442.610 <    inf | logz: -4450.724 +/-  0.402 | dlogz: 8838.120 >  0.109]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 292it [00:30,  6.46it/s, bound: 23 | nc: 5 | ncall: 1896 | eff(%): 15.401 | loglstar:   -inf < -3844.206 <    inf | logz: -3852.410 +/-  0.404 | dlogz: 8392.739 >  0.109] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 314it [00:34,  8.50it/s, bound: 25 | nc: 5 | ncall: 2059 | eff(%): 15.250 | loglstar:   -inf < -2685.272 <    inf | logz: -2693.695 +/-  0.409 | dlogz: 7107.726 >  0.109] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 389it [00:44,  8.82it/s, +100 | bound: 32 | nc: 1 | ncall: 2616 | eff(%): 18.693 | loglstar:   -inf < 4361.126 <    inf | logz: 4351.947 +/-  0.497 | dlogz:  1.099 >  0.109]
# INFO:root:2500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 391it [00:00, 1973.39it/s, bound: 32 | nc: 6 | ncall: 2627 | eff(%): 14.884 | loglstar:   -inf < -63.410 <    inf | logz: -72.599 +/-  0.428 | dlogz: 4439.306 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 506it [00:21,  5.26it/s, bound: 45 | nc: 8 | ncall: 3744 | eff(%): 13.515 | loglstar:   -inf < 1941.797 <    inf | logz: 1931.463 +/-  0.453 | dlogz: 2758.074 >  0.109] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 517it [00:25,  6.02it/s, bound: 46 | nc: 9 | ncall: 3888 | eff(%): 13.297 | loglstar:   -inf < 2043.163 <    inf | logz: 2032.744 +/-  0.453 | dlogz: 2647.596 >  0.109] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 602it [00:38,  7.69it/s, bound: 56 | nc: 5 | ncall: 4673 | eff(%): 12.883 | loglstar:   -inf < 2851.967 <    inf | logz: 2840.678 +/-  0.474 | dlogz: 1921.085 >  0.109] /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 653it [00:48, 13.53it/s, +100 | bound: 61 | nc: 1 | ncall: 5121 | eff(%): 14.704 | loglstar:   -inf < 5081.919 <    inf | logz: 5070.113 +/-  0.691 | dlogz:  1.099 >  0.109]
# INFO:root:5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 854it [00:37,  5.54it/s, bound: 84 | nc: 5 | ncall: 6927 | eff(%): 12.329 | loglstar:   -inf < 4413.997 <    inf | logz: 4401.008 +/-  0.492 | dlogz: 1028.195 >  0.109]  /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 886it [00:53, 16.59it/s, +100 | bound: 88 | nc: 1 | ncall: 7622 | eff(%): 12.936 | loglstar:   -inf < 5436.769 <    inf | logz: 5422.645 +/-  0.558 | dlogz:  1.099 >  0.109]
# INFO:root:7500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1136it [00:57, 19.75it/s, +100 | bound: 118 | nc: 1 | ncall: 10126 | eff(%): 12.206 | loglstar:   -inf < 5783.857 <    inf | logz: 5767.246 +/-  0.685 | dlogz:  1.099 >  0.109]
# INFO:root:10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1371it [01:00, 22.63it/s, +100 | bound: 147 | nc: 1 | ncall: 12633 | eff(%): 11.644 | loglstar:   -inf < 5890.495 <    inf | logz: 5871.551 +/-  0.847 | dlogz:  1.094 >  0.109]
# INFO:root:12500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1519it [00:43,  3.83it/s, bound: 166 | nc: 5 | ncall: 14293 | eff(%): 10.628 | loglstar:   -inf < 5724.688 <    inf | logz: 5705.916 +/-  0.596 | dlogz: 253.500 >  0.109]   /home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1571it [01:06, 23.64it/s, +100 | bound: 173 | nc: 1 | ncall: 15134 | eff(%): 11.041 | loglstar:   -inf < 5979.009 <    inf | logz: 5958.729 +/-    nan | dlogz:  0.710 >  0.109]
# INFO:root:15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1809it [01:05, 27.53it/s, +100 | bound: 201 | nc: 1 | ncall: 17636 | eff(%): 10.824 | loglstar:   -inf < 6147.716 <    inf | logz: 6124.427 +/-  0.782 | dlogz:  1.085 >  0.109]
# INFO:root:17500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2006it [01:05, 30.72it/s, +100 | bound: 228 | nc: 1 | ncall: 20141 | eff(%): 10.456 | loglstar:   -inf < 6187.622 <    inf | logz: 6162.487 +/-  0.673 | dlogz:  1.012 >  0.109]
# INFO:root:20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2197it [01:04, 33.96it/s, +100 | bound: 253 | nc: 1 | ncall: 22646 | eff(%): 10.143 | loglstar:   -inf < 6254.603 <    inf | logz: 6227.518 +/-  0.726 | dlogz:  1.044 >  0.109]
# INFO:root:22500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2443it [01:07, 36.36it/s, +100 | bound: 283 | nc: 1 | ncall: 25161 | eff(%): 10.107 | loglstar:   -inf < 6287.936 <    inf | logz: 6258.319 +/-  1.171 | dlogz:  1.098 >  0.109]
# INFO:root:25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2679it [01:06, 40.42it/s, +100 | bound: 311 | nc: 1 | ncall: 27667 | eff(%): 10.044 | loglstar:   -inf < 6307.963 <    inf | logz: 6276.092 +/-  1.417 | dlogz:  1.037 >  0.109]
# INFO:root:27500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2916it [01:09, 41.94it/s, +100 | bound: 341 | nc: 1 | ncall: 30171 | eff(%):  9.996 | loglstar:   -inf < 6352.628 <    inf | logz: 6318.305 +/-  1.648 | dlogz:  1.099 >  0.109]
# INFO:root:30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2962it [00:20, 18497.81it/s, bound: 346 | nc: 5 | ncall: 30726 | eff(%):  9.640 | loglstar:   -inf < 6302.472 <    inf | logz: 6270.257 +/-  0.788 | dlogz: 53.076 >  0.109]/home/carlos/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 3136it [01:08, 45.99it/s, +100 | bound: 366 | nc: 1 | ncall: 32681 | eff(%):  9.902 | loglstar:   -inf < 6361.797 <    inf | logz: 6325.285 +/-  1.673 | dlogz:  1.098 >  0.109]
# INFO:root:32500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3411it [01:09, 48.79it/s, +100 | bound: 396 | nc: 1 | ncall: 35191 | eff(%):  9.977 | loglstar:   -inf < 6378.675 <    inf | logz: 6340.767 +/-  0.586 | dlogz:  0.421 >  0.109]
# INFO:root:35000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3719it [01:09, 53.53it/s, +100 | bound: 428 | nc: 1 | ncall: 37707 | eff(%): 10.128 | loglstar:   -inf < 6400.318 <    inf | logz: 6358.058 +/-  1.792 | dlogz:  1.064 >  0.109]
# INFO:root:37500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4019it [01:08, 58.45it/s, +100 | bound: 459 | nc: 1 | ncall: 40217 | eff(%): 10.242 | loglstar:   -inf < 6414.190 <    inf | logz: 6370.219 +/-  1.188 | dlogz:  0.425 >  0.109]
# INFO:root:40000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4301it [01:09, 62.10it/s, +100 | bound: 490 | nc: 1 | ncall: 42719 | eff(%): 10.302 | loglstar:   -inf < 6426.375 <    inf | logz: 6379.485 +/-  1.314 | dlogz:  0.466 >  0.109]
# INFO:root:42500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4591it [01:09, 66.25it/s, +100 | bound: 520 | nc: 1 | ncall: 45223 | eff(%): 10.373 | loglstar:   -inf < 6441.551 <    inf | logz: 6390.827 +/-  1.803 | dlogz:  0.929 >  0.109]
# INFO:root:45000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4861it [01:09, 70.26it/s, +100 | bound: 550 | nc: 1 | ncall: 47728 | eff(%): 10.394 | loglstar:   -inf < 6450.244 <    inf | logz: 6397.104 +/-  1.606 | dlogz:  0.774 >  0.109]
# INFO:root:47500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5155it [01:05, 79.07it/s, +100 | bound: 580 | nc: 1 | ncall: 50239 | eff(%): 10.460 | loglstar:   -inf < 6468.213 <    inf | logz: 6412.557 +/-  1.081 | dlogz:  0.574 >  0.109]
# INFO:root:50000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5445it [01:05, 83.42it/s, +100 | bound: 611 | nc: 1 | ncall: 52741 | eff(%): 10.514 | loglstar:   -inf < 6487.554 <    inf | logz: 6428.508 +/-  1.442 | dlogz:  0.827 >  0.109]
# INFO:root:52500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5737it [01:05, 87.60it/s, +100 | bound: 643 | nc: 1 | ncall: 55250 | eff(%): 10.565 | loglstar:   -inf < 6507.053 <    inf | logz: 6445.301 +/-  1.410 | dlogz:  0.719 >  0.109]
# INFO:root:55000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6008it [01:05, 92.37it/s, +100 | bound: 674 | nc: 1 | ncall: 57755 | eff(%): 10.576 | loglstar:   -inf < 6516.157 <    inf | logz: 6451.634 +/-  1.668 | dlogz:  0.758 >  0.109]
# INFO:root:57500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6311it [01:05, 96.78it/s, +100 | bound: 705 | nc: 1 | ncall: 60262 | eff(%): 10.639 | loglstar:   -inf < 6525.319 <    inf | logz: 6459.122 +/-  1.241 | dlogz:  0.260 >  0.109]
# INFO:root:60000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6584it [01:05, 101.28it/s, +100 | bound: 736 | nc: 1 | ncall: 62773 | eff(%): 10.648 | loglstar:   -inf < 6534.357 <    inf | logz: 6464.260 +/-  1.766 | dlogz:  0.678 >  0.109]
# INFO:root:62500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6861it [01:04, 105.64it/s, +100 | bound: 768 | nc: 1 | ncall: 65277 | eff(%): 10.664 | loglstar:   -inf < 6542.536 <    inf | logz: 6470.749 +/-  1.403 | dlogz:  0.288 >  0.109]
# INFO:root:65000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7105it [01:05, 109.21it/s, +100 | bound: 797 | nc: 1 | ncall: 67787 | eff(%): 10.629 | loglstar:   -inf < 6549.262 <    inf | logz: 6474.829 +/-  1.500 | dlogz:  0.347 >  0.109]
# INFO:root:67500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7374it [01:05, 112.46it/s, +100 | bound: 828 | nc: 1 | ncall: 70290 | eff(%): 10.633 | loglstar:   -inf < 6552.570 <    inf | logz: 6475.540 +/-  1.580 | dlogz:  0.325 >  0.109]
# INFO:root:70000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7628it [01:05, 115.87it/s, +100 | bound: 858 | nc: 1 | ncall: 72811 | eff(%): 10.614 | loglstar:   -inf < 6556.221 <    inf | logz: 6477.820 +/-  1.449 | dlogz:  0.114 >  0.109]
# INFO:root:72500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7913it [01:05, 121.17it/s, +100 | bound: 891 | nc: 1 | ncall: 75320 | eff(%): 10.639 | loglstar:   -inf < 6563.024 <    inf | logz: 6480.617 +/-  1.705 | dlogz:  0.328 >  0.109]
# INFO:root:75000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8188it [01:05, 125.89it/s, +100 | bound: 920 | nc: 1 | ncall: 77828 | eff(%): 10.649 | loglstar:   -inf < 6566.441 <    inf | logz: 6482.285 +/-  1.512 | dlogz:  0.135 >  0.109]
# INFO:root:77500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8477it [01:04, 130.46it/s, +100 | bound: 952 | nc: 1 | ncall: 80333 | eff(%): 10.677 | loglstar:   -inf < 6570.426 <    inf | logz: 6483.336 +/-  1.559 | dlogz:  0.143 >  0.109]
# INFO:root:80000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8763it [01:05, 134.60it/s, +100 | bound: 984 | nc: 1 | ncall: 82835 | eff(%): 10.700 | loglstar:   -inf < 6575.621 <    inf | logz: 6484.354 +/-  2.030 | dlogz:  0.458 >  0.109]
# INFO:root:82500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9040it [01:05, 138.86it/s, +100 | bound: 1016 | nc: 1 | ncall: 85342 | eff(%): 10.710 | loglstar:   -inf < 6576.918 <    inf | logz: 6485.023 +/-  1.545 | dlogz:  0.067 >  0.109]
# INFO:root:85000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9310it [01:08, 135.28it/s, +100 | bound: 1045 | nc: 1 | ncall: 87845 | eff(%): 10.712 | loglstar:   -inf < 6580.386 <    inf | logz: 6485.705 +/-  1.539 | dlogz:  0.074 >  0.109]
# INFO:root:87500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9612it [01:06, 145.10it/s, +100 | bound: 1078 | nc: 1 | ncall: 90356 | eff(%): 10.749 | loglstar:   -inf < 6582.873 <    inf | logz: 6485.950 +/-  1.476 | dlogz:  0.035 >  0.109]
# INFO:root:90000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9885it [01:05, 150.07it/s, +100 | bound: 1107 | nc: 1 | ncall: 92861 | eff(%): 10.753 | loglstar:   -inf < 6584.840 <    inf | logz: 6486.117 +/-  1.443 | dlogz:  0.014 >  0.109]
# INFO:root:92500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10152it [01:05, 155.91it/s, +100 | bound: 1139 | nc: 1 | ncall: 95363 | eff(%): 10.751 | loglstar:   -inf < 6586.589 <    inf | logz: 6486.186 +/-  1.393 | dlogz:  0.005 >  0.109]
# INFO:root:95000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10440it [01:05, 160.13it/s, +100 | bound: 1169 | nc: 1 | ncall: 97865 | eff(%): 10.770 | loglstar:   -inf < 6588.484 <    inf | logz: 6486.218 +/-  1.380 | dlogz:  0.002 >  0.109]
# INFO:root:97500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10706it [01:05, 164.56it/s, +100 | bound: 1201 | nc: 1 | ncall: 100367 | eff(%): 10.766 | loglstar:   -inf < 6591.257 <    inf | logz: 6486.246 +/-  1.380 | dlogz:  0.002 >  0.109]
# INFO:root:100000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10913it [00:50, 215.17it/s, +100 | bound: 1227 | nc: 1 | ncall: 102322 | eff(%): 10.763 | loglstar:   -inf < 6592.664 <    inf | logz: 6486.263 +/-  1.378 | dlogz:  0.001 >  0.109]
# INFO:root:102500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10913it [00:00, 2078958.97it/s, +100 | bound: 1227 | nc: 1 | ncall: 102322 | eff(%): 10.763 | loglstar:   -inf < 6592.664 <    inf | logz: 6486.263 +/-  1.378 | dlogz:  0.001 >  0.109]
# INFO:root:105000 Iterations: Performing update (Visualization, outputting samples, etc.).
# INFO:root:107500 Iterations: Performing update (Visualization, outputting samples, etc.).

# %% [markdown]
# Okay, good job, we're running our first pipeline in PyAutoLens! But what does it *actually* do? Well, to find that out,
# go to the script 'tutorial_1_pipeline_lens_and_source.py', which contains a full description of the pipeline, as well
# as an overview of the tools we use to write the most general pipelines possible. Once you're done, come back to this
# pipeline runner script and we'll wrap up tutorial 1.
#
# And there we have it, a pipeline that breaks the analysis of the lens and source galaxy into 3 simple phases. This approach is much faster than fitting the lens and source simultaneously from the beginning.
