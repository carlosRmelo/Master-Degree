# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 05/27/2020
#
# Obj: Perform the modeling of spectrum based on pPXF method by Cappellari,and obtein the kinematics./Realizar o modelamento de espectros baeado no código pPXF de Cappellari, e obter a cinemática.

# %%
import glob
from os import path

from astropy.io import fits
from scipy import ndimage
import numpy as np

import ppxf as ppxf_package
from ppxf.ppxf import ppxf
import ppxf.ppxf_util as util

import matplotlib.pyplot as plt

data_folder = "/home/carlos/Desktop/ESO"

# %%
ppxf_dir = '/home/carlos/Desktop/ppxf' #Directory of stellar library/Diretória da biblioteca estelar


stellar_lib = '/home/carlos/Downloads/Bibliotecas Estelares/BINTABLE'
Indo = glob.glob(stellar_lib + '/*.fits')
FWHM_tem = 1.35


for i in range(51): #Number of bins
     #READING THE SPECTRUM/LENDO UM ESPECTRO
    file = (data_folder+'/Data/Binned_Spec/Bin%d.fits'%i) #Path and name of the spectrum/Caminho e nome do arquivo do espectro
    hdu = fits.open(file) #Opening the .fits file/Abrindo o arquivo.fits
    gal_lin = hdu[1].data #Read the data/Lendo os dados
    h1 = hdu[1].header    #Read the header/Lendo o header dos dados
    
    #READING THE VARIANCE/LENDO A VARIÂNCIA DO ESPECTRO
    var = hdu[2].data     #Read the variance/Lendo a variância
    h_var = hdu[2].header #Read the variance header/Lendo o header da variância
    
    #LOG-REBIN THE SPECTRUM AND VARIANCE/LOGARITMIZANDO O ESPECTRO E A VARIÂNCIA
        #SPECTRUM/ESPECTRO
    FWHM_gal = 2.71  #FWHM of telescope in Angstrons/FWHM do telescópio em Angstrons
    lambRange1 = h1['CRVAL1'] + np.array([0.,h1['CDELT1']*(h1['NAXIS1']-1)]) #Generating the wavelengths/Está linha gera os comprimentos de onda
                                #pois a variável gal_lin armazena em um array apenas as intensidades, mas não os comprimentos de onda
        
    #De-redshift
    z = 0.035 # Initial estimate of the galaxy redshift
    lambRange1 = lambRange1/(1+z) # Compute approximate restframe wavelength range
    FWHM_gal = FWHM_gal/(1+z)   # Adjust resolution in Angstrom
    #Depois do passo acima, a galáxia passa a estar no restframe, logo é preeciso setar
    z = 0.
    
    
    galaxy, logLam1, velscale = util.log_rebin(lambRange1, gal_lin) #Log-rebin the spectrum/Logaritimizando o espectro da galáxia
    median_galaxy = np.median(galaxy) #Mean of spectrum for normalization/Média do espectro, pois vamos normalizá-lo pela média
    galaxy = galaxy/median_galaxy        #Normalizing the spectrum/Normalizando o espectro pela média
    lam = np.exp(logLam1)                #Recovering the wavelength in Ansgstrons/Recuperando o comprimento de onda em unidades do SI
        
    #VARIANCE/VARIÂNCIA
    lamRange_var = h_var['CRVAL1'] + np.array([0.,h_var['CDELT1']*(h_var['NAXIS1']-1)])
    erro = np.sqrt(var) #1-sigma error from variance/1-sigma erro da variância
    erro, loglam_var, velscale_var = util.log_rebin(lamRange_var, erro)
    noise = erro/median_galaxy         #Normalizing the error/Normalizando o erro        
        
    #READING ONE TEMPLATE FOR DETERMINE THE LENGHT/LENDO UM TEMPLATE PARA SABER O TAMANHO DO VETOR FINAL
        #The ideia is make a empty array to after complete with the informations about the templates of the stellar libary/
                    #A ideia é crirar um array vazio para que mais tarde seja preenchido com as informações de todos os templetes.

    
    
    
    velscale_ratio = 2
    hdu = fits.open(Indo[0])
    data = hdu[1].data
    ssp = data[0][1]
    h2 = hdu[0].header
    
    #Log_rebin TEMPLATE/LOGARITMIZANDO O TEMPLATE
    lamRange2 = np.array([data[0][0][0], data[0][0][len(data[0][0]) - 1]]) 
    sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
    templates = np.empty((sspNew.size, len(Indo)))  #Array com o tamanho necessário

    #FINAL FWHM FOR GALAXY AND TEMPLATE CONVOLUTION/CALCULANDO A FWHM FINAL PARA REALIZAR A CONVOLUÇÃO DO TEMPLATE E GALÁXIA
    FWHM_dif = np.sqrt(FWHM_gal**2 - FWHM_tem**2)
    sigma = FWHM_dif/2.355/0.4 #New sigma PSF/Novo sigma da PSF.
    
    #READING ALL TEMPLATES/LENDO TODOS OS TEMPLATES E JÁ LOGARITMIZANDO
    for j, file in enumerate(Indo):
        hdu = fits.open(file)
        data = hdu[1].data
        ssp = data[0][1]
        ssp = ndimage.gaussian_filter1d(ssp, sigma) #Realizando a convolução
        sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
        templates[:, j] = sspNew/np.median(sspNew)
    
    

    #ADICIONANDO UM SHIFT PARA COINCIDIR OS COMPRIMENTOS DE ONDA DO ESPECTRO E DO TEMPLATE
        #Artificial shift for the galaxy and templates wavelenght may coincide.    
        #Nem sempre os comprimentos de onda do templete e do espectro coincidem, por esse motivo é dado um 
        #shift artificial ao templete, mas que após o ajuste é retirado.
    c = 299792.458 #Speed of light/Velocidade da Luz
    dv = (np.mean(logLam2[:velscale_ratio]) - logLam1[0])*c #Shift
    goodPixels = util.determine_goodpixels(logLam1, lamRange2, z)  #Mask bad emission lines/Máscaras para linhas de emissão
    vel = c*np.log(1 + z)
    start = [vel, 200.] #Inicial guess/Chute inicial
    
    #START OF FIT/INÍCIO DO AJUSTE
       #For each spectrum the modeling is done. After the best solution is printed 
       #(velocity, velocity dispersion, another moments). Then, a table is write with the information about the
       #pixel position, velocity, velocity dispersion, chi²/DOF and 1-sigma error. The table is saved with name
       #'Output_Ppxf.txt'.  
        
       #Para cada espectro ele realiza o ajuste e printa abaixo o nome do px em que foi realizado o ajuste,
       #bem como as infomações do melhor ajuste (qui², Velocidade, Dispersão, Demais momentos). Então cria uma
       #tabela com as informações necessárias e a salva com o nome 'Output_Ppxf.txt'.
    pp = ppxf(templates, galaxy, noise, velscale, start,
                lam = lam, plot=True, moments=2,
                  degree=6,vsyst=dv, goodpixels=goodPixels, velscale_ratio=velscale_ratio)
        #For more informations about the method, visit the paper of Cappellari avaible in README
        #Para mais informações sobre o método, visite o paper de Cappellari disponível no README
        
        #Plot and save the best model/Plota e salva o melhor modelo
    pp.plot() #Plot the fit/Plota o fit
    plt.legend(["$\\chi^2/DOF$=%.3f"%pp.chi2])
    plt.savefig(data_folder+'/Data/Spec_Fit/Bin%d.png'%i,format='png')
    plt.clf()
    
    print(i)
    print('Vel :%f.\nDisp:%f.'%(pp.sol[0],pp.sol[1]))
    print('Best-fitting redshift z:', (0.035 + 1)*(1 + pp.sol[0]/c) - 1)
    error = pp.error*np.sqrt(pp.chi2) #Formal Error. dV = error[0], dsigma = error[1]
    #ESCREVENDO UMA TABELA COM OS DADOS DE Bin  VELOCIDADE(KM/S) DISPERSÃO(KM/S) chi2 dV dsigma
    newrow = [np.int(i), pp.sol[0], pp.sol[1], pp.chi2, error[0], error[1]]
    if i == 0:
        table = np.array([np.int(i), pp.sol[0], pp.sol[1],pp.chi2, error[0], error[1]])
    else:
        table = np.vstack([table,newrow])
    print('\n####################\n')
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -302       357
# chi2/DOF: 0.635
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  13 / 1273
# 0
# Vel :-302.169420.
# Disp:357.025601.
# Best-fitting redshift z: 0.03395679380530514
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -312       355
# chi2/DOF: 1.022
# method = capfit; Jac calls: 7; Func calls: 23; Status: 3
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 1
# Vel :-312.143706.
# Disp:354.789858.
# Best-fitting redshift z: 0.03392235869588767
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       353
# chi2/DOF: 0.9035
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 2
# Vel :-317.109828.
# Disp:352.934376.
# Best-fitting redshift z: 0.03390521371214339
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -327       345
# chi2/DOF: 0.9838
# method = capfit; Jac calls: 8; Func calls: 28; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 3
# Vel :-327.053501.
# Disp:345.473032.
# Best-fitting redshift z: 0.0338708842931954
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -318       337
# chi2/DOF: 0.995
# method = capfit; Jac calls: 6; Func calls: 20; Status: 4
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 4
# Vel :-317.987901.
# Disp:337.485306.
# Best-fitting redshift z: 0.03390218226557429
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -318       330
# chi2/DOF: 1.097
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 5
# Vel :-318.358723.
# Disp:330.165720.
# Best-fitting redshift z: 0.033900902041303915
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -319       324
# chi2/DOF: 1.134
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 6
# Vel :-319.373077.
# Disp:323.996843.
# Best-fitting redshift z: 0.0338974000975949
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -320       320
# chi2/DOF: 1.083
# method = capfit; Jac calls: 6; Func calls: 20; Status: 4
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 7
# Vel :-320.013367.
# Disp:319.951433.
# Best-fitting redshift z: 0.033895189568796
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -318       312
# chi2/DOF: 1.232
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 8
# Vel :-317.996716.
# Disp:312.394716.
# Best-fitting redshift z: 0.03390215183251288
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -320       308
# chi2/DOF: 1.069
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 9
# Vel :-320.079760.
# Disp:308.166745.
# Best-fitting redshift z: 0.0338949603537575
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       301
# chi2/DOF: 0.974
# method = capfit; Jac calls: 6; Func calls: 20; Status: 4
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 10
# Vel :-321.201316.
# Disp:300.531537.
# Best-fitting redshift z: 0.033891088308131145
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       308
# chi2/DOF: 1.032
# method = capfit; Jac calls: 9; Func calls: 31; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 11
# Vel :-321.812423.
# Disp:308.178812.
# Best-fitting redshift z: 0.03388897852901018
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       302
# chi2/DOF: 1.011
# method = capfit; Jac calls: 6; Func calls: 20; Status: 3
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 12
# Vel :-320.954214.
# Disp:301.782640.
# Best-fitting redshift z: 0.033891941398849434
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -318       298
# chi2/DOF: 1.207
# method = capfit; Jac calls: 9; Func calls: 31; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 13
# Vel :-318.351567.
# Disp:298.025805.
# Best-fitting redshift z: 0.0339009267477568
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -308       304
# chi2/DOF: 1.159
# method = capfit; Jac calls: 6; Func calls: 22; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 14
# Vel :-307.526680.
# Disp:304.101800.
# Best-fitting redshift z: 0.033938298461201555
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -323       305
# chi2/DOF: 1.133
# method = capfit; Jac calls: 6; Func calls: 20; Status: 4
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 15
# Vel :-322.614637.
# Disp:304.730919.
# Best-fitting redshift z: 0.03388620897454131
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -316       297
# chi2/DOF: 1.154
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  12 / 1273
# 16
# Vel :-316.349552.
# Disp:297.064891.
# Best-fitting redshift z: 0.03390783847971268
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -325       308
# chi2/DOF: 1.115
# method = capfit; Jac calls: 6; Func calls: 20; Status: 3
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 17
# Vel :-324.788620.
# Disp:307.666903.
# Best-fitting redshift z: 0.033878703540981325
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -312       303
# chi2/DOF: 1.102
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 18
# Vel :-312.302584.
# Disp:302.607536.
# Best-fitting redshift z: 0.03392181018596685
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -314       301
# chi2/DOF: 1.003
# method = capfit; Jac calls: 6; Func calls: 20; Status: 4
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 19
# Vel :-313.863753.
# Disp:300.783073.
# Best-fitting redshift z: 0.03391642042616172
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -319       299
# chi2/DOF: 0.9813
# method = capfit; Jac calls: 8; Func calls: 29; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  19 / 1273
# 20
# Vel :-319.344724.
# Disp:299.067555.
# Best-fitting redshift z: 0.033897497984846536
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -323       297
# chi2/DOF: 1.062
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  24 / 1273
# 21
# Vel :-323.344902.
# Disp:297.433009.
# Best-fitting redshift z: 0.03388368781523843
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -316       295
# chi2/DOF: 1.007
# method = capfit; Jac calls: 7; Func calls: 23; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 22
# Vel :-315.698793.
# Disp:294.698032.
# Best-fitting redshift z: 0.033910085153112446
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -309       295
# chi2/DOF: 1.057
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  15 / 1273
# 23
# Vel :-309.340318.
# Disp:294.991883.
# Best-fitting redshift z: 0.03393203707976422
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       292
# chi2/DOF: 1.2
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 24
# Vel :-320.652080.
# Disp:291.958042.
# Best-fitting redshift z: 0.03389298448311773
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       285
# chi2/DOF: 1.103
# method = capfit; Jac calls: 8; Func calls: 29; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  25 / 1273
# 25
# Vel :-312.898402.
# Disp:285.391744.
# Best-fitting redshift z: 0.03391975319192442
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -312       284
# chi2/DOF: 1.208
# method = capfit; Jac calls: 7; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  20 / 1273
# 26
# Vel :-312.069272.
# Disp:284.121211.
# Best-fitting redshift z: 0.03392261566988619
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       294
# chi2/DOF: 1.142
# method = capfit; Jac calls: 9; Func calls: 29; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 27
# Vel :-322.403491.
# Disp:293.577790.
# Best-fitting redshift z: 0.0338869379317146
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       283
# chi2/DOF: 1.294
# method = capfit; Jac calls: 8; Func calls: 28; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 28
# Vel :-313.187883.
# Disp:283.052315.
# Best-fitting redshift z: 0.03391875378965725
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -323       281
# chi2/DOF: 1.344
# method = capfit; Jac calls: 8; Func calls: 28; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 29
# Vel :-322.847631.
# Disp:281.168282.
# Best-fitting redshift z: 0.03388540459018996
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       283
# chi2/DOF: 1.383
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 30
# Vel :-320.948491.
# Disp:282.743990.
# Best-fitting redshift z: 0.03389196115639059
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -324       274
# chi2/DOF: 1.197
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  18 / 1273
# 31
# Vel :-324.317784.
# Disp:273.937392.
# Best-fitting redshift z: 0.03388032904961813
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       279
# chi2/DOF: 1.257
# method = capfit; Jac calls: 7; Func calls: 26; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 32
# Vel :-322.162017.
# Disp:278.520836.
# Best-fitting redshift z: 0.03388777159465306
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -326       275
# chi2/DOF: 1.324
# method = capfit; Jac calls: 9; Func calls: 32; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 33
# Vel :-325.939467.
# Disp:275.000254.
# Best-fitting redshift z: 0.0338747303714122
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       274
# chi2/DOF: 1.125
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 34
# Vel :-312.598012.
# Disp:274.316939.
# Best-fitting redshift z: 0.03392079025336692
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -311       281
# chi2/DOF: 1.305
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  24 / 1273
# 35
# Vel :-311.105870.
# Disp:280.550026.
# Best-fitting redshift z: 0.033925941706950624
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       283
# chi2/DOF: 1.195
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 36
# Vel :-317.215634.
# Disp:283.363232.
# Best-fitting redshift z: 0.033904848428718104
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       272
# chi2/DOF: 1.233
# method = capfit; Jac calls: 9; Func calls: 32; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  20 / 1273
# 37
# Vel :-312.791664.
# Disp:272.413902.
# Best-fitting redshift z: 0.033920121692587735
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -310       253
# chi2/DOF: 1.288
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 38
# Vel :-309.992538.
# Disp:252.888218.
# Best-fitting redshift z: 0.03392978536184166
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -335       266
# chi2/DOF: 1.356
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 39
# Vel :-334.838028.
# Disp:265.667585.
# Best-fitting redshift z: 0.03384400908276297
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -326       258
# chi2/DOF: 1.126
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  17 / 1273
# 40
# Vel :-325.577015.
# Disp:257.679838.
# Best-fitting redshift z: 0.033875981694528434
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -309       270
# chi2/DOF: 1.268
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 41
# Vel :-308.809077.
# Disp:270.339654.
# Best-fitting redshift z: 0.033933871128240645
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -284       269
# chi2/DOF: 1.332
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  13 / 1273
# 42
# Vel :-284.118656.
# Disp:268.936370.
# Best-fitting redshift z: 0.0340191120512634
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -311       298
# chi2/DOF: 1.213
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 43
# Vel :-310.672101.
# Disp:297.582973.
# Best-fitting redshift z: 0.03392743924712205
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -312       292
# chi2/DOF: 1.259
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 44
# Vel :-312.087621.
# Disp:291.807922.
# Best-fitting redshift z: 0.03392255232125119
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -300       283
# chi2/DOF: 1.171
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 45
# Vel :-300.487342.
# Disp:283.196345.
# Best-fitting redshift z: 0.0339626009917382
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -297       251
# chi2/DOF: 1.29
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 46
# Vel :-296.623849.
# Disp:251.046973.
# Best-fitting redshift z: 0.03397593926831788
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -345       260
# chi2/DOF: 1.201
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  20 / 1273
# 47
# Vel :-344.611496.
# Disp:259.594308.
# Best-fitting redshift z: 0.033810267274967165
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -307       283
# chi2/DOF: 1.208
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 48
# Vel :-307.103611.
# Disp:282.914809.
# Best-fitting redshift z: 0.03393975906077662
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -306       256
# chi2/DOF: 1.227
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  1 / 1273
# 49
# Vel :-305.632598.
# Disp:255.635568.
# Best-fitting redshift z: 0.03394483756882871
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -277       255
# chi2/DOF: 1.25
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  2 / 1273
# 50
# Vel :-276.598648.
# Disp:254.632893.
# Best-fitting redshift z: 0.03404507404148571
#
# ####################

# %%
np.savetxt('Output_Ppxf_IndoTemplate.txt',table, header= 'Bin vel(km/s) disp(km/s) chi2/DOF dV dsigma', fmt='%i %i %.18e %.18e %.18e %.18e',delimiter=' ')
