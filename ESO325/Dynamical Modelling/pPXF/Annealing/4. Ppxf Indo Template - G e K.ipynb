# %% [markdown]
# Author: Carlos Roberto de Melo
#
# Date: 05/27/2020
#
# Obj: Perform the modeling of spectrum based on pPXF method by Cappellari,and obtein the kinematics./Realizar o modelamento de espectros baeado no código pPXF de Cappellari, e obter a cinemática.

# %%
import glob
from os import path

from astropy.io import fits
from scipy import ndimage
import numpy as np

import ppxf as ppxf_package
from ppxf.ppxf import ppxf
import ppxf.ppxf_util as util

import matplotlib.pyplot as plt

data_folder = "/home/carlos/Desktop/ESO"

# %%
#Directory of stellar library/
stellar_lib = '/home/carlos/Downloads/Bibliotecas Estelares/BINTABLE'
Indo_all    = glob.glob(stellar_lib + '/*.fits')    #All templates
Indo_GK     = []

#Selecting only G and K stars
for i in range(len(Indo_all)):
    hdu = fits.open(Indo_all[i])
    h3 = hdu[1].header
    try:
        if h3['SPTYPE'][0] == "K" or h3['SPTYPE'][0] == "k" or h3['SPTYPE'][0] == "G" or h3['SPTYPE'][0] == "g":
            Indo_GK.append(Indo_all[i])
    except:
        continue

# %%
No_Gaps = []

#Selecting templates with no gaps and entiry wavelengt coverage
for i in range(len(Indo_GK)):
    hdu = fits.open(Indo_GK[i])
    h3 = hdu[1].header
    try:
        gap = h3['GAPS']
    except:
        if float(h3["COVERAGE"][7:]) == 9469.0:
            No_Gaps.append(Indo_GK[i])
        continue

# %%
ppxf_dir = '/home/carlos/Desktop/ppxf' #Directory of stellar library/Diretória da biblioteca estelar
spec_path = "/home/carlos/Desktop/ESO/Data/Binned_Spec/"

FWHM_tem = 1.35


for i in range(51): #Number of bins
     #READING THE SPECTRUM/LENDO UM ESPECTRO
    file = (spec_path + 'Bin%d.fits'%i) #Path and name of the spectrum/Caminho e nome do arquivo do espectro
    hdu = fits.open(file) #Opening the .fits file/Abrindo o arquivo.fits
    gal_lin = hdu[1].data #Read the data/Lendo os dados
    h1 = hdu[1].header    #Read the header/Lendo o header dos dados
    
    #READING THE VARIANCE/LENDO A VARIÂNCIA DO ESPECTRO
    var = hdu[2].data     #Read the variance/Lendo a variância
    h_var = hdu[2].header #Read the variance header/Lendo o header da variância
    
    #LOG-REBIN THE SPECTRUM AND VARIANCE/LOGARITMIZANDO O ESPECTRO E A VARIÂNCIA
        #SPECTRUM/ESPECTRO
    FWHM_gal = 2.71  #FWHM of telescope in Angstrons/FWHM do telescópio em Angstrons
    lambRange1 = h1['CRVAL1'] + np.array([0.,h1['CDELT1']*(h1['NAXIS1']-1)]) #Generating the wavelengths/Está linha gera os comprimentos de onda
                                #pois a variável gal_lin armazena em um array apenas as intensidades, mas não os comprimentos de onda
        
    #De-redshift
    z = 0.035 # Initial estimate of the galaxy redshift
    lambRange1 = lambRange1/(1+z) # Compute approximate restframe wavelength range
    FWHM_gal = FWHM_gal/(1+z)   # Adjust resolution in Angstrom
    #Depois do passo acima, a galáxia passa a estar no restframe, logo é preeciso setar
    z = 0.
    
    
    galaxy, logLam1, velscale = util.log_rebin(lambRange1, gal_lin) #Log-rebin the spectrum/Logaritimizando o espectro da galáxia
    median_galaxy = np.median(galaxy) #Mean of spectrum for normalization/Média do espectro, pois vamos normalizá-lo pela média
    galaxy = galaxy/median_galaxy        #Normalizing the spectrum/Normalizando o espectro pela média
    lam = np.exp(logLam1)                #Recovering the wavelength in Ansgstrons/Recuperando o comprimento de onda em unidades do SI
        
    #VARIANCE/VARIÂNCIA
    lamRange_var = h_var['CRVAL1'] + np.array([0.,h_var['CDELT1']*(h_var['NAXIS1']-1)])
    lamRange_var = lamRange_var/(1+ 0.035)
    erro = np.sqrt(var) #1-sigma error from variance/1-sigma erro da variância
    erro, loglam_var, velscale_var = util.log_rebin(lamRange_var, erro)
    noise = erro/median_galaxy         #Normalizing the error/Normalizando o erro  
    
        
    #READING ONE TEMPLATE FOR DETERMINE THE LENGHT/LENDO UM TEMPLATE PARA SABER O TAMANHO DO VETOR FINAL
        #The ideia is make a empty array to after complete with the informations about the templates of the stellar libary/
                    #A ideia é crirar um array vazio para que mais tarde seja preenchido com as informações de todos os templetes.

    
    
    
    velscale_ratio = 1
    hdu = fits.open(No_Gaps[0])
    data = hdu[1].data
    ssp = hdu[1].data
    h2 = hdu[0].header
    
    #Log_rebin TEMPLATE/LOGARITMIZANDO O TEMPLATE
    lamRange2 = np.array([ssp[0][0][0], ssp[0][0][-1]]) 
    sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp[0][1], velscale=velscale/velscale_ratio)
    templates = np.empty((sspNew.size, len(No_Gaps)))  #Array com o tamanho necessário

    #FINAL FWHM FOR GALAXY AND TEMPLATE CONVOLUTION/CALCULANDO A FWHM FINAL PARA REALIZAR A CONVOLUÇÃO DO TEMPLATE E GALÁXIA
    FWHM_dif = np.sqrt(FWHM_gal**2 - FWHM_tem**2)
    sigma = FWHM_dif/2.355/0.4 #New sigma PSF/Novo sigma da PSF.
    
    #READING ALL TEMPLATES/LENDO TODOS OS TEMPLATES E JÁ LOGARITMIZANDO
    for j, file in enumerate(No_Gaps):
        hdu = fits.open(file)
        data = hdu[1].data
        ssp = hdu[1].data
        ssp = ndimage.gaussian_filter1d(ssp[0][1], sigma) #Realizando a convolução
        sspNew, logLam2, velscale_temp = util.log_rebin(lamRange2, ssp, velscale=velscale/velscale_ratio)
        templates[:, j] = sspNew/np.median(sspNew)
    
    

    #ADICIONANDO UM SHIFT PARA COINCIDIR OS COMPRIMENTOS DE ONDA DO ESPECTRO E DO TEMPLATE
        #Artificial shift for the galaxy and templates wavelenght may coincide.    
        #Nem sempre os comprimentos de onda do templete e do espectro coincidem, por esse motivo é dado um 
        #shift artificial ao templete, mas que após o ajuste é retirado.
    c = 299792.458 #Speed of light/Velocidade da Luz
    dv = (np.mean(logLam2[:velscale_ratio]) - logLam1[0])*c #Shift
    goodPixels = util.determine_goodpixels(logLam1, lamRange2, z)  #Mask bad emission lines/Máscaras para linhas de emissão
    vel = c*np.log(1 + z)
    start = [vel, 200.] #Inicial guess/Chute inicial
    goodPixels = np.arange(0, galaxy.size)
    goodPixels = util.determine_goodpixels(logLam1, lamRange2, z)
    
    #START OF FIT/INÍCIO DO AJUSTE
       #For each spectrum the modeling is done. After the best solution is printed 
       #(velocity, velocity dispersion, another moments). Then, a table is write with the information about the
       #pixel position, velocity, velocity dispersion, chi²/DOF and 1-sigma error. The table is saved with name
       #'Output_Ppxf.txt'.  
        
       #Para cada espectro ele realiza o ajuste e printa abaixo o nome do px em que foi realizado o ajuste,
       #bem como as infomações do melhor ajuste (qui², Velocidade, Dispersão, Demais momentos). Então cria uma
       #tabela com as informações necessárias e a salva com o nome 'Output_Ppxf.txt'.
    pp = ppxf(templates, galaxy, noise, velscale, start,
                lam = lam, plot=True, moments=2,goodpixels=goodPixels,
                  degree=6,vsyst=dv, velscale_ratio=velscale_ratio)
        #For more informations about the method, visit the paper of Cappellari avaible in README
        #Para mais informações sobre o método, visite o paper de Cappellari disponível no README
        
        #Plot and save the best model/Plota e salva o melhor modelo
    pp.plot() #Plot the fit/Plota o fit
    plt.legend(["$\\chi^2/DOF$=%.3f"%pp.chi2])
    plt.savefig(data_folder+'/Data/Spec_Fit_GK/Bin%d.png'%i,format='png')
    plt.clf()
    
    print(i)
    print('Vel :%f.\nDisp:%f.'%(pp.sol[0],pp.sol[1]))
    print('Best-fitting redshift z:', (0.035 + 1)*(1 + pp.sol[0]/c) - 1)
    error = pp.error*np.sqrt(pp.chi2) #Formal Error. dV = error[0], dsigma = error[1]
    #ESCREVENDO UMA TABELA COM OS DADOS DE Bin  VELOCIDADE(KM/S) DISPERSÃO(KM/S) chi2 dV dsigma
    newrow = [np.int(i), pp.sol[0], pp.sol[1], pp.chi2, error[0], error[1]]
    if i == 0:
        table = np.array([np.int(i), pp.sol[0], pp.sol[1],pp.chi2, error[0], error[1]])
    else:
        table = np.vstack([table,newrow])
    print('\n####################\n')
# Out:
#  Best Fit:       Vel     sigma
#  comp.  0:      -301       373
# chi2/DOF: 0.7315
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 0
# Vel :-301.443949.
# Disp:373.492919.
# Best-fitting redshift z: 0.03395929841223655
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       375
# chi2/DOF: 1.729
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 1
# Vel :-317.092437.
# Disp:374.897810.
# Best-fitting redshift z: 0.03390527375221786
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       372
# chi2/DOF: 2.068
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 2
# Vel :-317.208973.
# Disp:372.444104.
# Best-fitting redshift z: 0.03390487142434595
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -324       366
# chi2/DOF: 2.196
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  8 / 102
# 3
# Vel :-324.332753.
# Disp:366.263847.
# Best-fitting redshift z: 0.033880277369803924
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       360
# chi2/DOF: 2.292
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 4
# Vel :-316.631328.
# Disp:359.843335.
# Best-fitting redshift z: 0.03390686568177537
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -319       350
# chi2/DOF: 2.314
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 5
# Vel :-318.849266.
# Disp:349.837941.
# Best-fitting redshift z: 0.033899208498306965
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -320       342
# chi2/DOF: 2.607
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 6
# Vel :-320.390759.
# Disp:341.520457.
# Best-fitting redshift z: 0.03389388666572013
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -320       340
# chi2/DOF: 2.52
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  5 / 102
# 7
# Vel :-319.589647.
# Disp:340.329715.
# Best-fitting redshift z: 0.03389665241597717
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -318       334
# chi2/DOF: 2.758
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 8
# Vel :-318.196281.
# Disp:334.371978.
# Best-fitting redshift z: 0.033901462854621256
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       329
# chi2/DOF: 2.222
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 9
# Vel :-320.800448.
# Disp:329.378801.
# Best-fitting redshift z: 0.03389247225937875
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       321
# chi2/DOF: 2.283
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 10
# Vel :-321.872120.
# Disp:320.811696.
# Best-fitting redshift z: 0.033888772429872205
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       324
# chi2/DOF: 2.025
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 11
# Vel :-321.677142.
# Disp:324.205614.
# Best-fitting redshift z: 0.03388944557285556
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -323       319
# chi2/DOF: 1.93
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  8 / 102
# 12
# Vel :-322.971869.
# Disp:319.194948.
# Best-fitting redshift z: 0.033884975670362305
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -320       316
# chi2/DOF: 2.194
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 13
# Vel :-320.009616.
# Disp:316.270154.
# Best-fitting redshift z: 0.03389520252005318
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -308       326
# chi2/DOF: 2.126
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 14
# Vel :-307.836568.
# Disp:325.545654.
# Best-fitting redshift z: 0.033937228606719216
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -324       319
# chi2/DOF: 2.134
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  8 / 102
# 15
# Vel :-323.721746.
# Disp:318.663908.
# Best-fitting redshift z: 0.033882386805100806
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -316       313
# chi2/DOF: 2.073
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 16
# Vel :-315.999689.
# Disp:312.539081.
# Best-fitting redshift z: 0.03390904634533087
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -326       325
# chi2/DOF: 1.87
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 17
# Vel :-326.312101.
# Disp:325.041897.
# Best-fitting redshift z: 0.03387344389383462
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       318
# chi2/DOF: 1.701
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 18
# Vel :-316.720065.
# Disp:317.669019.
# Best-fitting redshift z: 0.03390655932483089
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -315       317
# chi2/DOF: 1.737
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  8 / 102
# 19
# Vel :-315.283735.
# Disp:317.408581.
# Best-fitting redshift z: 0.0339115180942382
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -320       317
# chi2/DOF: 1.622
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 20
# Vel :-319.926036.
# Disp:317.479501.
# Best-fitting redshift z: 0.03389549106874412
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       316
# chi2/DOF: 1.654
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 21
# Vel :-321.398128.
# Disp:315.590271.
# Best-fitting redshift z: 0.03389040883594796
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -315       311
# chi2/DOF: 1.617
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  5 / 102
# 22
# Vel :-315.292892.
# Disp:310.653908.
# Best-fitting redshift z: 0.03391148648259179
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -310       316
# chi2/DOF: 1.786
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 23
# Vel :-310.197487.
# Disp:315.657569.
# Best-fitting redshift z: 0.033929077798157126
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       310
# chi2/DOF: 1.83
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 24
# Vel :-321.858412.
# Disp:309.793386.
# Best-fitting redshift z: 0.0338888197559859
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       302
# chi2/DOF: 1.617
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 25
# Vel :-312.675362.
# Disp:301.670754.
# Best-fitting redshift z: 0.03392052321033301
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -315       302
# chi2/DOF: 1.619
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 26
# Vel :-315.265820.
# Disp:301.744649.
# Best-fitting redshift z: 0.03391157994440652
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -323       304
# chi2/DOF: 1.651
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 27
# Vel :-323.206985.
# Disp:304.030785.
# Best-fitting redshift z: 0.03388416396063931
#
# ####################
#  Best Fit:       Vel     sigma
#  comp.  0:      -313       301
# chi2/DOF: 1.727
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 28
# Vel :-313.255445.
# Disp:301.071045.
# Best-fitting redshift z: 0.03391852053937838
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       298
# chi2/DOF: 1.777
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 29
# Vel :-320.969363.
# Disp:297.815535.
# Best-fitting redshift z: 0.033891889098162986
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       300
# chi2/DOF: 1.855
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 30
# Vel :-321.655246.
# Disp:299.881596.
# Best-fitting redshift z: 0.033889521166076575
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -326       288
# chi2/DOF: 1.535
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 31
# Vel :-325.973922.
# Disp:287.712238.
# Best-fitting redshift z: 0.0338746114163182
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       293
# chi2/DOF: 1.613
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 32
# Vel :-320.645235.
# Disp:293.146361.
# Best-fitting redshift z: 0.0338930081160953
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -324       293
# chi2/DOF: 1.768
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 33
# Vel :-324.370616.
# Disp:293.491627.
# Best-fitting redshift z: 0.03388014665308425
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -318       292
# chi2/DOF: 1.323
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 34
# Vel :-317.869593.
# Disp:292.349787.
# Best-fitting redshift z: 0.033902590707859614
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -314       285
# chi2/DOF: 1.521
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  9 / 102
# 35
# Vel :-313.556470.
# Disp:284.754903.
# Best-fitting redshift z: 0.03391748128351124
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -322       292
# chi2/DOF: 1.443
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 36
# Vel :-321.554127.
# Disp:292.225549.
# Best-fitting redshift z: 0.033889870267011846
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       290
# chi2/DOF: 1.492
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  5 / 102
# 37
# Vel :-316.813335.
# Disp:290.289273.
# Best-fitting redshift z: 0.033906237321397636
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -330       276
# chi2/DOF: 1.518
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  5 / 102
# 38
# Vel :-329.871724.
# Disp:276.026011.
# Best-fitting redshift z: 0.033861154691366746
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -334       284
# chi2/DOF: 1.474
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 39
# Vel :-334.271720.
# Disp:284.431080.
# Best-fitting redshift z: 0.033845964197443346
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -325       270
# chi2/DOF: 1.245
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 40
# Vel :-324.548565.
# Disp:269.509863.
# Best-fitting redshift z: 0.03387953230345708
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -307       283
# chi2/DOF: 1.409
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  7 / 102
# 41
# Vel :-306.760615.
# Disp:283.143144.
# Best-fitting redshift z: 0.03394094321580843
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -291       282
# chi2/DOF: 1.404
# method = capfit; Jac calls: 5; Func calls: 17; Status: 4
# linear_method = nnls; Nonzero Templates (>0.1%):  6 / 102
# 42
# Vel :-290.896190.
# Disp:282.224212.
# Best-fitting redshift z: 0.03399571337063545
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -310       314
# chi2/DOF: 1.289
# method = capfit; Jac calls: 6; Func calls: 20; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  5 / 102
# 43
# Vel :-309.813510.
# Disp:313.738827.
# Best-fitting redshift z: 0.03393040343575793
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -299       303
# chi2/DOF: 1.312
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  8 / 102
# 44
# Vel :-298.768806.
# Disp:302.616334.
# Best-fitting redshift z: 0.033968534044005905
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -311       299
# chi2/DOF: 1.296
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  5 / 102
# 45
# Vel :-310.870460.
# Disp:299.096063.
# Best-fitting redshift z: 0.033926754433005524
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -299       262
# chi2/DOF: 1.384
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  4 / 102
# 46
# Vel :-298.926812.
# Disp:261.724305.
# Best-fitting redshift z: 0.033967988547321415
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -331       288
# chi2/DOF: 1.31
# method = capfit; Jac calls: 5; Func calls: 17; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  4 / 102
# 47
# Vel :-331.441784.
# Disp:287.848880.
# Best-fitting redshift z: 0.033855734234138124
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -312       284
# chi2/DOF: 1.299
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  5 / 102
# 48
# Vel :-312.106613.
# Disp:283.922834.
# Best-fitting redshift z: 0.03392248675575993
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       264
# chi2/DOF: 1.29
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  5 / 102
# 49
# Vel :-320.906155.
# Disp:264.009275.
# Best-fitting redshift z: 0.033892107316538356
#
# ####################
#
#  Best Fit:       Vel     sigma
#  comp.  0:      -309       303
# chi2/DOF: 1.318
# method = capfit; Jac calls: 4; Func calls: 14; Status: 2
# linear_method = nnls; Nonzero Templates (>0.1%):  2 / 102
# 50
# Vel :-308.554389.
# Disp:303.366684.
# Best-fitting redshift z: 0.03393475041241811
#
# ####################

# %%
temp = np.where(pp.weights !=0)
for j in range(len(temp[0])):
    index = temp[0][j]
    plt.figure(figsize=(15,5))
    plt.plot(np.exp(logLam2),pp.weights[index]*pp.templates[:,index])
    plt.plot(np.exp(logLam1),pp.galaxy)
    plt.title("%d"%index)
    plt.show()
    plt.clf()

# %%
np.savetxt('Output_Ppxf_IndoGK_Template.txt',table, header= 'Bin vel(km/s) disp(km/s) chi2/DOF dV dsigma', fmt='%i %i %.18e %.18e %.18e %.18e',delimiter=' ')
